# %% [markdown]
# # Import Libraries

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
from functools import reduce
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy import stats
import statsmodels.api as sm
#import mplcursors
from pylab import rcParams
from matplotlib.backends.backend_agg import FigureCanvasAgg
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # Load the Dataset

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('C:\\NachuMohan\\Saint_Peters_University\\GA_Summer2020\\Health-Literacy-COVID19\\Census Demographic Data\\Clean Data\\COVIDdemographic.csv')

# %%
df.head(5)
# Out:
#         State    cases  deaths  Total Population  Total population_Male  \
# 0  Alabama     387786   14345   4887871           2369271
# 1  Alaska      18316    367     737438            382952
# 2  Arizona     426614   18857   7171646           3565129
# 3  Arkansas    161569   3301    3013825           1476680
# 4  California  2664110  102387  39557045          19673553
#
#    Total population_Female  Under 5 years  5 to 9 years  10 to 14 years  \
# 0  2518600                  288589         290369        321430
# 1  354486                   52173          52544         49747
# 2  3606517                  434032         441613        488738
# 3  1537145                  188092         192523        203502
# 4  19883492                 2428493        2398894       2646096
#
#    15 to 19 years  20 to 24 years  25 to 34 years  35 to 44 years  \
# 0  332209          317810          635976          593480
# 1  48514           49107           117688          97020
# 2  477306          489653          979328          882618
# 3  208021          199748          392937          367053
# 4  2557470         2710448         6034398         5264457
#
#    45 to 54 years  55 to 59 years  60 to 64 years  65 to 74 years  \
# 0  626173          332700          319472          493396
# 1  89333           47300           46012           59630
# 2  852462          430467          436326          727956
# 3  370343          196034          187896          296808
# 4  5068026         2485050         2296376         3286461
#
#    75 to 84 years  85 years and over  RACE_Total population     White  \
# 0  251025          85242              4887871                3306838
# 1  21000           7370               737438                 474555
# 2  398408          132739             7171646                5590505
# 3  154699          56169              3013825                2306096
# 4  1651296         729580             39557045               23535388
#
#    Black or African American  American Indian and Alaska Native    Asian  \
# 0  1307040                    22063                              65095
# 1  25197                      111371                             46381
# 2  336340                     330599                             237873
# 3  456714                     20951                              47548
# 4  2283850                    302792                             5821585
#
#    Native Hawaiian and Other Pacific Islander  \
# 0  1797
# 1  7958
# 2  15661
# 3  9398
# 4  155739
#
#    Total population_HISPANIC OR LATINO
# 0  4887871
# 1  737438
# 2  7171646
# 3  3013825
# 4  39557045

# %% [markdown]
# # Shape of a dataframe

# %%
df.shape
# Out:
# (51, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 26 columns):
# State                                         51 non-null object
# cases                                         51 non-null int64
# deaths                                        51 non-null int64
# Total Population                              51 non-null int64
# Total population_Male                         51 non-null int64
# Total population_Female                       51 non-null int64
# Under 5 years                                 51 non-null int64
# 5 to 9 years                                  51 non-null int64
# 10 to 14 years                                51 non-null int64
# 15 to 19 years                                51 non-null int64
# 20 to 24 years                                51 non-null int64
# 25 to 34 years                                51 non-null int64
# 35 to 44 years                                51 non-null int64
# 45 to 54 years                                51 non-null int64
# 55 to 59 years                                51 non-null int64
# 60 to 64 years                                51 non-null int64
# 65 to 74 years                                51 non-null int64
# 75 to 84 years                                51 non-null int64
# 85 years and over                             51 non-null int64
# RACE_Total population                         51 non-null int64
# White                                         51 non-null int64
# Black or African American                     51 non-null int64
# American Indian and Alaska Native             51 non-null int64
# Asian                                         51 non-null int64
# Native Hawaiian and Other Pacific Islander    51 non-null int64
# Total population_HISPANIC OR LATINO           51 non-null int64
# dtypes: int64(25), object(1)
# memory usage: 10.5+ KB

# %%
df.isnull().sum()
# Out:
# State                                         0
# cases                                         0
# deaths                                        0
# Total Population                              0
# Total population_Male                         0
# Total population_Female                       0
# Under 5 years                                 0
# 5 to 9 years                                  0
# 10 to 14 years                                0
# 15 to 19 years                                0
# 20 to 24 years                                0
# 25 to 34 years                                0
# 35 to 44 years                                0
# 45 to 54 years                                0
# 55 to 59 years                                0
# 60 to 64 years                                0
# 65 to 74 years                                0
# 75 to 84 years                                0
# 85 years and over                             0
# RACE_Total population                         0
# White                                         0
# Black or African American                     0
# American Indian and Alaska Native             0
# Asian                                         0
# Native Hawaiian and Other Pacific Islander    0
# Total population_HISPANIC OR LATINO           0
# dtype: int64

# %%
df.describe()
# Out:
#               cases        deaths  Total Population  Total population_Male  \
# count  5.100000e+01  5.100000e+01  5.100000e+01      5.100000e+01
# mean   1.056306e+06  5.861198e+04  6.415048e+06      3.159179e+06
# std    2.249183e+06  1.579360e+05  7.343308e+06      3.628720e+06
# min    1.831600e+04  2.810000e+02  5.777370e+05      2.926190e+05
# 25%    1.696980e+05  4.021000e+03  1.780020e+06      8.884075e+05
# 50%    3.877860e+05  1.425100e+04  4.468402e+06      2.199021e+06
# 75%    1.047118e+06  5.046050e+04  7.353618e+06      3.665994e+06
# max    1.504181e+07  1.081194e+06  3.955704e+07      1.967355e+07
#
#        Total population_Female  Under 5 years  5 to 9 years  10 to 14 years  \
# count  5.100000e+01             5.100000e+01   5.100000e+01  5.100000e+01
# mean   3.255868e+06             3.852219e+05   3.883510e+05  4.194691e+05
# std    3.715146e+06             4.565007e+05   4.501072e+05  4.942501e+05
# min    2.851180e+05             2.881000e+04   3.201900e+04  3.338600e+04
# 25%    8.916125e+05             1.038075e+05   1.105810e+05  1.186685e+05
# 50%    2.269381e+06             2.734890e+05   2.799780e+05  2.858330e+05
# 75%    3.687624e+06             4.461130e+05   4.540500e+05  4.784465e+05
# max    1.988349e+07             2.428493e+06   2.398894e+06  2.646096e+06
#
#        15 to 19 years  20 to 24 years  25 to 34 years  35 to 44 years  \
# count  5.100000e+01    5.100000e+01    5.100000e+01    5.100000e+01
# mean   4.204999e+05    4.258424e+05    8.891113e+05    8.136952e+05
# std    4.817187e+05    4.934780e+05    1.078738e+06    9.638990e+05
# min    3.756800e+04    3.288000e+04    7.505800e+04    7.011300e+04
# 25%    1.198940e+05    1.148050e+05    2.185410e+05    2.192580e+05
# 50%    2.889440e+05    3.007440e+05    5.926550e+05    5.568330e+05
# 75%    4.682640e+05    4.913170e+05    1.070712e+06    9.444730e+05
# max    2.557470e+06    2.710448e+06    6.034398e+06    5.264457e+06
#
#        45 to 54 years  55 to 59 years  60 to 64 years  65 to 74 years  \
# count  5.100000e+01    5.100000e+01    5.100000e+01    5.100000e+01
# mean   8.157891e+05    4.240106e+05    4.051534e+05    5.994375e+05
# std    9.421501e+05    4.680109e+05    4.366872e+05    6.423737e+05
# min    6.748700e+04    3.686900e+04    3.315300e+04    4.883300e+04
# 25%    2.099755e+05    1.174285e+05    1.136820e+05    1.706250e+05
# 50%    5.673130e+05    3.035890e+05    2.953110e+05    4.354650e+05
# 75%    9.262360e+05    4.893070e+05    4.615040e+05    7.193685e+05
# max    5.068026e+06    2.485050e+06    2.296376e+06    3.286461e+06
#
#        75 to 84 years  85 years and over  RACE_Total population         White  \
# count  5.100000e+01    51.000000          5.100000e+01           5.100000e+01
# mean   3.048618e+05    123604.862745      6.415048e+06           4.630844e+06
# std    3.359567e+05    142146.703257      7.343308e+06           4.872214e+06
# min    2.100000e+04    7370.000000        5.777370e+05           2.967470e+05
# 25%    8.526700e+04    37668.000000       1.780020e+06           1.588392e+06
# 50%    2.118690e+05    81382.000000       4.468402e+06           3.305047e+06
# 75%    3.616560e+05    137769.500000      7.353618e+06           5.611884e+06
# max    1.651296e+06    729580.000000      3.955704e+07           2.353539e+07
#
#        Black or African American  American Indian and Alaska Native  \
# count  5.100000e+01               51.000000
# mean   8.160346e+05               54933.078431
# std    9.833194e+05               76477.000582
# min    3.667000e+03               1743.000000
# 25%    6.971400e+04               13736.500000
# 50%    3.547610e+05               25657.000000
# 75%    1.365175e+06               57508.000000
# max    3.527027e+06               330599.000000
#
#               Asian  Native Hawaiian and Other Pacific Islander  \
# count  5.100000e+01  51.000000
# mean   3.610823e+05  12275.568627
# std    8.507498e+05  29651.663554
# min    5.807000e+03  51.000000
# 25%    3.754350e+04  1211.000000
# 50%    1.190460e+05  3859.000000
# 75%    3.524065e+05  8678.000000
# max    5.821585e+06  155739.000000
#
#        Total population_HISPANIC OR LATINO
# count  5.100000e+01
# mean   6.415048e+06
# std    7.343308e+06
# min    5.777370e+05
# 25%    1.780020e+06
# 50%    4.468402e+06
# 75%    7.353618e+06
# max    3.955704e+07

# %%
corr = df.corr()

# %%
corr
# Out:
#                                                cases    deaths  \
# cases                                       1.000000  0.990033
# deaths                                      0.990033  1.000000
# Total Population                            0.474197  0.381703
# Total population_Male                       0.467591  0.374954
# Total population_Female                     0.480579  0.388237
# Under 5 years                               0.445039  0.352253
# 5 to 9 years                                0.432210  0.338495
# 10 to 14 years                              0.427069  0.332640
# 15 to 19 years                              0.449039  0.355787
# 20 to 24 years                              0.466246  0.374678
# 25 to 34 years                              0.471632  0.380169
# 35 to 44 years                              0.456208  0.362104
# 45 to 54 years                              0.489046  0.396419
# 55 to 59 years                              0.504028  0.412764
# 60 to 64 years                              0.508914  0.419185
# 65 to 74 years                              0.490507  0.401017
# 75 to 84 years                              0.500801  0.412830
# 85 years and over                           0.536630  0.449968
# RACE_Total population                       0.474197  0.381703
# White                                       0.449186  0.357395
# Black or African American                   0.512076  0.437061
# American Indian and Alaska Native           0.072430  0.044793
# Asian                                       0.399092  0.321336
# Native Hawaiian and Other Pacific Islander  0.045184  0.002666
# Total population_HISPANIC OR LATINO         0.474197  0.381703
#
#                                             Total Population  \
# cases                                       0.474197
# deaths                                      0.381703
# Total Population                            1.000000
# Total population_Male                       0.999922
# Total population_Female                     0.999926
# Under 5 years                               0.994301
# 5 to 9 years                                0.994205
# 10 to 14 years                              0.994159
# 15 to 19 years                              0.996431
# 20 to 24 years                              0.997935
# 25 to 34 years                              0.997147
# 35 to 44 years                              0.998273
# 45 to 54 years                              0.999294
# 55 to 59 years                              0.996956
# 60 to 64 years                              0.994484
# 65 to 74 years                              0.987113
# 75 to 84 years                              0.972106
# 85 years and over                           0.964929
# RACE_Total population                       1.000000
# White                                       0.987836
# Black or African American                   0.790134
# American Indian and Alaska Native           0.446071
# Asian                                       0.846644
# Native Hawaiian and Other Pacific Islander  0.469451
# Total population_HISPANIC OR LATINO         1.000000
#
#                                             Total population_Male  \
# cases                                       0.467591
# deaths                                      0.374954
# Total Population                            0.999922
# Total population_Male                       1.000000
# Total population_Female                     0.999696
# Under 5 years                               0.994986
# 5 to 9 years                                0.994910
# 10 to 14 years                              0.994888
# 15 to 19 years                              0.996746
# 20 to 24 years                              0.998295
# 25 to 34 years                              0.997662
# 35 to 44 years                              0.998700
# 45 to 54 years                              0.998933
# 55 to 59 years                              0.996223
# 60 to 64 years                              0.993517
# 65 to 74 years                              0.985777
# 75 to 84 years                              0.970211
# 85 years and over                           0.963131
# RACE_Total population                       0.999922
# White                                       0.987550
# Black or African American                   0.784252
# American Indian and Alaska Native           0.450225
# Asian                                       0.849893
# Native Hawaiian and Other Pacific Islander  0.474392
# Total population_HISPANIC OR LATINO         0.999922
#
#                                             Total population_Female  \
# cases                                       0.480579
# deaths                                      0.388237
# Total Population                            0.999926
# Total population_Male                       0.999696
# Total population_Female                     1.000000
# Under 5 years                               0.993483
# 5 to 9 years                                0.993368
# 10 to 14 years                              0.993297
# 15 to 19 years                              0.995975
# 20 to 24 years                              0.997434
# 25 to 34 years                              0.996495
# 35 to 44 years                              0.997706
# 45 to 54 years                              0.999498
# 55 to 59 years                              0.997522
# 60 to 64 years                              0.995280
# 65 to 74 years                              0.988270
# 75 to 84 years                              0.973811
# 85 years and over                           0.966540
# RACE_Total population                       0.999926
# White                                       0.987967
# Black or African American                   0.795760
# American Indian and Alaska Native           0.441946
# Asian                                       0.843344
# Native Hawaiian and Other Pacific Islander  0.464553
# Total population_HISPANIC OR LATINO         0.999926
#
#                                             Under 5 years  5 to 9 years  \
# cases                                       0.445039       0.432210
# deaths                                      0.352253       0.338495
# Total Population                            0.994301       0.994205
# Total population_Male                       0.994986       0.994910
# Total population_Female                     0.993483       0.993368
# Under 5 years                               1.000000       0.999627
# 5 to 9 years                                0.999627       1.000000
# 10 to 14 years                              0.999392       0.999727
# 15 to 19 years                              0.998417       0.998928
# 20 to 24 years                              0.996974       0.996929
# 25 to 34 years                              0.995016       0.994203
# 35 to 44 years                              0.997464       0.997355
# 45 to 54 years                              0.990949       0.990943
# 55 to 59 years                              0.984225       0.984184
# 60 to 64 years                              0.979059       0.979074
# 65 to 74 years                              0.966701       0.967036
# 75 to 84 years                              0.945656       0.945379
# 85 years and over                           0.934517       0.932996
# RACE_Total population                       0.994301       0.994205
# White                                       0.982582       0.983305
# Black or African American                   0.776991       0.780179
# American Indian and Alaska Native           0.459525       0.459685
# Asian                                       0.843027       0.839254
# Native Hawaiian and Other Pacific Islander  0.473724       0.471881
# Total population_HISPANIC OR LATINO         0.994301       0.994205
#
#                                             10 to 14 years  15 to 19 years  \
# cases                                       0.427069        0.449039
# deaths                                      0.332640        0.355787
# Total Population                            0.994159        0.996431
# Total population_Male                       0.994888        0.996746
# Total population_Female                     0.993297        0.995975
# Under 5 years                               0.999392        0.998417
# 5 to 9 years                                0.999727        0.998928
# 10 to 14 years                              1.000000        0.998906
# 15 to 19 years                              0.998906        1.000000
# 20 to 24 years                              0.996780        0.998400
# 25 to 34 years                              0.994059        0.994885
# 35 to 44 years                              0.997334        0.997664
# 45 to 54 years                              0.990913        0.994234
# 55 to 59 years                              0.983932        0.988875
# 60 to 64 years                              0.978796        0.984602
# 65 to 74 years                              0.967042        0.973195
# 75 to 84 years                              0.945864        0.953029
# 85 years and over                           0.933797        0.941984
# RACE_Total population                       0.994159        0.996431
# White                                       0.982653        0.985960
# Black or African American                   0.778248        0.790820
# American Indian and Alaska Native           0.462720        0.450504
# Asian                                       0.841328        0.836441
# Native Hawaiian and Other Pacific Islander  0.472402        0.459347
# Total population_HISPANIC OR LATINO         0.994159        0.996431
#
#                                             20 to 24 years  25 to 34 years  \
# cases                                       0.466246        0.471632
# deaths                                      0.374678        0.380169
# Total Population                            0.997935        0.997147
# Total population_Male                       0.998295        0.997662
# Total population_Female                     0.997434        0.996495
# Under 5 years                               0.996974        0.995016
# 5 to 9 years                                0.996929        0.994203
# 10 to 14 years                              0.996780        0.994059
# 15 to 19 years                              0.998400        0.994885
# 20 to 24 years                              1.000000        0.998198
# 25 to 34 years                              0.998198        1.000000
# 35 to 44 years                              0.998600        0.998636
# 45 to 54 years                              0.996324        0.995730
# 55 to 59 years                              0.991692        0.990648
# 60 to 64 years                              0.987779        0.986559
# 65 to 74 years                              0.976225        0.975610
# 75 to 84 years                              0.957059        0.956878
# 85 years and over                           0.950304        0.952543
# RACE_Total population                       0.997935        0.997147
# White                                       0.982956        0.977771
# Black or African American                   0.775786        0.762398
# American Indian and Alaska Native           0.457376        0.464614
# Asian                                       0.858616        0.875567
# Native Hawaiian and Other Pacific Islander  0.480216        0.501574
# Total population_HISPANIC OR LATINO         0.997935        0.997147
#
#                                             35 to 44 years  45 to 54 years  \
# cases                                       0.456208        0.489046
# deaths                                      0.362104        0.396419
# Total Population                            0.998273        0.999294
# Total population_Male                       0.998700        0.998933
# Total population_Female                     0.997706        0.999498
# Under 5 years                               0.997464        0.990949
# 5 to 9 years                                0.997355        0.990943
# 10 to 14 years                              0.997334        0.990913
# 15 to 19 years                              0.997664        0.994234
# 20 to 24 years                              0.998600        0.996324
# 25 to 34 years                              0.998636        0.995730
# 35 to 44 years                              1.000000        0.996696
# 45 to 54 years                              0.996696        1.000000
# 55 to 59 years                              0.991293        0.998247
# 60 to 64 years                              0.987032        0.996075
# 65 to 74 years                              0.977219        0.988729
# 75 to 84 years                              0.958571        0.974447
# 85 years and over                           0.950493        0.968699
# RACE_Total population                       0.998273        0.999294
# White                                       0.982595        0.985262
# Black or African American                   0.779215        0.797594
# American Indian and Alaska Native           0.455312        0.433112
# Asian                                       0.858573        0.848588
# Native Hawaiian and Other Pacific Islander  0.485899        0.465576
# Total population_HISPANIC OR LATINO         0.998273        0.999294
#
#                                             55 to 59 years  60 to 64 years  \
# cases                                       0.504028        0.508914
# deaths                                      0.412764        0.419185
# Total Population                            0.996956        0.994484
# Total population_Male                       0.996223        0.993517
# Total population_Female                     0.997522        0.995280
# Under 5 years                               0.984225        0.979059
# 5 to 9 years                                0.984184        0.979074
# 10 to 14 years                              0.983932        0.978796
# 15 to 19 years                              0.988875        0.984602
# 20 to 24 years                              0.991692        0.987779
# 25 to 34 years                              0.990648        0.986559
# 35 to 44 years                              0.991293        0.987032
# 45 to 54 years                              0.998247        0.996075
# 55 to 59 years                              1.000000        0.999255
# 60 to 64 years                              0.999255        1.000000
# 65 to 74 years                              0.993680        0.996154
# 75 to 84 years                              0.982651        0.986996
# 85 years and over                           0.978910        0.982976
# RACE_Total population                       0.996956        0.994484
# White                                       0.987047        0.986697
# Black or African American                   0.799235        0.801812
# American Indian and Alaska Native           0.420744        0.417834
# Asian                                       0.835490        0.825377
# Native Hawaiian and Other Pacific Islander  0.447880        0.442252
# Total population_HISPANIC OR LATINO         0.996956        0.994484
#
#                                             65 to 74 years  75 to 84 years  \
# cases                                       0.490507        0.500801
# deaths                                      0.401017        0.412830
# Total Population                            0.987113        0.972106
# Total population_Male                       0.985777        0.970211
# Total population_Female                     0.988270        0.973811
# Under 5 years                               0.966701        0.945656
# 5 to 9 years                                0.967036        0.945379
# 10 to 14 years                              0.967042        0.945864
# 15 to 19 years                              0.973195        0.953029
# 20 to 24 years                              0.976225        0.957059
# 25 to 34 years                              0.975610        0.956878
# 35 to 44 years                              0.977219        0.958571
# 45 to 54 years                              0.988729        0.974447
# 55 to 59 years                              0.993680        0.982651
# 60 to 64 years                              0.996154        0.986996
# 65 to 74 years                              1.000000        0.996296
# 75 to 84 years                              0.996296        1.000000
# 85 years and over                           0.988755        0.993841
# RACE_Total population                       0.987113        0.972106
# White                                       0.983114        0.971485
# Black or African American                   0.808654        0.805217
# American Indian and Alaska Native           0.418794        0.403762
# Asian                                       0.800579        0.774788
# Native Hawaiian and Other Pacific Islander  0.431647        0.408779
# Total population_HISPANIC OR LATINO         0.987113        0.972106
#
#                                             85 years and over  \
# cases                                       0.536630
# deaths                                      0.449968
# Total Population                            0.964929
# Total population_Male                       0.963131
# Total population_Female                     0.966540
# Under 5 years                               0.934517
# 5 to 9 years                                0.932996
# 10 to 14 years                              0.933797
# 15 to 19 years                              0.941984
# 20 to 24 years                              0.950304
# 25 to 34 years                              0.952543
# 35 to 44 years                              0.950493
# 45 to 54 years                              0.968699
# 55 to 59 years                              0.978910
# 60 to 64 years                              0.982976
# 65 to 74 years                              0.988755
# 75 to 84 years                              0.993841
# 85 years and over                           1.000000
# RACE_Total population                       0.964929
# White                                       0.958633
# Black or African American                   0.765161
# American Indian and Alaska Native           0.389465
# Asian                                       0.805569
# Native Hawaiian and Other Pacific Islander  0.432751
# Total population_HISPANIC OR LATINO         0.964929
#
#                                             RACE_Total population     White  \
# cases                                       0.474197               0.449186
# deaths                                      0.381703               0.357395
# Total Population                            1.000000               0.987836
# Total population_Male                       0.999922               0.987550
# Total population_Female                     0.999926               0.987967
# Under 5 years                               0.994301               0.982582
# 5 to 9 years                                0.994205               0.983305
# 10 to 14 years                              0.994159               0.982653
# 15 to 19 years                              0.996431               0.985960
# 20 to 24 years                              0.997935               0.982956
# 25 to 34 years                              0.997147               0.977771
# 35 to 44 years                              0.998273               0.982595
# 45 to 54 years                              0.999294               0.985262
# 55 to 59 years                              0.996956               0.987047
# 60 to 64 years                              0.994484               0.986697
# 65 to 74 years                              0.987113               0.983114
# 75 to 84 years                              0.972106               0.971485
# 85 years and over                           0.964929               0.958633
# RACE_Total population                       1.000000               0.987836
# White                                       0.987836               1.000000
# Black or African American                   0.790134               0.784516
# American Indian and Alaska Native           0.446071               0.418181
# Asian                                       0.846644               0.769930
# Native Hawaiian and Other Pacific Islander  0.469451               0.393314
# Total population_HISPANIC OR LATINO         1.000000               0.987836
#
#                                             Black or African American  \
# cases                                       0.512076
# deaths                                      0.437061
# Total Population                            0.790134
# Total population_Male                       0.784252
# Total population_Female                     0.795760
# Under 5 years                               0.776991
# 5 to 9 years                                0.780179
# 10 to 14 years                              0.778248
# 15 to 19 years                              0.790820
# 20 to 24 years                              0.775786
# 25 to 34 years                              0.762398
# 35 to 44 years                              0.779215
# 45 to 54 years                              0.797594
# 55 to 59 years                              0.799235
# 60 to 64 years                              0.801812
# 65 to 74 years                              0.808654
# 75 to 84 years                              0.805217
# 85 years and over                           0.765161
# RACE_Total population                       0.790134
# White                                       0.784516
# Black or African American                   1.000000
# American Indian and Alaska Native           0.156077
# Asian                                       0.470605
# Native Hawaiian and Other Pacific Islander  0.129677
# Total population_HISPANIC OR LATINO         0.790134
#
#                                             American Indian and Alaska Native  \
# cases                                       0.072430
# deaths                                      0.044793
# Total Population                            0.446071
# Total population_Male                       0.450225
# Total population_Female                     0.441946
# Under 5 years                               0.459525
# 5 to 9 years                                0.459685
# 10 to 14 years                              0.462720
# 15 to 19 years                              0.450504
# 20 to 24 years                              0.457376
# 25 to 34 years                              0.464614
# 35 to 44 years                              0.455312
# 45 to 54 years                              0.433112
# 55 to 59 years                              0.420744
# 60 to 64 years                              0.417834
# 65 to 74 years                              0.418794
# 75 to 84 years                              0.403762
# 85 years and over                           0.389465
# RACE_Total population                       0.446071
# White                                       0.418181
# Black or African American                   0.156077
# American Indian and Alaska Native           1.000000
# Asian                                       0.480230
# Native Hawaiian and Other Pacific Islander  0.337475
# Total population_HISPANIC OR LATINO         0.446071
#
#                                                Asian  \
# cases                                       0.399092
# deaths                                      0.321336
# Total Population                            0.846644
# Total population_Male                       0.849893
# Total population_Female                     0.843344
# Under 5 years                               0.843027
# 5 to 9 years                                0.839254
# 10 to 14 years                              0.841328
# 15 to 19 years                              0.836441
# 20 to 24 years                              0.858616
# 25 to 34 years                              0.875567
# 35 to 44 years                              0.858573
# 45 to 54 years                              0.848588
# 55 to 59 years                              0.835490
# 60 to 64 years                              0.825377
# 65 to 74 years                              0.800579
# 75 to 84 years                              0.774788
# 85 years and over                           0.805569
# RACE_Total population                       0.846644
# White                                       0.769930
# Black or African American                   0.470605
# American Indian and Alaska Native           0.480230
# Asian                                       1.000000
# Native Hawaiian and Other Pacific Islander  0.711371
# Total population_HISPANIC OR LATINO         0.846644
#
#                                             Native Hawaiian and Other Pacific Islander  \
# cases                                       0.045184
# deaths                                      0.002666
# Total Population                            0.469451
# Total population_Male                       0.474392
# Total population_Female                     0.464553
# Under 5 years                               0.473724
# 5 to 9 years                                0.471881
# 10 to 14 years                              0.472402
# 15 to 19 years                              0.459347
# 20 to 24 years                              0.480216
# 25 to 34 years                              0.501574
# 35 to 44 years                              0.485899
# 45 to 54 years                              0.465576
# 55 to 59 years                              0.447880
# 60 to 64 years                              0.442252
# 65 to 74 years                              0.431647
# 75 to 84 years                              0.408779
# 85 years and over                           0.432751
# RACE_Total population                       0.469451
# White                                       0.393314
# Black or African American                   0.129677
# American Indian and Alaska Native           0.337475
# Asian                                       0.711371
# Native Hawaiian and Other Pacific Islander  1.000000
# Total population_HISPANIC OR LATINO         0.469451
#
#                                             Total population_HISPANIC OR LATINO
# cases                                       0.474197
# deaths                                      0.381703
# Total Population                            1.000000
# Total population_Male                       0.999922
# Total population_Female                     0.999926
# Under 5 years                               0.994301
# 5 to 9 years                                0.994205
# 10 to 14 years                              0.994159
# 15 to 19 years                              0.996431
# 20 to 24 years                              0.997935
# 25 to 34 years                              0.997147
# 35 to 44 years                              0.998273
# 45 to 54 years                              0.999294
# 55 to 59 years                              0.996956
# 60 to 64 years                              0.994484
# 65 to 74 years                              0.987113
# 75 to 84 years                              0.972106
# 85 years and over                           0.964929
# RACE_Total population                       1.000000
# White                                       0.987836
# Black or African American                   0.790134
# American Indian and Alaska Native           0.446071
# Asian                                       0.846644
# Native Hawaiian and Other Pacific Islander  0.469451
# Total population_HISPANIC OR LATINO         1.000000

# %%
# Make the figsize 15 x 12
plt.figure(figsize=(15,12))

# Plot heatmap of annotated correlations
sns.heatmap(corr *100, annot=True, fmt = '.0f')

#Title
plt.title('COVIDDemographic Correlation Heatmap', fontweight = 'bold', fontsize = 20);

# %% [markdown]
# # Histogram

# %% [markdown]
# # Age

# %%
plt.style.use('seaborn-darkgrid')

df['Under 5 years'].plot(kind = 'hist', color = 'green', edgecolor = 'black', figsize = (10,7))
plt.title('Under 5 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('Under 5 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['5 to 9 years'].plot(kind = 'hist', color = 'blue', edgecolor = 'black', figsize = (10,7))
plt.title('5 to 9 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('5 to 9 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['10 to 14 years'].plot(kind = 'hist', color = 'orange', edgecolor = 'black', figsize = (10,7))
plt.title('10 to 14 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('10 to 14 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['15 to 19 years'].plot(kind = 'hist', color = 'purple', edgecolor = 'black', figsize = (10,7))
plt.title('15 to 19 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('15 to 19 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['20 to 24 years'].plot(kind = 'hist', color = 'green', edgecolor = 'black', figsize = (10,7))
plt.title('20 to 24 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('20 to 24 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['25 to 34 years'].plot(kind = 'hist', color = 'blue', edgecolor = 'black', figsize = (10,7))
plt.title('25 to 34 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('25 to 34 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['35 to 44 years'].plot(kind = 'hist', color = 'orange', edgecolor = 'black', figsize = (10,7))
plt.title('35 to 44 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('35 to 44 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['45 to 54 years'].plot(kind = 'hist', color = 'green', edgecolor = 'black', figsize = (10,7))
plt.title('45 to 54 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('45 to 54 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['55 to 59 years'].plot(kind = 'hist', color = 'blue', edgecolor = 'black', figsize = (10,7))
plt.title('55 to 59 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('55 to 59 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['60 to 64 years'].plot(kind = 'hist', color = 'orange', edgecolor = 'black', figsize = (10,7))
plt.title('60 to 64 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('60 to 64 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['65 to 74 years'].plot(kind = 'hist', color = 'blue', edgecolor = 'black', figsize = (10,7))
plt.title('65 to 74 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('65 to 74 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['75 to 84 years'].plot(kind = 'hist', color = 'purple', edgecolor = 'black', figsize = (10,7))
plt.title('75 to 84 years Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('75 to 84 years', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
plt.style.use('seaborn-darkgrid')

df['85 years and over'].plot(kind = 'hist', color = 'blue', edgecolor = 'black', figsize = (10,7))
plt.title('85 years and over Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('85 years and over', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %% [markdown]
# # Violin Plot

# %%
# Violin plot of White
sns.violinplot(x='White', data=df)
plt.show()

# Violin plot of Black or African American
sns.violinplot(x='Black or African American', data=df)
plt.show()

# Violin plot of American Indian and Alaska Native
sns.violinplot(x='American Indian and Alaska Native', data=df)
plt.show()

# Violin plot of Asian
sns.violinplot(x='Asian', data=df)
plt.show()

# Violin plot of Native Hawaiian and Other Pacific Islander
sns.violinplot(x='Native Hawaiian and Other Pacific Islander', data=df)
plt.show()

# Violin plot of Hispanic or Latino
sns.violinplot(x='Total population_HISPANIC OR LATINO', data=df)
plt.show()

# %% [markdown]
# # RACE VS COVID-19 Case Count

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'White', y = 'cases', data = df, color = 'b', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('White vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('White', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %% [markdown]
# # RACE - Ordinary Least Square Regression(OLS)

# %%
model1 = sm.OLS(df['cases'], df['White']).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.348
# Model:                            OLS   Adj. R-squared (uncentered):              0.335
# Method:                 Least Squares   F-statistic:                              26.64
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):                    4.25e-06
# Time:                        07:42:15   Log-Likelihood:                         -812.08
# No. Observations:                  51   AIC:                                      1626.
# Df Residuals:                      50   BIC:                                      1628.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# White          0.2173      0.042      5.161      0.000       0.133       0.302
# ==============================================================================
# Omnibus:                       87.470   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1651.819
# Skew:                           4.704   Prob(JB):                         0.00
# Kurtosis:                      29.245   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'Black or African American', y = 'cases', data = df, color = 'g', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('Black or African American vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('Black or African American', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
model2 = sm.OLS(df['cases'], df['Black or African American']).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.397
# Model:                            OLS   Adj. R-squared (uncentered):              0.385
# Method:                 Least Squares   F-statistic:                              32.88
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):                    5.65e-07
# Time:                        07:44:09   Log-Likelihood:                         -810.08
# No. Observations:                  51   AIC:                                      1622.
# Df Residuals:                      50   BIC:                                      1624.
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Black or African American     1.2221      0.213      5.734      0.000       0.794       1.650
# ==============================================================================
# Omnibus:                       76.927   Durbin-Watson:                   2.148
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1072.881
# Skew:                           3.962   Prob(JB):                    1.06e-233
# Kurtosis:                      24.026   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'American Indian and Alaska Native', y = 'cases', data = df, color = 'b', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('American Indian and Alaska Native vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('American Indian and Alaska Native', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
model3 = sm.OLS(df['cases'], df['American Indian and Alaska Native']).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.093
# Model:                            OLS   Adj. R-squared (uncentered):              0.075
# Method:                 Least Squares   F-statistic:                              5.114
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):                      0.0281
# Time:                        07:45:52   Log-Likelihood:                         -820.48
# No. Observations:                  51   AIC:                                      1643.
# Df Residuals:                      50   BIC:                                      1645.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# American Indian and Alaska Native     8.0259      3.549      2.261      0.028       0.897      15.154
# ==============================================================================
# Omnibus:                       84.345   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1413.603
# Skew:                           4.500   Prob(JB):                    1.10e-307
# Kurtosis:                      27.171   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'Asian', y = 'cases', data = df, color = 'g', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('Asian vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('Asian', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
model4 = sm.OLS(df['cases'], df['Asian']).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.250
# Model:                            OLS   Adj. R-squared (uncentered):              0.235
# Method:                 Least Squares   F-statistic:                              16.69
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):                    0.000159
# Time:                        07:46:14   Log-Likelihood:                         -815.62
# No. Observations:                  51   AIC:                                      1633.
# Df Residuals:                      50   BIC:                                      1635.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Asian          1.3454      0.329      4.085      0.000       0.684       2.007
# ==============================================================================
# Omnibus:                       76.825   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1248.141
# Skew:                           3.840   Prob(JB):                    9.32e-272
# Kurtosis:                      25.986   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'Native Hawaiian and Other Pacific Islander', y = 'cases', data = df, color = 'b', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('Native Hawaiian and Other Pacific Islander vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('Native Hawaiian and Other Pacific Islander', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
model5 = sm.OLS(df['cases'], df['Native Hawaiian and Other Pacific Islander']).fit()
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.041
# Model:                            OLS   Adj. R-squared (uncentered):              0.022
# Method:                 Least Squares   F-statistic:                              2.149
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):                       0.149
# Time:                        07:46:45   Log-Likelihood:                         -821.89
# No. Observations:                  51   AIC:                                      1646.
# Df Residuals:                      50   BIC:                                      1648.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Native Hawaiian and Other Pacific Islander    15.7219     10.726      1.466      0.149      -5.822      37.265
# ==============================================================================
# Omnibus:                       89.421   Durbin-Watson:                   1.836
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1743.121
# Skew:                           4.870   Prob(JB):                         0.00
# Kurtosis:                      29.934   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'Total population_HISPANIC OR LATINO', y = 'cases', data = df, color = 'g', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('Total population_HISPANIC OR LATINO vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('Total population_HISPANIC OR LATINO', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
model6 = sm.OLS(df['cases'], df['Total population_HISPANIC OR LATINO']).fit()
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.366
# Model:                            OLS   Adj. R-squared (uncentered):              0.353
# Method:                 Least Squares   F-statistic:                              28.84
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):                    2.05e-06
# Time:                        07:47:13   Log-Likelihood:                         -811.35
# No. Observations:                  51   AIC:                                      1625.
# Df Residuals:                      50   BIC:                                      1627.
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Total population_HISPANIC OR LATINO     0.1537      0.029      5.370      0.000       0.096       0.211
# ==============================================================================
# Omnibus:                       84.397   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1486.407
# Skew:                           4.465   Prob(JB):                         0.00
# Kurtosis:                      27.895   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # ALL RACES - Ordinary Least Square Regression(OLS)

# %%
model7 = sm.OLS(df['cases'], df[['White', 'Black or African American', 'American Indian and Alaska Native',
                                       'Asian', 'Native Hawaiian and Other Pacific Islander',
                                       'Total population_HISPANIC OR LATINO']]).fit()
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.490
# Model:                            OLS   Adj. R-squared (uncentered):              0.421
# Method:                 Least Squares   F-statistic:                              7.192
# Date:                Tue, 02 Jun 2020   Prob (F-statistic):                    2.03e-05
# Time:                        07:51:49   Log-Likelihood:                         -805.82
# No. Observations:                  51   AIC:                                      1624.
# Df Residuals:                      45   BIC:                                      1635.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# White                                          4.1227      2.735      1.507      0.139      -1.387       9.632
# Black or African American                      5.1157      2.709      1.888      0.065      -0.341      10.573
# American Indian and Alaska Native              6.1073      6.192      0.986      0.329      -6.365      18.579
# Asian                                         10.1958      5.828      1.750      0.087      -1.542      21.933
# Native Hawaiian and Other Pacific Islander   -23.9235     12.942     -1.848      0.071     -49.990       2.143
# Total population_HISPANIC OR LATINO           -4.0643      2.669     -1.523      0.135      -9.440       1.312
# ==============================================================================
# Omnibus:                       75.243   Durbin-Watson:                   2.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1056.345
# Skew:                           3.810   Prob(JB):                    4.15e-230
# Kurtosis:                      23.953   Cond. No.                         588.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # RACE VS COVID-19 Case Per State

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['White'], cmap = 'inferno')
plt.title('White vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['White'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['Black or African American'], cmap = 'inferno')
plt.title('Black or African American  vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Black or African American'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['Asian'], cmap = 'inferno')
plt.title('Asian vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Asian'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['American Indian and Alaska Native'], cmap = 'inferno')
plt.title('American Indian and Alaska Native vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['American Indian and Alaska Native'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['Native Hawaiian and Other Pacific Islander'], cmap = 'inferno')
plt.title('Native Hawaiian and Other Pacific Islander vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Native Hawaiian and Other Pacific Islander'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['Total population_HISPANIC OR LATINO'], cmap = 'inferno')
plt.title('Total population_HISPANIC OR LATINO vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Total population_HISPANIC OR LATINO'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %% [markdown]
# # RACE - R SQUARE VALUE

# %%
X = df[['White']]

y = df[['cases']]

train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

DemographicModel = LinearRegression()
DemographicModel.fit(train_X, train_y)

predictions = DemographicModel.predict(test_X)

MAE = mean_absolute_error(test_y, predictions)
MSE = mean_squared_error(test_y, predictions)
RMS = sqrt(mean_squared_error(test_y, predictions))
R2Score = r2_score(test_y, predictions)

print('MAE Value:', MAE)
print('MSE Value:', MSE)
print('RMS Value:', RMS)
print('R2 Score:', R2Score)
# Out:
# MAE Value: 1379167.1669855262
# MSE Value: 13676008328510.44
# RMS Value: 3698108.7502276674
# R2 Score: 0.10902786421530852

# %%
X = df[['Black or African American']]

y = df[['cases']]

train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

DemographicModel = LinearRegression()
DemographicModel.fit(train_X, train_y)

predictions = DemographicModel.predict(test_X)

MAE = mean_absolute_error(test_y, predictions)
MSE = mean_squared_error(test_y, predictions)
RMS = sqrt(mean_squared_error(test_y, predictions))
R2Score = r2_score(test_y, predictions)

print('MAE Value:', MAE)
print('MSE Value:', MSE)
print('RMS Value:', RMS)
print('R2 Score:', R2Score)
# Out:
# MAE Value: 1460935.043589438
# MSE Value: 13089572280495.25
# RMS Value: 3617951.3927767533
# R2 Score: 0.14723332341439166

# %%
X = df[['American Indian and Alaska Native']]

y = df[['cases']]

train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

DemographicModel = LinearRegression()
DemographicModel.fit(train_X, train_y)

predictions = DemographicModel.predict(test_X)

MAE = mean_absolute_error(test_y, predictions)
MSE = mean_squared_error(test_y, predictions)
RMS = sqrt(mean_squared_error(test_y, predictions))
R2Score = r2_score(test_y, predictions)

print('MAE Value:', MAE)
print('MSE Value:', MSE)
print('RMS Value:', RMS)
print('R2 Score:', R2Score)
# Out:
# MAE Value: 1807805.3079768787
# MSE Value: 16545232876786.012
# RMS Value: 4067583.173923554
# R2 Score: -0.07789795963737345

# %%
X = df[['Asian']]

y = df[['cases']]

train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

DemographicModel = LinearRegression()
DemographicModel.fit(train_X, train_y)

predictions = DemographicModel.predict(test_X)

MAE = mean_absolute_error(test_y, predictions)
MSE = mean_squared_error(test_y, predictions)
RMS = sqrt(mean_squared_error(test_y, predictions))
R2Score = r2_score(test_y, predictions)

print('MAE Value:', MAE)
print('MSE Value:', MSE)
print('RMS Value:', RMS)
print('R2 Score:', R2Score)
# Out:
# MAE Value: 2126545.05780754
# MSE Value: 20171305518880.758
# RMS Value: 4491247.657264154
# R2 Score: -0.3141313406673103

# %%
X = df[['Native Hawaiian and Other Pacific Islander']]

y = df[['cases']]

train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

DemographicModel = LinearRegression()
DemographicModel.fit(train_X, train_y)

predictions = DemographicModel.predict(test_X)

MAE = mean_absolute_error(test_y, predictions)
MSE = mean_squared_error(test_y, predictions)
RMS = sqrt(mean_squared_error(test_y, predictions))
R2Score = r2_score(test_y, predictions)

print('MAE Value:', MAE)
print('MSE Value:', MSE)
print('RMS Value:', RMS)
print('R2 Score:', R2Score)
# Out:
# MAE Value: 1785872.2208383007
# MSE Value: 16211764873104.146
# RMS Value: 4026383.5973618
# R2 Score: -0.05617300215567167

# %%
X = df[['Total population_HISPANIC OR LATINO']]

y = df[['cases']]

train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

DemographicModel = LinearRegression()
DemographicModel.fit(train_X, train_y)

predictions = DemographicModel.predict(test_X)

MAE = mean_absolute_error(test_y, predictions)
MSE = mean_squared_error(test_y, predictions)
RMS = sqrt(mean_squared_error(test_y, predictions))
R2Score = r2_score(test_y, predictions)

print('MAE Value:', MAE)
print('MSE Value:', MSE)
print('RMS Value:', RMS)
print('R2 Score:', R2Score)
# Out:
# MAE Value: 1406224.2094874745
# MSE Value: 13109076182392.95
# RMS Value: 3620645.8239370706
# R2 Score: 0.14596267245305072

# %% [markdown]
# # RACE - MULTILINEAR REGRESSION

# %%
X = df[['White','Black or African American','American Indian and Alaska Native','Asian','Native Hawaiian and Other Pacific Islander','Total population_HISPANIC OR LATINO']]

y = df[['cases']]

train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

DemographicModel = LinearRegression()
DemographicModel.fit(train_X, train_y)

predictions = DemographicModel.predict(test_X)

MAE = mean_absolute_error(test_y, predictions)
MSE = mean_squared_error(test_y, predictions)
RMS = sqrt(mean_squared_error(test_y, predictions))
R2Score = r2_score(test_y, predictions)

print('MAE Value:', MAE)
print('MSE Value:', MSE)
print('RMS Value:', RMS)
print('R2 Score:', R2Score)
# Out:
# MAE Value: 2004888.685658403
# MSE Value: 17162930920898.055
# RMS Value: 4142816.78582315
# R2 Score: -0.11814009260574942
