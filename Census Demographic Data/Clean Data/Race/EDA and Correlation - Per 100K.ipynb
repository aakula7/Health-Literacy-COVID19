# %% [markdown]
# # Import libraries

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
from scipy.stats import spearmanr
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams
from matplotlib.backends.backend_agg import FigureCanvasAgg

plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # Load the Dataset

# %%
df = pd.read_csv('COVIDdemographic.csv')
df.head()
# Out:
#         State    cases  deaths  Total Population  Total population_Male  \
# 0     Alabama   387786   14345           4887871                2369271
# 1      Alaska    18316     367            737438                 382952
# 2     Arizona   426614   18857           7171646                3565129
# 3    Arkansas   161569    3301           3013825                1476680
# 4  California  2664110  102387          39557045               19673553
#
#    Total population_Female  Under 5 years  5 to 9 years  10 to 14 years  \
# 0                  2518600         288589        290369          321430
# 1                   354486          52173         52544           49747
# 2                  3606517         434032        441613          488738
# 3                  1537145         188092        192523          203502
# 4                 19883492        2428493       2398894         2646096
#
#    15 to 19 years  ...  65 to 74 years  75 to 84 years  85 years and over  \
# 0          332209  ...          493396          251025              85242
# 1           48514  ...           59630           21000               7370
# 2          477306  ...          727956          398408             132739
# 3          208021  ...          296808          154699              56169
# 4         2557470  ...         3286461         1651296             729580
#
#    RACE_Total population     White  Black or African American  \
# 0                4887871   3306838                    1307040
# 1                 737438    474555                      25197
# 2                7171646   5590505                     336340
# 3                3013825   2306096                     456714
# 4               39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  \
# 0                                        1797
# 1                                        7958
# 2                                       15661
# 3                                        9398
# 4                                      155739
#
#    Total population_HISPANIC OR LATINO
# 0                              4887871
# 1                               737438
# 2                              7171646
# 3                              3013825
# 4                             39557045
#
# [5 rows x 26 columns]

# %%
list(df.columns)
# Out:
# ['State',
#  'cases',
#  'deaths',
#  'Total Population',
#  'Total population_Male',
#  'Total population_Female',
#  'Under 5 years',
#  '5 to 9 years',
#  '10 to 14 years',
#  '15 to 19 years',
#  '20 to 24 years',
#  '25 to 34 years',
#  '35 to 44 years',
#  '45 to 54 years',
#  '55 to 59 years',
#  '60 to 64 years',
#  '65 to 74 years',
#  '75 to 84 years',
#  '85 years and over',
#  'RACE_Total population',
#  'White',
#  'Black or African American',
#  'American Indian and Alaska Native',
#  'Asian',
#  'Native Hawaiian and Other Pacific Islander',
#  'Total population_HISPANIC OR LATINO']

# %%
df = df.rename(columns = {'Total population_HISPANIC OR LATINO':'Hispanic or Latino'})
df.head()
# Out:
#         State    cases  deaths  Total Population  Total population_Male  \
# 0     Alabama   387786   14345           4887871                2369271
# 1      Alaska    18316     367            737438                 382952
# 2     Arizona   426614   18857           7171646                3565129
# 3    Arkansas   161569    3301           3013825                1476680
# 4  California  2664110  102387          39557045               19673553
#
#    Total population_Female  Under 5 years  5 to 9 years  10 to 14 years  \
# 0                  2518600         288589        290369          321430
# 1                   354486          52173         52544           49747
# 2                  3606517         434032        441613          488738
# 3                  1537145         188092        192523          203502
# 4                 19883492        2428493       2398894         2646096
#
#    15 to 19 years  ...  65 to 74 years  75 to 84 years  85 years and over  \
# 0          332209  ...          493396          251025              85242
# 1           48514  ...           59630           21000               7370
# 2          477306  ...          727956          398408             132739
# 3          208021  ...          296808          154699              56169
# 4         2557470  ...         3286461         1651296             729580
#
#    RACE_Total population     White  Black or African American  \
# 0                4887871   3306838                    1307040
# 1                 737438    474555                      25197
# 2                7171646   5590505                     336340
# 3                3013825   2306096                     456714
# 4               39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino
# 0                                        1797             4887871
# 1                                        7958              737438
# 2                                       15661             7171646
# 3                                        9398             3013825
# 4                                      155739            39557045
#
# [5 rows x 26 columns]

# %%
list(df.columns)
# Out:
# ['State',
#  'cases',
#  'deaths',
#  'Total Population',
#  'Total population_Male',
#  'Total population_Female',
#  'Under 5 years',
#  '5 to 9 years',
#  '10 to 14 years',
#  '15 to 19 years',
#  '20 to 24 years',
#  '25 to 34 years',
#  '35 to 44 years',
#  '45 to 54 years',
#  '55 to 59 years',
#  '60 to 64 years',
#  '65 to 74 years',
#  '75 to 84 years',
#  '85 years and over',
#  'RACE_Total population',
#  'White',
#  'Black or African American',
#  'American Indian and Alaska Native',
#  'Asian',
#  'Native Hawaiian and Other Pacific Islander',
#  'Hispanic or Latino']

# %%
df['Hispanic or Latino'] = (df['Total Population'])-(df['White'] + df['Black or African American'] + 
                                                     df['American Indian and Alaska Native'] + df['Asian'] + 
                                                     df['Native Hawaiian and Other Pacific Islander'])

df.head()
# Out:
#         State    cases  deaths  Total Population  Total population_Male  \
# 0     Alabama   387786   14345           4887871                2369271
# 1      Alaska    18316     367            737438                 382952
# 2     Arizona   426614   18857           7171646                3565129
# 3    Arkansas   161569    3301           3013825                1476680
# 4  California  2664110  102387          39557045               19673553
#
#    Total population_Female  Under 5 years  5 to 9 years  10 to 14 years  \
# 0                  2518600         288589        290369          321430
# 1                   354486          52173         52544           49747
# 2                  3606517         434032        441613          488738
# 3                  1537145         188092        192523          203502
# 4                 19883492        2428493       2398894         2646096
#
#    15 to 19 years  ...  65 to 74 years  75 to 84 years  85 years and over  \
# 0          332209  ...          493396          251025              85242
# 1           48514  ...           59630           21000               7370
# 2          477306  ...          727956          398408             132739
# 3          208021  ...          296808          154699              56169
# 4         2557470  ...         3286461         1651296             729580
#
#    RACE_Total population     White  Black or African American  \
# 0                4887871   3306838                    1307040
# 1                 737438    474555                      25197
# 2                7171646   5590505                     336340
# 3                3013825   2306096                     456714
# 4               39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino
# 0                                        1797              185038
# 1                                        7958               71976
# 2                                       15661              660668
# 3                                        9398              173118
# 4                                      155739             7457691
#
# [5 rows x 26 columns]

# %%
df = df[['State', 'cases', 'deaths', 'Total Population', 'White', 'Black or African American', 
         'American Indian and Alaska Native', 'Asian', 'Native Hawaiian and Other Pacific Islander', 
         'Hispanic or Latino']]

df.head()
# Out:
#         State    cases  deaths  Total Population     White  \
# 0     Alabama   387786   14345           4887871   3306838
# 1      Alaska    18316     367            737438    474555
# 2     Arizona   426614   18857           7171646   5590505
# 3    Arkansas   161569    3301           3013825   2306096
# 4  California  2664110  102387          39557045  23535388
#
#    Black or African American  American Indian and Alaska Native    Asian  \
# 0                    1307040                              22063    65095
# 1                      25197                             111371    46381
# 2                     336340                             330599   237873
# 3                     456714                              20951    47548
# 4                    2283850                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino
# 0                                        1797              185038
# 1                                        7958               71976
# 2                                       15661              660668
# 3                                        9398              173118
# 4                                      155739             7457691

# %%
df = df.drop(columns = ['cases', 'deaths'])
df.head()
# Out:
#         State  Total Population     White  Black or African American  \
# 0     Alabama           4887871   3306838                    1307040
# 1      Alaska            737438    474555                      25197
# 2     Arizona           7171646   5590505                     336340
# 3    Arkansas           3013825   2306096                     456714
# 4  California          39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino
# 0                                        1797              185038
# 1                                        7958               71976
# 2                                       15661              660668
# 3                                        9398              173118
# 4                                      155739             7457691

# %%
COVID_Case = pd.read_csv('COVID.csv', index_col = 0)
COVID_Case.head()
# Out:
#         State   cases  deaths
# 0     Alabama   26912     785
# 1      Alaska     751      10
# 2     Arizona   39298    1228
# 3    Arkansas   13191     188
# 4  California  159098    5202

# %%
df = pd.merge(df, COVID_Case, how = 'left', on = 'State')
df.head()
# Out:
#         State  Total Population     White  Black or African American  \
# 0     Alabama           4887871   3306838                    1307040
# 1      Alaska            737438    474555                      25197
# 2     Arizona           7171646   5590505                     336340
# 3    Arkansas           3013825   2306096                     456714
# 4  California          39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino   cases  \
# 0                                        1797              185038   26912
# 1                                        7958               71976     751
# 2                                       15661              660668   39298
# 3                                        9398              173118   13191
# 4                                      155739             7457691  159098
#
#    deaths
# 0     785
# 1      10
# 2    1228
# 3     188
# 4    5202

# %%
columns = ['White', 'Black or African American', 'American Indian and Alaska Native', 'Asian', 
           'Native Hawaiian and Other Pacific Islander', 'Hispanic or Latino']

for c in columns:
    df['{}_Prop_100K'.format(c)] = (df['cases']/df[c])
    
df.head()
# Out:
#         State  Total Population     White  Black or African American  \
# 0     Alabama           4887871   3306838                    1307040
# 1      Alaska            737438    474555                      25197
# 2     Arizona           7171646   5590505                     336340
# 3    Arkansas           3013825   2306096                     456714
# 4  California          39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino   cases  \
# 0                                        1797              185038   26912
# 1                                        7958               71976     751
# 2                                       15661              660668   39298
# 3                                        9398              173118   13191
# 4                                      155739             7457691  159098
#
#    deaths  White_Prop_100K  Black or African American_Prop_100K  \
# 0     785         0.008138                             0.020590
# 1      10         0.001583                             0.029805
# 2    1228         0.007029                             0.116840
# 3     188         0.005720                             0.028882
# 4    5202         0.006760                             0.069662
#
#    American Indian and Alaska Native_Prop_100K  Asian_Prop_100K  \
# 0                                     1.219780         0.413427
# 1                                     0.006743         0.016192
# 2                                     0.118869         0.165206
# 3                                     0.629612         0.277425
# 4                                     0.525437         0.027329
#
#    Native Hawaiian and Other Pacific Islander_Prop_100K  \
# 0                                          14.976071
# 1                                           0.094370
# 2                                           2.509291
# 3                                           1.403597
# 4                                           1.021568
#
#    Hispanic or Latino_Prop_100K
# 0                      0.145440
# 1                      0.010434
# 2                      0.059482
# 3                      0.076197
# 4                      0.021333

# %%
columns_keep = ['State', 'Total Population', 'cases', 'deaths']

df_columns = list(df.columns)

for c in df_columns:
    if '_Prop_100K' in c:
        columns_keep.append(c)
    
df = df[columns_keep]
df.head()
# Out:
#         State  Total Population   cases  deaths  White_Prop_100K  \
# 0     Alabama           4887871   26912     785       813.828800
# 1      Alaska            737438     751      10       158.253522
# 2     Arizona           7171646   39298    1228       702.941863
# 3    Arkansas           3013825   13191     188       572.005675
# 4  California          39557045  159098    5202       675.994804
#
#    Black or African American_Prop_100K  \
# 0                          2059.003550
# 1                          2980.513553
# 2                         11684.010228
# 3                          2888.240781
# 4                          6966.219323
#
#    American Indian and Alaska Native_Prop_100K  Asian_Prop_100K  \
# 0                                121977.972171     41342.653046
# 1                                   674.322759      1619.197516
# 2                                 11886.908309     16520.580310
# 3                                 62961.195170     27742.491798
# 4                                 52543.660334      2732.898343
#
#    Native Hawaiian and Other Pacific Islander_Prop_100K  \
# 0                                       1.497607e+06
# 1                                       9.437044e+03
# 2                                       2.509291e+05
# 3                                       1.403597e+05
# 4                                       1.021568e+05
#
#    Hispanic or Latino_Prop_100K
# 0                  14544.039603
# 1                   1043.403357
# 2                   5948.222102
# 3                   7619.658268
# 4                   2133.341271

# %%
df.shape
# Out:
# (51, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   State                                                 51 non-null     object
#  1   Total Population                                      51 non-null     int64
#  2   cases                                                 51 non-null     int64
#  3   deaths                                                51 non-null     int64
#  4   White_Prop_100K                                       51 non-null     float64
#  5   Black or African American_Prop_100K                   51 non-null     float64
#  6   American Indian and Alaska Native_Prop_100K           51 non-null     float64
#  7   Asian_Prop_100K                                       51 non-null     float64
#  8   Native Hawaiian and Other Pacific Islander_Prop_100K  51 non-null     float64
#  9   Hispanic or Latino_Prop_100K                          51 non-null     float64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 4.4+ KB

# %%
df.isnull().sum()
# Out:
# State                                                   0
# Total Population                                        0
# cases                                                   0
# deaths                                                  0
# White_Prop_100K                                         0
# Black or African American_Prop_100K                     0
# American Indian and Alaska Native_Prop_100K             0
# Asian_Prop_100K                                         0
# Native Hawaiian and Other Pacific Islander_Prop_100K    0
# Hispanic or Latino_Prop_100K                            0
# dtype: int64

# %%
df.describe()
# Out:
#        Total Population          cases        deaths  White_Prop_100K  \
# count      5.100000e+01      51.000000     51.000000        51.000000
# mean       6.415048e+06   41994.235294   2290.549020       854.654623
# std        7.343308e+06   63513.183767   4748.588326       745.313086
# min        5.777370e+05     614.000000     10.000000        65.219377
# 25%        1.780020e+06    9231.500000    212.000000       435.671055
# 50%        4.468402e+06   20152.000000    704.000000       614.255563
# 75%        7.353618e+06   46961.500000   2469.500000       941.590414
# max        3.955704e+07  389349.000000  30683.000000      3308.542294
#
#        Black or African American_Prop_100K  \
# count                            51.000000
# mean                           9874.293289
# std                            9000.797427
# min                            1476.803691
# 25%                            2992.794318
# 50%                            6556.018811
# 75%                           13272.632645
# max                           37351.666047
#
#        American Indian and Alaska Native_Prop_100K  Asian_Prop_100K  \
# count                                    51.000000        51.000000
# mean                                 157625.929949     20494.195347
# std                                  183520.555105     14457.048344
# min                                     674.322759       136.207409
# 25%                                   30812.590145     13010.695296
# 50%                                   84445.758702     17974.877256
# 75%                                  198733.416491     26611.159240
# max                                  792324.073636     77086.680438
#
#        Native Hawaiian and Other Pacific Islander_Prop_100K  \
# count                                       5.100000e+01
# mean                                        1.308910e+06
# std                                         1.971157e+06
# min                                         5.021694e+02
# 25%                                         2.400888e+05
# 50%                                         6.237910e+05
# 75%                                         1.395031e+06
# max                                         1.169804e+07
#
#        Hispanic or Latino_Prop_100K
# count                     51.000000
# mean                   10471.278010
# std                     6926.911532
# min                      200.095100
# 25%                     5631.328687
# 50%                     8928.153970
# 75%                    14433.941229
# max                    28060.395162

# %% [markdown]
# ## Pearson Correlation

# %%
Pcorr = df.corr(method = 'pearson')
Pcorr
# Out:
#                                                     Total Population  \
# Total Population                                            1.000000
# cases                                                       0.661893
# deaths                                                      0.452008
# White_Prop_100K                                             0.108422
# Black or African American_Prop_100K                        -0.279138
# American Indian and Alaska Native_Prop_100K                 0.121299
# Asian_Prop_100K                                            -0.257357
# Native Hawaiian and Other Pacific Islander_Prop...         -0.032529
# Hispanic or Latino_Prop_100K                               -0.137507
#
#                                                        cases    deaths  \
# Total Population                                    0.661893  0.452008
# cases                                               1.000000  0.957358
# deaths                                              0.957358  1.000000
# White_Prop_100K                                     0.590200  0.631897
# Black or African American_Prop_100K                -0.073325 -0.007285
# American Indian and Alaska Native_Prop_100K         0.533905  0.575073
# Asian_Prop_100K                                    -0.034221  0.021962
# Native Hawaiian and Other Pacific Islander_Prop...  0.307375  0.370051
# Hispanic or Latino_Prop_100K                        0.210200  0.272090
#
#                                                     White_Prop_100K  \
# Total Population                                           0.108422
# cases                                                      0.590200
# deaths                                                     0.631897
# White_Prop_100K                                            1.000000
# Black or African American_Prop_100K                       -0.000648
# American Indian and Alaska Native_Prop_100K                0.848494
# Asian_Prop_100K                                            0.420010
# Native Hawaiian and Other Pacific Islander_Prop...         0.522546
# Hispanic or Latino_Prop_100K                               0.645985
#
#                                                     Black or African American_Prop_100K  \
# Total Population                                                              -0.279138
# cases                                                                         -0.073325
# deaths                                                                        -0.007285
# White_Prop_100K                                                               -0.000648
# Black or African American_Prop_100K                                            1.000000
# American Indian and Alaska Native_Prop_100K                                   -0.024954
# Asian_Prop_100K                                                                0.094624
# Native Hawaiian and Other Pacific Islander_Prop...                             0.281074
# Hispanic or Latino_Prop_100K                                                   0.080596
#
#                                                     American Indian and Alaska Native_Prop_100K  \
# Total Population                                                                       0.121299
# cases                                                                                  0.533905
# deaths                                                                                 0.575073
# White_Prop_100K                                                                        0.848494
# Black or African American_Prop_100K                                                   -0.024954
# American Indian and Alaska Native_Prop_100K                                            1.000000
# Asian_Prop_100K                                                                        0.251273
# Native Hawaiian and Other Pacific Islander_Prop...                                     0.452327
# Hispanic or Latino_Prop_100K                                                           0.570528
#
#                                                     Asian_Prop_100K  \
# Total Population                                          -0.257357
# cases                                                     -0.034221
# deaths                                                     0.021962
# White_Prop_100K                                            0.420010
# Black or African American_Prop_100K                        0.094624
# American Indian and Alaska Native_Prop_100K                0.251273
# Asian_Prop_100K                                            1.000000
# Native Hawaiian and Other Pacific Islander_Prop...         0.423164
# Hispanic or Latino_Prop_100K                               0.799993
#
#                                                     Native Hawaiian and Other Pacific Islander_Prop_100K  \
# Total Population                                                                            -0.032529
# cases                                                                                        0.307375
# deaths                                                                                       0.370051
# White_Prop_100K                                                                              0.522546
# Black or African American_Prop_100K                                                          0.281074
# American Indian and Alaska Native_Prop_100K                                                  0.452327
# Asian_Prop_100K                                                                              0.423164
# Native Hawaiian and Other Pacific Islander_Prop...                                           1.000000
# Hispanic or Latino_Prop_100K                                                                 0.601481
#
#                                                     Hispanic or Latino_Prop_100K
# Total Population                                                       -0.137507
# cases                                                                   0.210200
# deaths                                                                  0.272090
# White_Prop_100K                                                         0.645985
# Black or African American_Prop_100K                                     0.080596
# American Indian and Alaska Native_Prop_100K                             0.570528
# Asian_Prop_100K                                                         0.799993
# Native Hawaiian and Other Pacific Islander_Prop...                      0.601481
# Hispanic or Latino_Prop_100K                                            1.000000

# %%
plt.figure(figsize = (20,10))
sns.heatmap(Pcorr, cmap = 'BrBG', annot = True, linewidths = 0.5)
plt.title('State Race Demographic and COVID-19 Pearson Correlation Heatmap', fontweight = 'bold', fontsize = 24);

# %% [markdown]
# ## Kendall Correlation

# %%
Kcorr = df.corr(method = 'kendall')
Kcorr
# Out:
#                                                     Total Population  \
# Total Population                                            1.000000
# cases                                                       0.716078
# deaths                                                      0.646528
# White_Prop_100K                                             0.226667
# Black or African American_Prop_100K                        -0.231373
# American Indian and Alaska Native_Prop_100K                 0.265882
# Asian_Prop_100K                                            -0.143529
# Native Hawaiian and Other Pacific Islander_Prop...          0.090196
# Hispanic or Latino_Prop_100K                                0.044706
#
#                                                        cases    deaths  \
# Total Population                                    0.716078  0.646528
# cases                                               1.000000  0.823853
# deaths                                              0.823853  1.000000
# White_Prop_100K                                     0.494902  0.503727
# Black or African American_Prop_100K                -0.132549 -0.114555
# American Indian and Alaska Native_Prop_100K         0.455686  0.505296
# Asian_Prop_100K                                     0.087059  0.111416
# Native Hawaiian and Other Pacific Islander_Prop...  0.323922  0.382895
# Hispanic or Latino_Prop_100K                        0.287843  0.309141
#
#                                                     White_Prop_100K  \
# Total Population                                           0.226667
# cases                                                      0.494902
# deaths                                                     0.503727
# White_Prop_100K                                            1.000000
# Black or African American_Prop_100K                        0.008627
# American Indian and Alaska Native_Prop_100K                0.537255
# Asian_Prop_100K                                            0.419608
# Native Hawaiian and Other Pacific Islander_Prop...         0.530980
# Hispanic or Latino_Prop_100K                               0.567059
#
#                                                     Black or African American_Prop_100K  \
# Total Population                                                              -0.231373
# cases                                                                         -0.132549
# deaths                                                                        -0.114555
# White_Prop_100K                                                                0.008627
# Black or African American_Prop_100K                                            1.000000
# American Indian and Alaska Native_Prop_100K                                   -0.074510
# Asian_Prop_100K                                                                0.109020
# Native Hawaiian and Other Pacific Islander_Prop...                             0.082353
# Hispanic or Latino_Prop_100K                                                   0.065098
#
#                                                     American Indian and Alaska Native_Prop_100K  \
# Total Population                                                                       0.265882
# cases                                                                                  0.455686
# deaths                                                                                 0.505296
# White_Prop_100K                                                                        0.537255
# Black or African American_Prop_100K                                                   -0.074510
# American Indian and Alaska Native_Prop_100K                                            1.000000
# Asian_Prop_100K                                                                        0.308235
# Native Hawaiian and Other Pacific Islander_Prop...                                     0.548235
# Hispanic or Latino_Prop_100K                                                           0.562353
#
#                                                     Asian_Prop_100K  \
# Total Population                                          -0.143529
# cases                                                      0.087059
# deaths                                                     0.111416
# White_Prop_100K                                            0.419608
# Black or African American_Prop_100K                        0.109020
# American Indian and Alaska Native_Prop_100K                0.308235
# Asian_Prop_100K                                            1.000000
# Native Hawaiian and Other Pacific Islander_Prop...         0.474510
# Hispanic or Latino_Prop_100K                               0.585882
#
#                                                     Native Hawaiian and Other Pacific Islander_Prop_100K  \
# Total Population                                                                             0.090196
# cases                                                                                        0.323922
# deaths                                                                                       0.382895
# White_Prop_100K                                                                              0.530980
# Black or African American_Prop_100K                                                          0.082353
# American Indian and Alaska Native_Prop_100K                                                  0.548235
# Asian_Prop_100K                                                                              0.474510
# Native Hawaiian and Other Pacific Islander_Prop...                                           1.000000
# Hispanic or Latino_Prop_100K                                                                 0.709804
#
#                                                     Hispanic or Latino_Prop_100K
# Total Population                                                        0.044706
# cases                                                                   0.287843
# deaths                                                                  0.309141
# White_Prop_100K                                                         0.567059
# Black or African American_Prop_100K                                     0.065098
# American Indian and Alaska Native_Prop_100K                             0.562353
# Asian_Prop_100K                                                         0.585882
# Native Hawaiian and Other Pacific Islander_Prop...                      0.709804
# Hispanic or Latino_Prop_100K                                            1.000000

# %%
plt.figure(figsize = (20,10))
sns.heatmap(Kcorr, cmap = 'BrBG', annot = True, linewidths = 0.5)
plt.title('State Race Demographic and COVID-19 Kendall Correlation Heatmap', fontweight = 'bold', fontsize = 24);

# %% [markdown]
# ## Spearman Correlation

# %%
Scorr = df.corr(method = 'spearman')
Scorr
# Out:
#                                                     Total Population  \
# Total Population                                            1.000000
# cases                                                       0.896018
# deaths                                                      0.837621
# White_Prop_100K                                             0.312851
# Black or African American_Prop_100K                        -0.347873
# American Indian and Alaska Native_Prop_100K                 0.372308
# Asian_Prop_100K                                            -0.186244
# Native Hawaiian and Other Pacific Islander_Prop...          0.139548
# Hispanic or Latino_Prop_100K                                0.048416
#
#                                                        cases    deaths  \
# Total Population                                    0.896018  0.837621
# cases                                               1.000000  0.953189
# deaths                                              0.953189  1.000000
# White_Prop_100K                                     0.659367  0.673545
# Black or African American_Prop_100K                -0.207240 -0.184393
# American Indian and Alaska Native_Prop_100K         0.627330  0.676350
# Asian_Prop_100K                                     0.118190  0.134211
# Native Hawaiian and Other Pacific Islander_Prop...  0.453756  0.517252
# Hispanic or Latino_Prop_100K                        0.390407  0.429421
#
#                                                     White_Prop_100K  \
# Total Population                                           0.312851
# cases                                                      0.659367
# deaths                                                     0.673545
# White_Prop_100K                                            1.000000
# Black or African American_Prop_100K                        0.031403
# American Indian and Alaska Native_Prop_100K                0.724344
# Asian_Prop_100K                                            0.593665
# Native Hawaiian and Other Pacific Islander_Prop...         0.721176
# Hispanic or Latino_Prop_100K                               0.776652
#
#                                                     Black or African American_Prop_100K  \
# Total Population                                                              -0.347873
# cases                                                                         -0.207240
# deaths                                                                        -0.184393
# White_Prop_100K                                                                0.031403
# Black or African American_Prop_100K                                            1.000000
# American Indian and Alaska Native_Prop_100K                                   -0.121538
# Asian_Prop_100K                                                                0.140814
# Native Hawaiian and Other Pacific Islander_Prop...                             0.116561
# Hispanic or Latino_Prop_100K                                                   0.078190
#
#                                                     American Indian and Alaska Native_Prop_100K  \
# Total Population                                                                       0.372308
# cases                                                                                  0.627330
# deaths                                                                                 0.676350
# White_Prop_100K                                                                        0.724344
# Black or African American_Prop_100K                                                   -0.121538
# American Indian and Alaska Native_Prop_100K                                            1.000000
# Asian_Prop_100K                                                                        0.451041
# Native Hawaiian and Other Pacific Islander_Prop...                                     0.703348
# Hispanic or Latino_Prop_100K                                                           0.737376
#
#                                                     Asian_Prop_100K  \
# Total Population                                          -0.186244
# cases                                                      0.118190
# deaths                                                     0.134211
# White_Prop_100K                                            0.593665
# Black or African American_Prop_100K                        0.140814
# American Indian and Alaska Native_Prop_100K                0.451041
# Asian_Prop_100K                                            1.000000
# Native Hawaiian and Other Pacific Islander_Prop...         0.642353
# Hispanic or Latino_Prop_100K                               0.775113
#
#                                                     Native Hawaiian and Other Pacific Islander_Prop_100K  \
# Total Population                                                                             0.139548
# cases                                                                                        0.453756
# deaths                                                                                       0.517252
# White_Prop_100K                                                                              0.721176
# Black or African American_Prop_100K                                                          0.116561
# American Indian and Alaska Native_Prop_100K                                                  0.703348
# Asian_Prop_100K                                                                              0.642353
# Native Hawaiian and Other Pacific Islander_Prop...                                           1.000000
# Hispanic or Latino_Prop_100K                                                                 0.889774
#
#                                                     Hispanic or Latino_Prop_100K
# Total Population                                                        0.048416
# cases                                                                   0.390407
# deaths                                                                  0.429421
# White_Prop_100K                                                         0.776652
# Black or African American_Prop_100K                                     0.078190
# American Indian and Alaska Native_Prop_100K                             0.737376
# Asian_Prop_100K                                                         0.775113
# Native Hawaiian and Other Pacific Islander_Prop...                      0.889774
# Hispanic or Latino_Prop_100K                                            1.000000

# %%
plt.figure(figsize = (20,10))
sns.heatmap(Scorr, cmap = 'BrBG', annot = True, linewidths = 0.5)
plt.title('State Race Demographic and COVID-19 Spearman Correlation Heatmap', fontweight = 'bold', fontsize = 24);

# %%
AllCorr = pd.DataFrame(Pcorr.index, columns = ['Ethnicity'])

AllCorr['Pearson Correlation'] = list(Pcorr.cases)
AllCorr['Kendall Correlation'] = list(Kcorr.cases)
AllCorr['Spearman Correlation'] = list(Scorr.cases)

AllCorr = AllCorr.drop(list(range(0, 3)))
AllCorr = AllCorr.reset_index(drop = True)

AllCorr
# Out:
#                                            Ethnicity  Pearson Correlation  \
# 0                                    White_Prop_100K             0.590200
# 1                Black or African American_Prop_100K            -0.073325
# 2        American Indian and Alaska Native_Prop_100K             0.533905
# 3                                    Asian_Prop_100K            -0.034221
# 4  Native Hawaiian and Other Pacific Islander_Pro...             0.307375
# 5                       Hispanic or Latino_Prop_100K             0.210200
#
#    Kendall Correlation  Spearman Correlation
# 0             0.494902              0.659367
# 1            -0.132549             -0.207240
# 2             0.455686              0.627330
# 3             0.087059              0.118190
# 4             0.323922              0.453756
# 5             0.287843              0.390407

# %%
fig = plt.figure(figsize = (15,8))

X = list(AllCorr['Ethnicity'])
PearCorr = list(AllCorr['Pearson Correlation'])
KendCorr = list(AllCorr['Kendall Correlation'])
SpeaCorr = list(AllCorr['Spearman Correlation'])

_X = np.arange(len(X))

plt.bar(_X, PearCorr, 0.25, color = 'blue', edgecolor = 'black')
plt.bar(_X + 0.25, KendCorr, 0.25, color = 'green', edgecolor = 'black')
plt.bar(_X + 0.50, SpeaCorr, 0.25, color = 'red', edgecolor = 'black')

plt.title('COVID-19 Case Correlations Per Ethnicty', fontsize = 16, fontweight = 'bold')

plt.xlabel('Ethnicity', fontsize = 10, fontweight = 'bold')
plt.xticks(_X, X)
plt.xticks(rotation = 45)

plt.ylabel('Correlation', fontsize = 10, fontweight = 'bold')
plt.yticks(np.arange(0, 1.2, step = 0.2))

plt.legend(['Pearson', 'Kendall', 'Spearman'])

plt.show();

# %%
plt.style.use('seaborn-darkgrid')

df['White'].plot(kind = 'hist', color = 'green', edgecolor = 'black', figsize = (10,7))
plt.title('White Population Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('White', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'White', y = 'cases', data = df, color = 'b', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('White vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('White', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
spearmanr(df['cases'], df['White'])
# Out:
# SpearmanrResult(correlation=0.8761990950226244, pvalue=3.7718107928809123e-17)

# %%
model1 = sm.OLS(df['cases'], df['White']).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.585
# Model:                            OLS   Adj. R-squared (uncentered):              0.577
# Method:                 Least Squares   F-statistic:                              70.53
# Date:                Thu, 18 Jun 2020   Prob (F-statistic):                    4.05e-11
# Time:                        00:06:06   Log-Likelihood:                         -622.84
# No. Observations:                  51   AIC:                                      1248.
# Df Residuals:                      50   BIC:                                      1250.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# White          0.0087      0.001      8.398      0.000       0.007       0.011
# ==============================================================================
# Omnibus:                       74.932   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              939.586
# Skew:                           3.868   Prob(JB):                    9.36e-205
# Kurtosis:                      22.553   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['White'], cmap = 'inferno')
plt.title('White vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['White'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
plt.style.use('seaborn-darkgrid')

df['Black or African American'].plot(kind = 'hist', color = 'blue', edgecolor = 'black', figsize = (10,7))
plt.title('Black or African American Population Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('Black or African American', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'Black or African American', y = 'cases', data = df, color = 'b', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('Black or African American vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('Black or African American', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
spearmanr(df['cases'], df['Black or African American'])
# Out:
# SpearmanrResult(correlation=0.8893212669683257, pvalue=2.834054967270533e-18)

# %%
model2 = sm.OLS(df['cases'], df['Black or African American']).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.591
# Model:                            OLS   Adj. R-squared (uncentered):              0.583
# Method:                 Least Squares   F-statistic:                              72.26
# Date:                Thu, 18 Jun 2020   Prob (F-statistic):                    2.83e-11
# Time:                        00:06:07   Log-Likelihood:                         -622.47
# No. Observations:                  51   AIC:                                      1247.
# Df Residuals:                      50   BIC:                                      1249.
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Black or African American     0.0458      0.005      8.501      0.000       0.035       0.057
# ==============================================================================
# Omnibus:                       51.424   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              326.485
# Skew:                           2.485   Prob(JB):                     1.27e-71
# Kurtosis:                      14.355   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['Black or African American'], cmap = 'inferno')
plt.title('Black or African American  vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Black or African American'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
plt.style.use('seaborn-darkgrid')

df['American Indian and Alaska Native'].plot(kind = 'hist', color = 'green', edgecolor = 'black', figsize = (10,7))
plt.title('American Indian and Alaska Native Population Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('American Indian and Alaska Native', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'American Indian and Alaska Native', y = 'cases', data = df, color = 'b', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('American Indian and Alaska Native vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('American Indian and Alaska Native', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
spearmanr(df['cases'], df['American Indian and Alaska Native'])
# Out:
# SpearmanrResult(correlation=0.25348416289592757, pvalue=0.07268544758614355)

# %%
model3 = sm.OLS(df['cases'], df['American Indian and Alaska Native']).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.196
# Model:                            OLS   Adj. R-squared (uncentered):              0.180
# Method:                 Least Squares   F-statistic:                              12.17
# Date:                Thu, 18 Jun 2020   Prob (F-statistic):                     0.00102
# Time:                        00:06:09   Log-Likelihood:                         -639.72
# No. Observations:                  51   AIC:                                      1281.
# Df Residuals:                      50   BIC:                                      1283.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# American Indian and Alaska Native     0.3576      0.103      3.488      0.001       0.152       0.564
# ==============================================================================
# Omnibus:                       58.121   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              434.654
# Skew:                           2.870   Prob(JB):                     4.13e-95
# Kurtosis:                      16.099   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['American Indian and Alaska Native'], cmap = 'inferno')
plt.title('American Indian and Alaska Native vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['American Indian and Alaska Native'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
plt.style.use('seaborn-darkgrid')

df['Asian'].plot(kind = 'hist', color = 'blue', edgecolor = 'black', figsize = (10,7))
plt.title('Asian Population Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('Asian', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'Asian', y = 'cases', data = df, color = 'b', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('Asian vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('Asian', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
spearmanr(df['cases'], df['Asian'])
# Out:
# SpearmanrResult(correlation=0.8042533936651584, pvalue=1.176239236337126e-12)

# %%
model4 = sm.OLS(df['cases'], df['Asian']).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.425
# Model:                            OLS   Adj. R-squared (uncentered):              0.413
# Method:                 Least Squares   F-statistic:                              36.89
# Date:                Thu, 18 Jun 2020   Prob (F-statistic):                    1.68e-07
# Time:                        00:06:10   Log-Likelihood:                         -631.18
# No. Observations:                  51   AIC:                                      1264.
# Df Residuals:                      50   BIC:                                      1266.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Asian          0.0538      0.009      6.074      0.000       0.036       0.072
# ==============================================================================
# Omnibus:                       52.447   Durbin-Watson:                   1.691
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              510.401
# Skew:                           2.292   Prob(JB):                    1.47e-111
# Kurtosis:                      17.805   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['Asian'], cmap = 'inferno')
plt.title('Asian vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Asian'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
plt.style.use('seaborn-darkgrid')

df['Native Hawaiian and Other Pacific Islander'].plot(kind = 'hist', color = 'green', edgecolor = 'black', figsize = (10,7))
plt.title('Native Hawaiian and Other Pacific Islander Population Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('Native Hawaiian and Other Pacific Islander', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'Native Hawaiian and Other Pacific Islander', y = 'cases', data = df, color = 'b', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('Native Hawaiian and Other Pacific Islander vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('Native Hawaiian and Other Pacific Islander', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
spearmanr(df['cases'], df['Native Hawaiian and Other Pacific Islander'])
# Out:
# SpearmanrResult(correlation=0.4179185520361991, pvalue=0.0022767748893992713)

# %%
model5 = sm.OLS(df['cases'], df['Native Hawaiian and Other Pacific Islander']).fit()
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.108
# Model:                            OLS   Adj. R-squared (uncentered):              0.091
# Method:                 Least Squares   F-statistic:                              6.084
# Date:                Thu, 18 Jun 2020   Prob (F-statistic):                      0.0171
# Time:                        00:06:11   Log-Likelihood:                         -642.34
# No. Observations:                  51   AIC:                                      1287.
# Df Residuals:                      50   BIC:                                      1289.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Native Hawaiian and Other Pacific Islander     0.7827      0.317      2.467      0.017       0.145       1.420
# ==============================================================================
# Omnibus:                       65.475   Durbin-Watson:                   1.649
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              631.466
# Skew:                           3.267   Prob(JB):                    7.57e-138
# Kurtosis:                      18.952   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['Native Hawaiian and Other Pacific Islander'], cmap = 'inferno')
plt.title('Native Hawaiian and Other Pacific Islander vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Native Hawaiian and Other Pacific Islander'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
plt.style.use('seaborn-darkgrid')

df['Hispanic or Latino'].plot(kind = 'hist', color = 'blue', edgecolor = 'black', figsize = (10,7))
plt.title('Hispanic or Latino Population Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('Hispanic or Latino Population', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'Hispanic or Latino', y = 'cases', data = df, color = 'b', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('Hispanic or Latino Population vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('Hispanic or Latino Population', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
spearmanr(df['cases'], df['Hispanic or Latino'])
# Out:
# SpearmanrResult(correlation=0.8071493212669683, pvalue=8.462501618742135e-13)

# %%
model6 = sm.OLS(df['cases'], df['Hispanic or Latino']).fit()
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.455
# Model:                            OLS   Adj. R-squared (uncentered):              0.444
# Method:                 Least Squares   F-statistic:                              41.78
# Date:                Thu, 18 Jun 2020   Prob (F-statistic):                    4.15e-08
# Time:                        00:06:12   Log-Likelihood:                         -629.79
# No. Observations:                  51   AIC:                                      1262.
# Df Residuals:                      50   BIC:                                      1264.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Hispanic or Latino     0.0418      0.006      6.464      0.000       0.029       0.055
# ==============================================================================
# Omnibus:                       52.363   Durbin-Watson:                   1.775
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              475.171
# Skew:                           2.328   Prob(JB):                    6.58e-104
# Kurtosis:                      17.211   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (20,10))

x = df['State'] 
y = df['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = df['Hispanic or Latino'], cmap = 'inferno')
plt.title('Hispanic or Latino Population vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Hispanic or Latino Population'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
model7 = sm.OLS(df['cases'], df[['White','Black or African American','American Indian and Alaska Native','Asian',
                 'Native Hawaiian and Other Pacific Islander','Hispanic or Latino']]).fit()
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.705
# Model:                            OLS   Adj. R-squared (uncentered):              0.665
# Method:                 Least Squares   F-statistic:                              17.89
# Date:                Thu, 18 Jun 2020   Prob (F-statistic):                    1.79e-10
# Time:                        00:11:37   Log-Likelihood:                         -614.18
# No. Observations:                  51   AIC:                                      1240.
# Df Residuals:                      45   BIC:                                      1252.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# White                                          0.0038      0.003      1.173      0.247      -0.003       0.010
# Black or African American                      0.0299      0.011      2.689      0.010       0.008       0.052
# American Indian and Alaska Native              0.0824      0.104      0.796      0.430      -0.126       0.291
# Asian                                          0.1840      0.074      2.475      0.017       0.034       0.334
# Native Hawaiian and Other Pacific Islander    -0.7521      0.313     -2.403      0.020      -1.383      -0.122
# Hispanic or Latino                            -0.1225      0.062     -1.967      0.055      -0.248       0.003
# ==============================================================================
# Omnibus:                       63.865   Durbin-Watson:                   2.188
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              620.641
# Skew:                           3.133   Prob(JB):                    1.70e-135
# Kurtosis:                      18.900   Cond. No.                         356.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
