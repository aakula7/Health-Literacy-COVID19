# %% [markdown]
# # Import Libraries

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams
from matplotlib.backends.backend_agg import FigureCanvasAgg
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

plt.style.use('seaborn-darkgrid')

# %%
def classify(num, avg):
    if num > avg:
        return 1
    elif num < avg:
        return 0

# %% [markdown]
# # Load the Dataset

# %%
df = pd.read_csv('COVIDdemographic.csv')
df.head()
# Out:
#         State    cases  deaths  Total Population  Total population_Male  \
# 0     Alabama   387786   14345           4887871                2369271
# 1      Alaska    18316     367            737438                 382952
# 2     Arizona   426614   18857           7171646                3565129
# 3    Arkansas   161569    3301           3013825                1476680
# 4  California  2664110  102387          39557045               19673553
#
#    Total population_Female  Under 5 years  5 to 9 years  10 to 14 years  \
# 0                  2518600         288589        290369          321430
# 1                   354486          52173         52544           49747
# 2                  3606517         434032        441613          488738
# 3                  1537145         188092        192523          203502
# 4                 19883492        2428493       2398894         2646096
#
#    15 to 19 years  ...  65 to 74 years  75 to 84 years  85 years and over  \
# 0          332209  ...          493396          251025              85242
# 1           48514  ...           59630           21000               7370
# 2          477306  ...          727956          398408             132739
# 3          208021  ...          296808          154699              56169
# 4         2557470  ...         3286461         1651296             729580
#
#    RACE_Total population     White  Black or African American  \
# 0                4887871   3306838                    1307040
# 1                 737438    474555                      25197
# 2                7171646   5590505                     336340
# 3                3013825   2306096                     456714
# 4               39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  \
# 0                                        1797
# 1                                        7958
# 2                                       15661
# 3                                        9398
# 4                                      155739
#
#    Total population_HISPANIC OR LATINO
# 0                              4887871
# 1                               737438
# 2                              7171646
# 3                              3013825
# 4                             39557045
#
# [5 rows x 26 columns]

# %%
list(df.columns)
# Out:
# ['State',
#  'cases',
#  'deaths',
#  'Total Population',
#  'Total population_Male',
#  'Total population_Female',
#  'Under 5 years',
#  '5 to 9 years',
#  '10 to 14 years',
#  '15 to 19 years',
#  '20 to 24 years',
#  '25 to 34 years',
#  '35 to 44 years',
#  '45 to 54 years',
#  '55 to 59 years',
#  '60 to 64 years',
#  '65 to 74 years',
#  '75 to 84 years',
#  '85 years and over',
#  'RACE_Total population',
#  'White',
#  'Black or African American',
#  'American Indian and Alaska Native',
#  'Asian',
#  'Native Hawaiian and Other Pacific Islander',
#  'Total population_HISPANIC OR LATINO']

# %%
df = df.rename(columns = {'Total population_HISPANIC OR LATINO':'Hispanic or Latino'})
df.head()
# Out:
#         State    cases  deaths  Total Population  Total population_Male  \
# 0     Alabama   387786   14345           4887871                2369271
# 1      Alaska    18316     367            737438                 382952
# 2     Arizona   426614   18857           7171646                3565129
# 3    Arkansas   161569    3301           3013825                1476680
# 4  California  2664110  102387          39557045               19673553
#
#    Total population_Female  Under 5 years  5 to 9 years  10 to 14 years  \
# 0                  2518600         288589        290369          321430
# 1                   354486          52173         52544           49747
# 2                  3606517         434032        441613          488738
# 3                  1537145         188092        192523          203502
# 4                 19883492        2428493       2398894         2646096
#
#    15 to 19 years  ...  65 to 74 years  75 to 84 years  85 years and over  \
# 0          332209  ...          493396          251025              85242
# 1           48514  ...           59630           21000               7370
# 2          477306  ...          727956          398408             132739
# 3          208021  ...          296808          154699              56169
# 4         2557470  ...         3286461         1651296             729580
#
#    RACE_Total population     White  Black or African American  \
# 0                4887871   3306838                    1307040
# 1                 737438    474555                      25197
# 2                7171646   5590505                     336340
# 3                3013825   2306096                     456714
# 4               39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino
# 0                                        1797             4887871
# 1                                        7958              737438
# 2                                       15661             7171646
# 3                                        9398             3013825
# 4                                      155739            39557045
#
# [5 rows x 26 columns]

# %%
list(df.columns)
# Out:
# ['State',
#  'cases',
#  'deaths',
#  'Total Population',
#  'Total population_Male',
#  'Total population_Female',
#  'Under 5 years',
#  '5 to 9 years',
#  '10 to 14 years',
#  '15 to 19 years',
#  '20 to 24 years',
#  '25 to 34 years',
#  '35 to 44 years',
#  '45 to 54 years',
#  '55 to 59 years',
#  '60 to 64 years',
#  '65 to 74 years',
#  '75 to 84 years',
#  '85 years and over',
#  'RACE_Total population',
#  'White',
#  'Black or African American',
#  'American Indian and Alaska Native',
#  'Asian',
#  'Native Hawaiian and Other Pacific Islander',
#  'Hispanic or Latino']

# %%
df['Hispanic or Latino'] = (df['Total Population'])-(df['White'] + df['Black or African American'] + 
                                                     df['American Indian and Alaska Native'] + df['Asian'] + 
                                                     df['Native Hawaiian and Other Pacific Islander'])

df.head()
# Out:
#         State    cases  deaths  Total Population  Total population_Male  \
# 0     Alabama   387786   14345           4887871                2369271
# 1      Alaska    18316     367            737438                 382952
# 2     Arizona   426614   18857           7171646                3565129
# 3    Arkansas   161569    3301           3013825                1476680
# 4  California  2664110  102387          39557045               19673553
#
#    Total population_Female  Under 5 years  5 to 9 years  10 to 14 years  \
# 0                  2518600         288589        290369          321430
# 1                   354486          52173         52544           49747
# 2                  3606517         434032        441613          488738
# 3                  1537145         188092        192523          203502
# 4                 19883492        2428493       2398894         2646096
#
#    15 to 19 years  ...  65 to 74 years  75 to 84 years  85 years and over  \
# 0          332209  ...          493396          251025              85242
# 1           48514  ...           59630           21000               7370
# 2          477306  ...          727956          398408             132739
# 3          208021  ...          296808          154699              56169
# 4         2557470  ...         3286461         1651296             729580
#
#    RACE_Total population     White  Black or African American  \
# 0                4887871   3306838                    1307040
# 1                 737438    474555                      25197
# 2                7171646   5590505                     336340
# 3                3013825   2306096                     456714
# 4               39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino
# 0                                        1797              185038
# 1                                        7958               71976
# 2                                       15661              660668
# 3                                        9398              173118
# 4                                      155739             7457691
#
# [5 rows x 26 columns]

# %%
df = df[['State', 'cases', 'deaths', 'Total Population', 'White', 'Black or African American', 
         'American Indian and Alaska Native', 'Asian', 'Native Hawaiian and Other Pacific Islander', 
         'Hispanic or Latino']]

df.head()
# Out:
#         State    cases  deaths  Total Population     White  \
# 0     Alabama   387786   14345           4887871   3306838
# 1      Alaska    18316     367            737438    474555
# 2     Arizona   426614   18857           7171646   5590505
# 3    Arkansas   161569    3301           3013825   2306096
# 4  California  2664110  102387          39557045  23535388
#
#    Black or African American  American Indian and Alaska Native    Asian  \
# 0                    1307040                              22063    65095
# 1                      25197                             111371    46381
# 2                     336340                             330599   237873
# 3                     456714                              20951    47548
# 4                    2283850                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino
# 0                                        1797              185038
# 1                                        7958               71976
# 2                                       15661              660668
# 3                                        9398              173118
# 4                                      155739             7457691

# %%
df = df.drop(columns = ['cases', 'deaths'])
df.head()
# Out:
#         State  Total Population     White  Black or African American  \
# 0     Alabama           4887871   3306838                    1307040
# 1      Alaska            737438    474555                      25197
# 2     Arizona           7171646   5590505                     336340
# 3    Arkansas           3013825   2306096                     456714
# 4  California          39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino
# 0                                        1797              185038
# 1                                        7958               71976
# 2                                       15661              660668
# 3                                        9398              173118
# 4                                      155739             7457691

# %%
COVID_Case = pd.read_csv('COVID.csv', index_col = 0)
COVID_Case.head()
# Out:
#         State   cases  deaths
# 0     Alabama   59067    1211
# 1      Alaska    1954      15
# 2     Arizona  131411    2442
# 3    Arkansas   30297     335
# 4  California  355497    7368

# %%
df = pd.merge(df, COVID_Case, how = 'left', on = 'State')
df.head()
# Out:
#         State  Total Population     White  Black or African American  \
# 0     Alabama           4887871   3306838                    1307040
# 1      Alaska            737438    474555                      25197
# 2     Arizona           7171646   5590505                     336340
# 3    Arkansas           3013825   2306096                     456714
# 4  California          39557045  23535388                    2283850
#
#    American Indian and Alaska Native    Asian  \
# 0                              22063    65095
# 1                             111371    46381
# 2                             330599   237873
# 3                              20951    47548
# 4                             302792  5821585
#
#    Native Hawaiian and Other Pacific Islander  Hispanic or Latino   cases  \
# 0                                        1797              185038   59067
# 1                                        7958               71976    1954
# 2                                       15661              660668  131411
# 3                                        9398              173118   30297
# 4                                      155739             7457691  355497
#
#    deaths
# 0    1211
# 1      15
# 2    2442
# 3     335
# 4    7368

# %%
DFLogReg = df

CasesMean = DFLogReg['cases'].mean()

DFLogReg['Cases_Avg'] = DFLogReg['cases'].apply(lambda x: classify(x, CasesMean))

DFLogReg
# Out:
#                    State  Total Population     White  \
# 0                Alabama           4887871   3306838
# 1                 Alaska            737438    474555
# 2                Arizona           7171646   5590505
# 3               Arkansas           3013825   2306096
# 4             California          39557045  23535388
# 5               Colorado           5695564   4790677
# 6            Connecticut           3572665   2688136
# 7               Delaware            967171    659781
# 8   District of Columbia            702455    296747
# 9                Florida          21299325  15899574
# 10               Georgia          10519475   6127645
# 11                Hawaii           1420491    345652
# 12                 Idaho           1754208   1576846
# 13              Illinois          12741080   9135145
# 14               Indiana           6691878   5539927
# 15                  Iowa           3156145   2846099
# 16                Kansas           2911510   2446823
# 17              Kentucky           4468402   3875023
# 18             Louisiana           4659978   2877115
# 19                 Maine           1338404   1261453
# 20              Maryland           6042718   3305047
# 21         Massachusetts           6902149   5335175
# 22              Michigan           9995915   7825285
# 23             Minnesota           5611179   4629375
# 24           Mississippi           2986530   1735455
# 25              Missouri           6126452   5035197
# 26               Montana           1062305    941438
# 27              Nebraska           1929268   1666990
# 28                Nevada           3034392   1924976
# 29         New Hampshire           1356458   1253931
# 30            New Jersey           8908520   5956539
# 31            New Mexico           2095428   1599938
# 32              New York          19542209  12375601
# 33        North Carolina          10383620   7098569
# 34          North Dakota            760077    651687
# 35                  Ohio          11689442   9470940
# 36              Oklahoma           3943079   2845906
# 37                Oregon           4190713   3514983
# 38          Pennsylvania          12807060  10256084
# 39          Rhode Island           1057315    852805
# 40        South Carolina           5084127   3407706
# 41          South Dakota            882235    740870
# 42             Tennessee           6770010   5235588
# 43                 Texas          28701845  21099066
# 44                  Utah           3161105   2708195
# 45               Vermont            626299    589337
# 46              Virginia           8517685   5737580
# 47            Washington           7535591   5633263
# 48         West Virginia           1805832   1679773
# 49             Wisconsin           5813568   4957243
# 50               Wyoming            577737    528453
#
#     Black or African American  American Indian and Alaska Native    Asian  \
# 0                     1307040                              22063    65095
# 1                       25197                             111371    46381
# 2                      336340                             330599   237873
# 3                      456714                              20951    47548
# 42                                        5494              252945   67515
# 43                                       21463             2473435  295423
# 44                                       29362              272607   31228
# 45                                         139               15600    1318
# 46                                        5659              565247   73527
# 47                                       53924              797486   45004
# 48                                         451               40841    4557
# 49                                        1961              267988   42409
# 50                                        1111               22514    1985
#
#     deaths  Cases_Avg
# 0     1211          0
# 1       15          0
# 2     2442          1
# 3      335          0
# 4     7368          1
# 5     1745          0
# 6     4380          0
# 7      521          0
# 8      571          0
# 9     4520          1
# 10    3030          1
# 11      21          0
# 12     111          0
# 13    7435          1
# 14    2785          0
# 15     777          0
# 16     308          0
# 17     668          0
# 18    3461          1
# 19     114          0
# 20    3341          1
# 21    8368          1
# 22    6333          1
# 23    1558          0
# 24    1290          0
# 25    1141          0
# 26      34          0
# 27     302          0
# 28     619          0
# 29     394          0
# 30   15634          1
# 31     557          0
# 32   32115          1
# 33    1598          1
# 34      92          0
# 35    3075          1
# 36     432          0
# 37     249          0
# 38    7011          1
# 39     987          0
# 40     998          0
# 41     111          0
# 42     773          0
# 43    3582          1
# 44     233          0
# 45      56          0
# 46    1992          1
# 47    1486          0
# 48      98          0
# 49     835          0
# 50      22          0

# %%
test_len = int(0.25 * len(DFLogReg))
train_len = len(DFLogReg) - test_len
print('Train Set Len: ' + str(train_len))
print('Test Set Len: ' + str(test_len))

train = DFLogReg[:train_len]
test = DFLogReg[train_len:]
print('Train Set Shape: ' + str(train.shape))
print('Test Set Shape: ' + str(test.shape))
# Out:
# Train Set Len: 39
# Test Set Len: 12
# Train Set Shape: (39, 11)
# Test Set Shape: (12, 11)

# %%
features_list = ['White']

target = 'Cases_Avg'
    
X_train = train[features_list]
y_train = train[target]
X_test = test[features_list]
y_test = test[target]

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(np.array(X_train).reshape(-1, 1))
X_test_scaled = scaler.transform(np.array(X_test).reshape(-1, 1))

LogRegModel = LogisticRegression()
LogRegModel.fit(X_train_scaled, y_train)

train_predictions = LogRegModel.predict(X_train_scaled)
test_predictions = LogRegModel.predict(X_test_scaled)

Train_MAE = mean_absolute_error(y_train, train_predictions)
Train_MSE = mean_squared_error(y_train, train_predictions)
Train_RMS = sqrt(mean_squared_error(y_train, train_predictions))
Train_R2Score = r2_score(y_train, train_predictions)

Test_MAE = mean_absolute_error(y_test, test_predictions)
Test_MSE = mean_squared_error(y_test, test_predictions)
Test_RMS = sqrt(mean_squared_error(y_test, test_predictions))
Test_R2Score = r2_score(y_test, test_predictions)

print('Train MAE Value:', Train_MAE)
print('Train MSE Value:', Train_MSE)
print('Train RMS Value:', Train_RMS)
print('Train R2 Score:', Train_R2Score)
print('\n')

print('Test MAE Value:', Test_MAE)
print('Test MSE Value:', Test_MSE)
print('Test RMS Value:', Test_RMS)
print('Test R2 Score:', Test_R2Score)
# Out:
# Train MAE Value: 0.10256410256410256
# Train MSE Value: 0.10256410256410256
# Train RMS Value: 0.32025630761017426
# Train R2 Score: 0.5542857142857143
#
#
# Test MAE Value: 0.08333333333333333
# Test MSE Value: 0.08333333333333333
# Test RMS Value: 0.28867513459481287
# Test R2 Score: 0.3999999999999999

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = train['State'], y = train_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('White Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Train Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('White Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Test Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
features_list = ['Black or African American']

target = 'Cases_Avg'
    
X_train = train[features_list]
y_train = train[target]
X_test = test[features_list]
y_test = test[target]

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(np.array(X_train).reshape(-1, 1))
X_test_scaled = scaler.transform(np.array(X_test).reshape(-1, 1))

LogRegModel = LogisticRegression()
LogRegModel.fit(X_train_scaled, y_train)

train_predictions = LogRegModel.predict(X_train_scaled)
test_predictions = LogRegModel.predict(X_test_scaled)

Train_MAE = mean_absolute_error(y_train, train_predictions)
Train_MSE = mean_squared_error(y_train, train_predictions)
Train_RMS = sqrt(mean_squared_error(y_train, train_predictions))
Train_R2Score = r2_score(y_train, train_predictions)

Test_MAE = mean_absolute_error(y_test, test_predictions)
Test_MSE = mean_squared_error(y_test, test_predictions)
Test_RMS = sqrt(mean_squared_error(y_test, test_predictions))
Test_R2Score = r2_score(y_test, test_predictions)

print('Train MAE Value:', Train_MAE)
print('Train MSE Value:', Train_MSE)
print('Train RMS Value:', Train_RMS)
print('Train R2 Score:', Train_R2Score)
print('\n')

print('Test MAE Value:', Test_MAE)
print('Test MSE Value:', Test_MSE)
print('Test RMS Value:', Test_RMS)
print('Test R2 Score:', Test_R2Score)
# Out:
# Train MAE Value: 0.10256410256410256
# Train MSE Value: 0.10256410256410256
# Train RMS Value: 0.32025630761017426
# Train R2 Score: 0.5542857142857143
#
#
# Test MAE Value: 0.16666666666666666
# Test MSE Value: 0.16666666666666666
# Test RMS Value: 0.408248290463863
# Test R2 Score: -0.20000000000000018

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = train['State'], y = train_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('Black Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Train Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('Black Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Test Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
features_list = ['American Indian and Alaska Native']

target = 'Cases_Avg'
    
X_train = train[features_list]
y_train = train[target]
X_test = test[features_list]
y_test = test[target]

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(np.array(X_train).reshape(-1, 1))
X_test_scaled = scaler.transform(np.array(X_test).reshape(-1, 1))

LogRegModel = LogisticRegression()
LogRegModel.fit(X_train_scaled, y_train)

train_predictions = LogRegModel.predict(X_train_scaled)
test_predictions = LogRegModel.predict(X_test_scaled)

Train_MAE = mean_absolute_error(y_train, train_predictions)
Train_MSE = mean_squared_error(y_train, train_predictions)
Train_RMS = sqrt(mean_squared_error(y_train, train_predictions))
Train_R2Score = r2_score(y_train, train_predictions)

Test_MAE = mean_absolute_error(y_test, test_predictions)
Test_MSE = mean_squared_error(y_test, test_predictions)
Test_RMS = sqrt(mean_squared_error(y_test, test_predictions))
Test_R2Score = r2_score(y_test, test_predictions)

print('Train MAE Value:', Train_MAE)
print('Train MSE Value:', Train_MSE)
print('Train RMS Value:', Train_RMS)
print('Train R2 Score:', Train_R2Score)
print('\n')

print('Test MAE Value:', Test_MAE)
print('Test MSE Value:', Test_MSE)
print('Test RMS Value:', Test_RMS)
print('Test R2 Score:', Test_R2Score)
# Out:
# Train MAE Value: 0.358974358974359
# Train MSE Value: 0.358974358974359
# Train RMS Value: 0.5991446895152781
# Train R2 Score: -0.56
#
#
# Test MAE Value: 0.16666666666666666
# Test MSE Value: 0.16666666666666666
# Test RMS Value: 0.408248290463863
# Test R2 Score: -0.20000000000000018

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = train['State'], y = train_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('American Indian and Alaska Native Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Train Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('American Indian and Alaska Native Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Test Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
features_list = ['Asian']

target = 'Cases_Avg'
    
X_train = train[features_list]
y_train = train[target]
X_test = test[features_list]
y_test = test[target]

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(np.array(X_train).reshape(-1, 1))
X_test_scaled = scaler.transform(np.array(X_test).reshape(-1, 1))

LogRegModel = LogisticRegression()
LogRegModel.fit(X_train_scaled, y_train)

train_predictions = LogRegModel.predict(X_train_scaled)
test_predictions = LogRegModel.predict(X_test_scaled)

Train_MAE = mean_absolute_error(y_train, train_predictions)
Train_MSE = mean_squared_error(y_train, train_predictions)
Train_RMS = sqrt(mean_squared_error(y_train, train_predictions))
Train_R2Score = r2_score(y_train, train_predictions)

Test_MAE = mean_absolute_error(y_test, test_predictions)
Test_MSE = mean_squared_error(y_test, test_predictions)
Test_RMS = sqrt(mean_squared_error(y_test, test_predictions))
Test_R2Score = r2_score(y_test, test_predictions)

print('Train MAE Value:', Train_MAE)
print('Train MSE Value:', Train_MSE)
print('Train RMS Value:', Train_RMS)
print('Train R2 Score:', Train_R2Score)
print('\n')

print('Test MAE Value:', Test_MAE)
print('Test MSE Value:', Test_MSE)
print('Test RMS Value:', Test_RMS)
print('Test R2 Score:', Test_R2Score)
# Out:
# Train MAE Value: 0.23076923076923078
# Train MSE Value: 0.23076923076923078
# Train RMS Value: 0.4803844614152614
# Train R2 Score: -0.0028571428571428914
#
#
# Test MAE Value: 0.08333333333333333
# Test MSE Value: 0.08333333333333333
# Test RMS Value: 0.28867513459481287
# Test R2 Score: 0.3999999999999999

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = train['State'], y = train_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('Asian Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Train Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('Asian Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Test Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
features_list = ['Native Hawaiian and Other Pacific Islander']

target = 'Cases_Avg'
    
X_train = train[features_list]
y_train = train[target]
X_test = test[features_list]
y_test = test[target]

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(np.array(X_train).reshape(-1, 1))
X_test_scaled = scaler.transform(np.array(X_test).reshape(-1, 1))

LogRegModel = LogisticRegression()
LogRegModel.fit(X_train_scaled, y_train)

train_predictions = LogRegModel.predict(X_train_scaled)
test_predictions = LogRegModel.predict(X_test_scaled)

Train_MAE = mean_absolute_error(y_train, train_predictions)
Train_MSE = mean_squared_error(y_train, train_predictions)
Train_RMS = sqrt(mean_squared_error(y_train, train_predictions))
Train_R2Score = r2_score(y_train, train_predictions)

Test_MAE = mean_absolute_error(y_test, test_predictions)
Test_MSE = mean_squared_error(y_test, test_predictions)
Test_RMS = sqrt(mean_squared_error(y_test, test_predictions))
Test_R2Score = r2_score(y_test, test_predictions)

print('Train MAE Value:', Train_MAE)
print('Train MSE Value:', Train_MSE)
print('Train RMS Value:', Train_RMS)
print('Train R2 Score:', Train_R2Score)
print('\n')

print('Test MAE Value:', Test_MAE)
print('Test MSE Value:', Test_MSE)
print('Test RMS Value:', Test_RMS)
print('Test R2 Score:', Test_R2Score)
# Out:
# Train MAE Value: 0.358974358974359
# Train MSE Value: 0.358974358974359
# Train RMS Value: 0.5991446895152781
# Train R2 Score: -0.56
#
#
# Test MAE Value: 0.16666666666666666
# Test MSE Value: 0.16666666666666666
# Test RMS Value: 0.408248290463863
# Test R2 Score: -0.20000000000000018

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = train['State'], y = train_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('Native Hawaiian and Other Pacific Islander Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Train Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('Native Hawaiian and Other Pacific Islander Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Test Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
features_list = ['Hispanic or Latino']

target = 'Cases_Avg'
    
X_train = train[features_list]
y_train = train[target]
X_test = test[features_list]
y_test = test[target]

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(np.array(X_train).reshape(-1, 1))
X_test_scaled = scaler.transform(np.array(X_test).reshape(-1, 1))

LogRegModel = LogisticRegression()
LogRegModel.fit(X_train_scaled, y_train)

train_predictions = LogRegModel.predict(X_train_scaled)
test_predictions = LogRegModel.predict(X_test_scaled)

Train_MAE = mean_absolute_error(y_train, train_predictions)
Train_MSE = mean_squared_error(y_train, train_predictions)
Train_RMS = sqrt(mean_squared_error(y_train, train_predictions))
Train_R2Score = r2_score(y_train, train_predictions)

Test_MAE = mean_absolute_error(y_test, test_predictions)
Test_MSE = mean_squared_error(y_test, test_predictions)
Test_RMS = sqrt(mean_squared_error(y_test, test_predictions))
Test_R2Score = r2_score(y_test, test_predictions)

print('Train MAE Value:', Train_MAE)
print('Train MSE Value:', Train_MSE)
print('Train RMS Value:', Train_RMS)
print('Train R2 Score:', Train_R2Score)
print('\n')

print('Test MAE Value:', Test_MAE)
print('Test MSE Value:', Test_MSE)
print('Test RMS Value:', Test_RMS)
print('Test R2 Score:', Test_R2Score)
# Out:
# Train MAE Value: 0.23076923076923078
# Train MSE Value: 0.23076923076923078
# Train RMS Value: 0.4803844614152614
# Train R2 Score: -0.0028571428571428914
#
#
# Test MAE Value: 0.16666666666666666
# Test MSE Value: 0.16666666666666666
# Test RMS Value: 0.408248290463863
# Test R2 Score: -0.20000000000000018

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = train['State'], y = train_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('Hispanic and Latino Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Train Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('Hispanic and Latino Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Test Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
features_list = ['White','Black or African American','American Indian and Alaska Native','Asian',
                 'Native Hawaiian and Other Pacific Islander','Hispanic or Latino']

target = 'Cases_Avg'
    
X_train = train[features_list]
y_train = train[target]
X_test = test[features_list]
y_test = test[target]

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

LogRegModel = LogisticRegression()
LogRegModel.fit(X_train_scaled, y_train)

train_predictions = LogRegModel.predict(X_train_scaled)
test_predictions = LogRegModel.predict(X_test_scaled)

Train_MAE = mean_absolute_error(y_train, train_predictions)
Train_MSE = mean_squared_error(y_train, train_predictions)
Train_RMS = sqrt(mean_squared_error(y_train, train_predictions))
Train_R2Score = r2_score(y_train, train_predictions)

Test_MAE = mean_absolute_error(y_test, test_predictions)
Test_MSE = mean_squared_error(y_test, test_predictions)
Test_RMS = sqrt(mean_squared_error(y_test, test_predictions))
Test_R2Score = r2_score(y_test, test_predictions)

print('Train MAE Value:', Train_MAE)
print('Train MSE Value:', Train_MSE)
print('Train RMS Value:', Train_RMS)
print('Train R2 Score:', Train_R2Score)
print('\n')

print('Test MAE Value:', Test_MAE)
print('Test MSE Value:', Test_MSE)
print('Test RMS Value:', Test_RMS)
print('Test R2 Score:', Test_R2Score)
# Out:
# Train MAE Value: 0.05128205128205128
# Train MSE Value: 0.05128205128205128
# Train RMS Value: 0.22645540682891915
# Train R2 Score: 0.7771428571428571
#
#
# Test MAE Value: 0.0
# Test MSE Value: 0.0
# Test RMS Value: 0.0
# Test R2 Score: 1.0

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = train['State'], y = train_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('All Races Total Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Train Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['Cases_Avg'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('All Races Total Population Per State vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Test Predictions'])

plt.xticks(rotation = 90)
plt.show();
