# %% [markdown]
# # Import the libraries

# %%
#Numpy for numerical computing
import numpy as np

#Pandas for DataFrames
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

from sklearn import datasets, linear_model, metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from numpy.polynomial.polynomial import polyfit
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the dataset

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
#Load Real Estate Data from csv

df = pd.read_csv('C:\\NachuMohan\\Saint_Peters_University\\GA_Summer2020\\Demographic_newversion.csv')

# %%
df
# Out:
#                    State  Total Population  Total population_Male  \
# 0   Illinois              12741080          6266062
# 1   Iowa                  3156145           1564888
# 2   Missouri              6126452           3003165
# 3   Nevada                3034392           1522374
# 4   Pennsylvania          12807060          6271620
# 5   Utah                  3161105           1592457
# 6   West Virginia         1805832           894657
# 7   Colorado              5695564           2864761
# 8   Georgia               10519475          5120290
# 9   Idaho                 1754208           882158
# 10  Maryland              6042718           2930350
# 11  New Jersey            8908520           4350386
# 12  New Mexico            2095428           1039641
# 13  Ohio                  11689442          5732095
# 14  Alaska                737438            382952
# 15  Florida               21299325          10404676
# 16  Hawaii                1420491           710702
# ...

# %% [markdown]
# # Finding the datatypes in a dataframe

# %%
df.dtypes
# Out:
# State                                                          object
# Total Population                                               int64
# Total population_Male                                          int64
# Total population_Female                                        int64
# Under 5 years                                                  int64
# 5 to 9 years                                                   int64
# 10 to 14 years                                                 int64
# 15 to 19 years                                                 int64
# 20 to 24 years                                                 int64
# 25 to 34 years                                                 int64
# 35 to 44 years                                                 int64
# 45 to 54 years                                                 int64
# 55 to 59 years                                                 int64
# 60 to 64 years                                                 int64
# ...

# %% [markdown]
# # Removing unwanted columns

# %%
df = df.drop(['Asian Chinese','Asian Indian','Asian Filipino','Asian Japanese','Asian Korean','Asian Vietnamese',
             'Other Asian','Some other race','Total population!!White',
             'Total population_Black or African American',
             'Total population_American Indian and Alaska Native',
             'Total population_Asian',
             'Total population_Native Hawaiian and Other Pacific Islander',
             'Total population_Some other race',
             'Total population_Not Hispanic or Latino'], axis = 1)
df
# Out:
#                    State  Total Population  Total population_Male  \
# 0   Illinois              12741080          6266062
# 1   Iowa                  3156145           1564888
# 2   Missouri              6126452           3003165
# 3   Nevada                3034392           1522374
# 4   Pennsylvania          12807060          6271620
# 5   Utah                  3161105           1592457
# 6   West Virginia         1805832           894657
# 7   Colorado              5695564           2864761
# 8   Georgia               10519475          5120290
# 9   Idaho                 1754208           882158
# 10  Maryland              6042718           2930350
# 11  New Jersey            8908520           4350386
# 12  New Mexico            2095428           1039641
# 13  Ohio                  11689442          5732095
# 14  Alaska                737438            382952
# 15  Florida               21299325          10404676
# 16  Hawaii                1420491           710702
# ...

# %% [markdown]
# # Summarize the dataset

# %%
df.describe()
# Out:
#        Total Population  Total population_Male  Total population_Female  \
# count  5.300000e+01      5.300000e+01           5.300000e+01
# mean   1.240623e+07      6.108617e+06           6.297610e+06
# std    4.465386e+07      2.199259e+07           2.266136e+07
# min    5.777370e+05      2.926190e+05           2.851180e+05
# 25%    1.805832e+06      8.946570e+05           9.111750e+05
# 50%    4.468402e+06      2.199021e+06           2.269381e+06
# 75%    7.535591e+06      3.766859e+06           3.768732e+06
# max    3.271674e+08      1.611182e+08           1.660493e+08
#
#        Under 5 years  5 to 9 years  10 to 14 years  15 to 19 years  \
# count  5.300000e+01   5.300000e+01  5.300000e+01    5.300000e+01
# mean   7.437439e+05   7.505523e+05  8.106960e+05    8.132271e+05
# std    2.684228e+06   2.704223e+06  2.922211e+06    2.927071e+06
# min    2.881000e+04   3.201900e+04  3.338600e+04    3.756800e+04
# 25%    1.136930e+05   1.239590e+05  1.299470e+05    1.270120e+05
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# # To check whether there is a null value in a dataframe

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Instead of NA values, we could see there is a value N

# %% [markdown]
# Replacing the N values as NA

# %%
df1 = df.replace(to_replace = 'N', value = 'NaN')

# %%
df1.head(7)
# Out:
#            State  Total Population  Total population_Male  \
# 0  Illinois       12741080          6266062
# 1  Iowa           3156145           1564888
# 2  Missouri       6126452           3003165
# 3  Nevada         3034392           1522374
# 4  Pennsylvania   12807060          6271620
# 5  Utah           3161105           1592457
# 6  West Virginia  1805832           894657
#
#    Total population_Female  Under 5 years  5 to 9 years  10 to 14 years  \
# 0  6475018                  759456         762237        838140
# 1  1591257                  197883         197454        215222
# 2  3123287                  370408         373737        401199
# 3  1512018                  184539         188880        201625
# 4  6535440                  700416         708163        775827
# 5  1568648                  250194         257110        270952
# 6  911175                   93922          97203         107390
#
#    15 to 19 years  20 to 24 years  25 to 34 years  35 to 44 years  \
# ...

# %% [markdown]
# First N value found in statePuerto Rico, so instead of taking whole dataframe, checking for the state Puerto Rico whether the N value has replaced with value NaN

# %%
df2 = pd.DataFrame(columns=df.columns)

cond = df1['State'] == 'Puerto Rico'
rows = df1.loc[cond, :]
df2 = df2.append(rows, ignore_index=True)

# %%
df2
# Out:
#          State Total Population Total population_Male Total population_Female  \
# 0  Puerto Rico  3195153          1520415               1674738
#
#   Under 5 years 5 to 9 years 10 to 14 years 15 to 19 years 20 to 24 years  \
# 0  125796        167470       181046         210051         222760
#
#   25 to 34 years 35 to 44 years 45 to 54 years 55 to 59 years 60 to 64 years  \
# 0  381445         396979         422128         214899         211363
#
#   65 to 74 years 75 to 84 years 85 years and over RACE_Total population  \
# 0  361819         217779         81618             3195153
#
#      White Black or African American American Indian and Alaska Native Asian  \
# 0  2079304  400936                    4013                              5144
#
#   Native Hawaiian and Other Pacific Islander  \
# 0  767
#
#   Total population_HISPANIC OR LATINO
# 0  3195153

# %% [markdown]
# # Replacing the NA Values as mean value of the column

# %%
# fill missing values with mean column values
df1.fillna(df1.mean(), inplace=True)

# %%
df1
# Out:
#                    State  Total Population  Total population_Male  \
# 0   Illinois              12741080          6266062
# 1   Iowa                  3156145           1564888
# 2   Missouri              6126452           3003165
# 3   Nevada                3034392           1522374
# 4   Pennsylvania          12807060          6271620
# 5   Utah                  3161105           1592457
# 6   West Virginia         1805832           894657
# 7   Colorado              5695564           2864761
# 8   Georgia               10519475          5120290
# 9   Idaho                 1754208           882158
# 10  Maryland              6042718           2930350
# 11  New Jersey            8908520           4350386
# 12  New Mexico            2095428           1039641
# 13  Ohio                  11689442          5732095
# 14  Alaska                737438            382952
# 15  Florida               21299325          10404676
# 16  Hawaii                1420491           710702
# ...

# %%
covid_us_states = pd.read_csv('C:\\NachuMohan\\Saint_Peters_University\\GA_Summer2020\\us-states.csv')

# %%
covid_us_states = covid_us_states.groupby(['state']).sum()
covid_us_states = covid_us_states.reset_index()
covid_us_states.drop([11, 36, 41, 49], inplace = True)
covid_us_states = covid_us_states.reset_index(drop = True)
covid_us_states.head()
# Out:
#         state  fips    cases  deaths
# 0  Alabama     73    387786   14345
# 1  Alaska      148   18316    367
# 2  Arizona     480   426614   18857
# 3  Arkansas    375   161569   3301
# 4  California  726   2664110  102387

# %%
covid_us_states = covid_us_states.rename(columns = {'state':'State'})
covid_us_states.head()
# Out:
#         State  fips    cases  deaths
# 0  Alabama     73    387786   14345
# 1  Alaska      148   18316    367
# 2  Arizona     480   426614   18857
# 3  Arkansas    375   161569   3301
# 4  California  726   2664110  102387

# %%
covid_us_states = covid_us_states.drop(['fips'], axis = 1)
covid_us_states
# Out:
#                    State     cases   deaths
# 0   Alabama               387786    14345
# 1   Alaska                18316     367
# 2   Arizona               426614    18857
# 3   Arkansas              161569    3301
# 4   California            2664110   102387
# 5   Colorado              766512    37828
# 6   Connecticut           1314995   104185
# 7   Delaware              234327    7813
# 8   District of Columbia  229466    10822
# 9   Florida               1726811   63147
# 10  Georgia               1282091   54209
# 11  Hawaii                31433     681
# 12  Idaho                 103987    2828
# 13  Illinois              2843621   122000
# 14  Indiana               920434    53042
# 15  Iowa                  396980    9203
# 16  Kansas                231885    6527
# 17  Kentucky              246480    11851
# 18  Louisiana             1443404   90609
# 19  Maine                 61284     2451
# 20  Maryland              1173802   56126
# ...

# %%
COVIDdemographic = pd.merge(covid_us_states, df1, how = 'left', on = 'State')
COVIDdemographic
# Out:
#                    State     cases   deaths  Total Population  \
# 0   Alabama               387786    14345    4887871
# 1   Alaska                18316     367      737438
# 2   Arizona               426614    18857    7171646
# 3   Arkansas              161569    3301     3013825
# 4   California            2664110   102387   39557045
# 5   Colorado              766512    37828    5695564
# 6   Connecticut           1314995   104185   3572665
# 7   Delaware              234327    7813     967171
# 8   District of Columbia  229466    10822    702455
# 9   Florida               1726811   63147    21299325
# 10  Georgia               1282091   54209    10519475
# 11  Hawaii                31433     681      1420491
# 12  Idaho                 103987    2828     1754208
# 13  Illinois              2843621   122000   12741080
# 14  Indiana               920434    53042    6691878
# 15  Iowa                  396980    9203     3156145
# ...
