# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
SocSci = pd.read_excel('social-scientists-to-all-occupations.xlsx')
SocSci
# Out:
#                                            Table S-37         Unnamed: 1  \
# 0   Social Scientists as a Percentage of All Occup...                NaN
# 1                                                 NaN  Social scientists
# 2                                               State               2003
# 3                                       United States             461060
# 4                                             Alabama               3470
# ..                                                ...                ...
# 59  NOTES: Occupational Employment Statistics (OES...                NaN
# 60  SOURCE: Bureau of Labor Statistics, special ta...                NaN
# 61  Recommended Citation: National Science Board. ...                NaN
# 62                   Last updated: September 24, 2019                NaN
# 63                 Science and Engineering Indicators                NaN
#
#     Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# ...

# %%
SocSci2 = SocSci.drop(['Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
                          'Unnamed: 34', 'Unnamed: 33', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

SocSci2.head()
# Out:
#                                           Table S-37         Unnamed: 1  \
# 0  Social Scientists as a Percentage of All Occup...                NaN
# 1                                                NaN  Social scientists
# 2                                              State               2003
# 3                                      United States             461060
# 4                                            Alabama               3470
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2      2004.0      2005.0      2006.0      2007.0      2008.0      2009.0
# 3    497280.0    517950.0    536880.0    545360.0    561160.0    568730.0
# 4      4090.0      4270.0      4090.0      3550.0      3050.0         NaN
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# ...

# %%
SocSci2.drop(range(0,4), inplace = True)
SocSci2.drop(range(55,64), inplace = True)
SocSci2 = SocSci2.reset_index(drop = True)
SocSci2
# Out:
#               Table S-37 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                Alabama       3470      4090.0      4270.0      4090.0
# 1                 Alaska       1130      1150.0      1260.0      1070.0
# 2                Arizona       7690      8130.0      8380.0      8570.0
# 3               Arkansas       2250      2650.0      2500.0      2420.0
# 4             California      56540     60540.0     62940.0     63470.0
# 5               Colorado       8760      8510.0      8600.0      9660.0
# 6            Connecticut       8710      8800.0      8630.0      7770.0
# 7               Delaware       1910      2180.0      1760.0      2980.0
# 8   District of Columbia      13370     15770.0     17890.0     17310.0
# 9                Florida      19850     23130.0     25430.0     24570.0
# 10               Georgia      10150     10330.0     11430.0     11540.0
# 11                Hawaii       1890      2370.0      2300.0      2670.0
# ...

# %%
m = SocSci2.mean(axis=1)
for i, col in enumerate(SocSci2):
    SocSci2.iloc[:, i] = SocSci2.iloc[:, i].fillna(m)
SocSci2 = SocSci2.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15'], axis = 1)

SocSci2 = SocSci2.rename(columns = {'Table S-37':'State',
                                       'Unnamed: 16':'Social Scientists 2018'})

SocSci2.head(10)
# Out:
#                   State  Social Scientists 2018
# 0               Alabama             3195.000000
# 1                Alaska             1090.000000
# 2               Arizona             7870.000000
# 3              Arkansas             2426.923077
# 4            California            50350.000000
# 5              Colorado             8079.230769
# 6           Connecticut             4830.000000
# 7              Delaware             1230.000000
# 8  District of Columbia            18400.000000
# 9               Florida            15880.000000

# %%
SocSci3 = SocSci.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

SocSci3.head()
# Out:
#                                           Table S-37      Unnamed: 18  \
# 0  Social Scientists as a Percentage of All Occup...              NaN
# 1                                                NaN  All occupations
# 2                                              State             2003
# 3                                      United States        127420170
# 4                                            Alabama          1817240
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       2004.0       2005.0       2006.0       2007.0       2008.0
# 3  129146700.0  130307840.0  132604980.0  134354250.0  135185230.0
# 4    1851040.0    1872600.0    1912220.0    1931970.0    1945300.0
#
#    Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
SocSci3.drop(range(0,4), inplace = True)
SocSci3.drop(range(55,64), inplace = True)
SocSci3 = SocSci3.reset_index(drop = True)
SocSci3
# Out:
#               Table S-37 Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0                Alabama     1817240    1851040.0    1872600.0    1912220.0
# 1                 Alaska      290740     295810.0     300150.0     303890.0
# 2                Arizona     2275410    2370810.0    2437100.0    2574150.0
# 3               Arkansas     1118690    1133800.0    1142370.0    1166840.0
# 4             California    14460860   14598250.0   14723900.0   15065750.0
# 5               Colorado     2097650    2130430.0    2151520.0    2207120.0
# 6            Connecticut     1631610    1640840.0    1648070.0    1658980.0
# 7               Delaware      403650     413940.0     417550.0     424270.0
# 8   District of Columbia      595220     609770.0     611190.0     609400.0
# 9                Florida     7217400    7479050.0    7614840.0    7869210.0
# 10               Georgia     3770430    3848740.0    3904020.0    4001580.0
# ...

# %%
m = SocSci3.mean(axis=1)
for i, col in enumerate(SocSci3):
    SocSci3.iloc[:, i] = SocSci3.iloc[:, i].fillna(m)
SocSci3 = SocSci3.drop(['Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',], axis = 1)

SocSci3 = SocSci3.rename(columns = {'Table S-37':'State',
                                       'Unnamed: 33':'All Occupations 2018'})

SocSci3.head(10)
# Out:
#                   State  All Occupations 2018
# 0               Alabama             1943760.0
# 1                Alaska              315250.0
# 2               Arizona             2789520.0
# 3              Arkansas             1210120.0
# 4            California            17007690.0
# 5              Colorado             2620640.0
# 6           Connecticut             1660200.0
# 7              Delaware              448510.0
# 8  District of Columbia              712370.0
# 9               Florida             8608660.0

# %%
SocSci4 = SocSci.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
                          'Unnamed: 34',], axis = 1)

SocSci4.head()
# Out:
#                                           Table S-37  \
# 0  Social Scientists as a Percentage of All Occup...
# 1                                                NaN
# 2                                              State
# 3                                      United States
# 4                                            Alabama
#
#                                       Unnamed: 35  Unnamed: 36  Unnamed: 37  \
# 0                                             NaN          NaN          NaN
# 1  Social scientists in all occupations (Percent)          NaN          NaN
# 2                                            2003  2004.000000  2005.000000
# 3                                        0.361842     0.385050     0.397482
# 4                                        0.190949     0.220957     0.228025
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
SocSci4.drop(range(0,4), inplace = True)
SocSci4.drop(range(55,64), inplace = True)
SocSci4 = SocSci4.reset_index(drop = True)
SocSci4
# Out:
#               Table S-37 Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 0                Alabama    0.190949     0.220957     0.228025     0.213888
# 1                 Alaska    0.388663     0.388763     0.419790     0.352101
# 2                Arizona    0.337961     0.342921     0.343851     0.332925
# 3               Arkansas    0.201128     0.233727     0.218843     0.207398
# 4             California    0.390986     0.414707     0.427468     0.421287
# 5               Colorado     0.41761     0.399450     0.399717     0.437674
# 6            Connecticut    0.533829     0.536311     0.523643     0.468360
# 7               Delaware    0.473182     0.526646     0.421506     0.702383
# 8   District of Columbia     2.24623     2.586221     2.927077     2.840499
# 9                Florida     0.27503     0.309264     0.333953     0.312230
# 10               Georgia      0.2692     0.268400     0.292775     0.288386
# ...

# %%
m = SocSci4.mean(axis=1)
for i, col in enumerate(SocSci4):
    SocSci4.iloc[:, i] = SocSci4.iloc[:, i].fillna(m)
SocSci4 = SocSci4.drop(['Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49'], axis = 1)

SocSci4 = SocSci4.rename(columns = {'Table S-37':'State',
                                       'Unnamed: 50':'Social Scientists 2018 (Percent)'})

SocSci4.head(10)
# Out:
#                   State  Social Scientists 2018 (Percent)
# 0               Alabama                          0.170005
# 1                Alaska                          0.345757
# 2               Arizona                          0.282127
# 3              Arkansas                          0.209530
# 4            California                          0.296043
# 5              Colorado                          0.353777
# 6           Connecticut                          0.290929
# 7              Delaware                          0.274241
# 8  District of Columbia                          2.582927
# 9               Florida                          0.184465

# %%
SocSciDF = [SocSci2, SocSci3, SocSci4]

SocSciFinal = reduce(lambda left, right: pd.merge(left, right, on = 'State', how = 'outer'), SocSciDF)

SocSciFinal
# Out:
#                    State  Social Scientists 2018  All Occupations 2018  \
# 0                Alabama             3195.000000             1943760.0
# 1                 Alaska             1090.000000              315250.0
# 2                Arizona             7870.000000             2789520.0
# 3               Arkansas             2426.923077             1210120.0
# 4             California            50350.000000            17007690.0
# 5               Colorado             8079.230769             2620640.0
# 6            Connecticut             4830.000000             1660200.0
# 7               Delaware             1230.000000              448510.0
# 8   District of Columbia            18400.000000              712370.0
# 9                Florida            15880.000000             8608660.0
# 10               Georgia             9520.000000             4394740.0
# 11                Hawaii             2480.000000              641790.0
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDSocSci = pd.merge(COVIDCases, SocSciFinal, how = 'left', on = 'State')
COVIDSocSci
# Out:
#                    State  fips     cases   deaths  Social Scientists 2018  \
# 0                Alabama    73    387786    14345             3195.000000
# 1                 Alaska   148     18316      367             1090.000000
# 2                Arizona   480    426614    18857             7870.000000
# 3               Arkansas   375    161569     3301             2426.923077
# 4             California   726   2664110   102387            50350.000000
# 5               Colorado   648    766512    37828             8079.230769
# 6            Connecticut   702   1314995   104185             4830.000000
# 7               Delaware   750    234327     7813             1230.000000
# 8   District of Columbia   869    229466    10822            18400.000000
# 9                Florida  1020   1726811    63147            15880.000000
# 10               Georgia  1092   1282091    54209             9520.000000
# 11                Hawaii  1200     31433      681             2480.000000
# ...

# %%
COVIDSocSci = COVIDSocSci.drop(['fips'], axis = 1)
COVIDSocSci
# Out:
#                    State     cases   deaths  Social Scientists 2018  \
# 0                Alabama    387786    14345             3195.000000
# 1                 Alaska     18316      367             1090.000000
# 2                Arizona    426614    18857             7870.000000
# 3               Arkansas    161569     3301             2426.923077
# 4             California   2664110   102387            50350.000000
# 5               Colorado    766512    37828             8079.230769
# 6            Connecticut   1314995   104185             4830.000000
# 7               Delaware    234327     7813             1230.000000
# 8   District of Columbia    229466    10822            18400.000000
# 9                Florida   1726811    63147            15880.000000
# 10               Georgia   1282091    54209             9520.000000
# 11                Hawaii     31433      681             2480.000000
# 12                 Idaho    103987     2828             1340.000000
# ...

# %%
COVIDSocSci.to_csv('SocSci_jobs.csv')
