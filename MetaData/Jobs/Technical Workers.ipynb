# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
TechWork = pd.read_excel('technical-workers-to-all-occupations.xlsx')
TechWork
# Out:
#                                            Table S-39         Unnamed: 1  \
# 0   Technical Workers as a Percentage of All Occup...                NaN
# 1                                                 NaN  Technical workers
# 2                                               State               2003
# 3                                       United States            2046150
# 4                                             Alabama              27880
# ..                                                ...                ...
# 59  NOTES: Occupational Employment Statistics (OES...                NaN
# 60  SOURCE: Bureau of Labor Statistics, special ta...                NaN
# 61  Recommended Citation: National Science Board. ...                NaN
# 62                   Last updated: September 24, 2019                NaN
# 63                 Science and Engineering Indicators                NaN
#
#     Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# ...

# %%
TechWork2 = TechWork.drop(['Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
                          'Unnamed: 34', 'Unnamed: 33', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

TechWork2.head()
# Out:
#                                           Table S-39         Unnamed: 1  \
# 0  Technical Workers as a Percentage of All Occup...                NaN
# 1                                                NaN  Technical workers
# 2                                              State               2003
# 3                                      United States            2046150
# 4                                            Alabama              27880
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2      2004.0      2005.0      2006.0      2007.0      2008.0      2009.0
# 3   2030040.0   2022670.0   2034070.0   2054960.0   2071260.0   1989840.0
# 4     28190.0     28700.0     27300.0     26170.0     25000.0     25310.0
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# ...

# %%
TechWork2.drop(range(0,4), inplace = True)
TechWork2.drop(range(55,64), inplace = True)
TechWork2 = TechWork2.reset_index(drop = True)
TechWork2
# Out:
#               Table S-39 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                Alabama      27880     28190.0     28700.0     27300.0
# 1                 Alaska       6420      6530.0      6850.0      6900.0
# 2                Arizona      41120     38870.0     39640.0     42320.0
# 3               Arkansas      11950     12160.0     12710.0     12810.0
# 4             California        NaN    244920.0    240060.0         NaN
# 5               Colorado      40620     39310.0     39570.0     38760.0
# 6            Connecticut      30530     29770.0     29890.0     29700.0
# 7               Delaware       8060      8070.0      7420.0      7910.0
# 8   District of Columbia      12590     12960.0     12490.0     11870.0
# 9                Florida      98180     99880.0     97880.0    100520.0
# 10               Georgia      55790     55470.0     55530.0     53720.0
# 11                Hawaii       6260      6910.0      7140.0      7200.0
# ...

# %%
m = TechWork2.mean(axis=1)
for i, col in enumerate(TechWork2):
    TechWork2.iloc[:, i] = TechWork2.iloc[:, i].fillna(m)
TechWork2 = TechWork2.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15'], axis = 1)

TechWork2 = TechWork2.rename(columns = {'Table S-39':'State',
                                       'Unnamed: 16':'Technical Workers 2018'})

TechWork2.head(10)
# Out:
#                   State  Technical Workers 2018
# 0               Alabama            25768.461538
# 1                Alaska             6370.000000
# 2               Arizona            40286.923077
# 3              Arkansas            11790.000000
# 4            California           266500.000000
# 5              Colorado            39090.000000
# 6           Connecticut            27020.000000
# 7              Delaware             5870.000000
# 8  District of Columbia            10760.000000
# 9               Florida            83360.000000

# %%
TechWork3 = TechWork.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

TechWork3.head()
# Out:
#                                           Table S-39      Unnamed: 18  \
# 0  Technical Workers as a Percentage of All Occup...              NaN
# 1                                                NaN  All occupations
# 2                                              State             2003
# 3                                      United States        127420170
# 4                                            Alabama          1817240
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       2004.0       2005.0       2006.0       2007.0       2008.0
# 3  129146700.0  130307840.0  132604980.0  134354250.0  135185230.0
# 4    1851040.0    1872600.0    1912220.0    1931970.0    1945300.0
#
#    Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
TechWork3.drop(range(0,4), inplace = True)
TechWork3.drop(range(55,64), inplace = True)
TechWork3 = TechWork3.reset_index(drop = True)
TechWork3
# Out:
#               Table S-39 Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0                Alabama     1817240    1851040.0    1872600.0    1912220.0
# 1                 Alaska      290740     295810.0     300150.0     303890.0
# 2                Arizona     2275410    2370810.0    2437100.0    2574150.0
# 3               Arkansas     1118690    1133800.0    1142370.0    1166840.0
# 4             California    14460860   14598250.0   14723900.0   15065750.0
# 5               Colorado     2097650    2130430.0    2151520.0    2207120.0
# 6            Connecticut     1631610    1640840.0    1648070.0    1658980.0
# 7               Delaware      403650     413940.0     417550.0     424270.0
# 8   District of Columbia      595220     609770.0     611190.0     609400.0
# 9                Florida     7217400    7479050.0    7614840.0    7869210.0
# 10               Georgia     3770430    3848740.0    3904020.0    4001580.0
# ...

# %%
m = TechWork3.mean(axis=1)
for i, col in enumerate(TechWork3):
    TechWork3.iloc[:, i] = TechWork3.iloc[:, i].fillna(m)
TechWork3 = TechWork3.drop(['Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',], axis = 1)

TechWork3 = TechWork3.rename(columns = {'Table S-39':'State',
                                       'Unnamed: 33':'All Occupations 2018'})

TechWork3.head(10)
# Out:
#                   State  All Occupations 2018
# 0               Alabama             1943760.0
# 1                Alaska              315250.0
# 2               Arizona             2789520.0
# 3              Arkansas             1210120.0
# 4            California            17007690.0
# 5              Colorado             2620640.0
# 6           Connecticut             1660200.0
# 7              Delaware              448510.0
# 8  District of Columbia              712370.0
# 9               Florida             8608660.0

# %%
TechWork4 = TechWork.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
                          'Unnamed: 34',], axis = 1)

TechWork4.head()
# Out:
#                                           Table S-39  \
# 0  Technical Workers as a Percentage of All Occup...
# 1                                                NaN
# 2                                              State
# 3                                      United States
# 4                                            Alabama
#
#                                       Unnamed: 35  Unnamed: 36  Unnamed: 37  \
# 0                                             NaN          NaN          NaN
# 1  Technical workers in all occupations (Percent)          NaN          NaN
# 2                                            2003  2004.000000  2005.000000
# 3                                         1.60583     1.571887     1.552224
# 4                                         1.53419     1.522928     1.532628
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
TechWork4.drop(range(0,4), inplace = True)
TechWork4.drop(range(55,64), inplace = True)
TechWork4 = TechWork4.reset_index(drop = True)
TechWork4
# Out:
#               Table S-39 Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 0                Alabama     1.53419     1.522928     1.532628     1.427660
# 1                 Alaska     2.20816     2.207498     2.282192     2.270558
# 2                Arizona     1.80715     1.639524     1.626523     1.644038
# 3               Arkansas     1.06821     1.072500     1.112599     1.097837
# 4             California         NaN     1.677735     1.630410          NaN
# 5               Colorado     1.93645     1.845167     1.839165     1.756135
# 6            Connecticut     1.87116     1.814315     1.813637     1.790257
# 7               Delaware     1.99678     1.949558     1.777033     1.864379
# 8   District of Columbia     2.11518     2.125392     2.043554     1.947818
# 9                Florida     1.36032     1.335464     1.285385     1.277384
# 10               Georgia     1.47967     1.441251     1.422380     1.342470
# ...

# %%
m = TechWork4.mean(axis=1)
for i, col in enumerate(TechWork4):
    TechWork4.iloc[:, i] = TechWork4.iloc[:, i].fillna(m)
TechWork4 = TechWork4.drop(['Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49'], axis = 1)

TechWork4 = TechWork4.rename(columns = {'Table S-39':'State',
                                       'Unnamed: 50':'Technical Workers 2018 (Percent)'})

TechWork4.head(10)
# Out:
#                   State  Technical Workers 2018 (Percent)
# 0               Alabama                          1.377782
# 1                Alaska                          2.020619
# 2               Arizona                          1.608712
# 3              Arkansas                          0.974284
# 4            California                          1.566938
# 5              Colorado                          1.491620
# 6           Connecticut                          1.627515
# 7              Delaware                          1.308778
# 8  District of Columbia                          1.510451
# 9               Florida                          0.968327

# %%
TechWorkDFs = [TechWork2, TechWork3, TechWork4]

TechWorkFinal = reduce(lambda left, right: pd.merge(left, right, on = 'State', how = 'outer'), TechWorkDFs)

TechWorkFinal
# Out:
#                    State  Technical Workers 2018  All Occupations 2018  \
# 0                Alabama            25768.461538             1943760.0
# 1                 Alaska             6370.000000              315250.0
# 2                Arizona            40286.923077             2789520.0
# 3               Arkansas            11790.000000             1210120.0
# 4             California           266500.000000            17007690.0
# 5               Colorado            39090.000000             2620640.0
# 6            Connecticut            27020.000000             1660200.0
# 7               Delaware             5870.000000              448510.0
# 8   District of Columbia            10760.000000              712370.0
# 9                Florida            83360.000000             8608660.0
# 10               Georgia            49720.000000             4394740.0
# 11                Hawaii             6750.000000              641790.0
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDTechWork = pd.merge(COVIDCases, TechWorkFinal, how = 'left', on = 'State')
COVIDTechWork
# Out:
#                    State  fips     cases   deaths  Technical Workers 2018  \
# 0                Alabama    73    387786    14345            25768.461538
# 1                 Alaska   148     18316      367             6370.000000
# 2                Arizona   480    426614    18857            40286.923077
# 3               Arkansas   375    161569     3301            11790.000000
# 4             California   726   2664110   102387           266500.000000
# 5               Colorado   648    766512    37828            39090.000000
# 6            Connecticut   702   1314995   104185            27020.000000
# 7               Delaware   750    234327     7813             5870.000000
# 8   District of Columbia   869    229466    10822            10760.000000
# 9                Florida  1020   1726811    63147            83360.000000
# 10               Georgia  1092   1282091    54209            49720.000000
# 11                Hawaii  1200     31433      681             6750.000000
# ...

# %%
COVIDTechWork = COVIDTechWork.drop(['fips'], axis = 1)
COVIDTechWork
# Out:
#                    State     cases   deaths  Technical Workers 2018  \
# 0                Alabama    387786    14345            25768.461538
# 1                 Alaska     18316      367             6370.000000
# 2                Arizona    426614    18857            40286.923077
# 3               Arkansas    161569     3301            11790.000000
# 4             California   2664110   102387           266500.000000
# 5               Colorado    766512    37828            39090.000000
# 6            Connecticut   1314995   104185            27020.000000
# 7               Delaware    234327     7813             5870.000000
# 8   District of Columbia    229466    10822            10760.000000
# 9                Florida   1726811    63147            83360.000000
# 10               Georgia   1282091    54209            49720.000000
# 11                Hawaii     31433      681             6750.000000
# 12                 Idaho    103987     2828            12110.000000
# ...

# %%
COVIDTechWork.to_csv('TechWork_Jobs.csv')
