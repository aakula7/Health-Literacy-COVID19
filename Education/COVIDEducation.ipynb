# %%
import pandas as pd
import numpy as np

# %%
fourscience = pd.read_excel('fourth-grade-science-performance.xlsx')
fourscience.head()
# Out:
#                                            Table S-3          Unnamed: 1  \
# 0  Fourth Grade Science Performance, by state: 20...                 NaN
# 1                                                NaN  (Score out of 300)
# 2                                              State                2009
# 3                                      United States                 149
# 4                                            Alabama                 143
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2      2015.0
# 3       153.0
# 4       145.0

# %%
fourscience.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Table S-3   61 non-null     object
#  1   Unnamed: 1  49 non-null     object
#  2   Unnamed: 2  48 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB

# %%
fourscience = fourscience.rename(columns = {'Table S-3' : 'State',
                                   'Unnamed: 1' : '4th 2009 Science',
                                   'Unnamed: 2' : '4th 2015 Science'})

fourscience.drop(range(0,4), inplace = True)

fourscience.head()
# Out:
#         State 4th 2009 Science  4th 2015 Science
# 4     Alabama              143             145.0
# 5      Alaska              NaN               NaN
# 6     Arizona              138             149.0
# 7    Arkansas              146             150.0
# 8  California              136             140.0

# %%
fourscience = fourscience.reset_index(drop = True)

fourscience.head()
# Out:
#         State 4th 2009 Science  4th 2015 Science
# 0     Alabama              143             145.0
# 1      Alaska              NaN               NaN
# 2     Arizona              138             149.0
# 3    Arkansas              146             150.0
# 4  California              136             140.0

# %%
fourscience.isna().sum()
# Out:
# State                2
# 4th 2009 Science    14
# 4th 2015 Science    14
# dtype: int64

# %%
fourscience.State
# Out:
# 0                                               Alabama
# 1                                                Alaska
# 2                                               Arizona
# 3                                              Arkansas
# 4                                            California
# 5                                              Colorado
# 6                                           Connecticut
# 7                                              Delaware
# 8                                  District of Columbia
# 9                                               Florida
# 10                                              Georgia
# 11                                               Hawaii
# 12                                                Idaho
# 13                                             Illinois
# 14                                              Indiana
# 15                                                 Iowa
# 16                                               Kansas
# ...

# %%
fourscience.drop(range(51,60), inplace = True)
fourscience.State
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
fourscience.isna().sum()
# Out:
# State               0
# 4th 2009 Science    5
# 4th 2015 Science    5
# dtype: int64

# %%
fourscience = fourscience.fillna(fourscience.mean())
fourscience
# Out:
#                    State  4th 2009 Science  4th 2015 Science
# 0                Alabama        143.000000        145.000000
# 1                 Alaska        151.130435        154.456522
# 2                Arizona        138.000000        149.000000
# 3               Arkansas        146.000000        150.000000
# 4             California        136.000000        140.000000
# 5               Colorado        155.000000        154.456522
# 6            Connecticut        156.000000        154.000000
# 7               Delaware        153.000000        150.000000
# 8   District of Columbia        151.130435        154.456522
# 9                Florida        151.000000        158.000000
# 10               Georgia        144.000000        152.000000
# 11                Hawaii        140.000000        146.000000
# 12                 Idaho        154.000000        156.000000
# 13              Illinois        148.000000        151.000000
# ...

# %%
fourscience = fourscience.astype({'4th 2009 Science':'int32',
                         '4th 2015 Science':'int32'})

fourscience
# Out:
#                    State  4th 2009 Science  4th 2015 Science
# 0                Alabama               143               145
# 1                 Alaska               151               154
# 2                Arizona               138               149
# 3               Arkansas               146               150
# 4             California               136               140
# 5               Colorado               155               154
# 6            Connecticut               156               154
# 7               Delaware               153               150
# 8   District of Columbia               151               154
# 9                Florida               151               158
# 10               Georgia               144               152
# 11                Hawaii               140               146
# 12                 Idaho               154               156
# 13              Illinois               148               151
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases
# Out:
#             date          state  fips  cases  deaths
# 0     2020-01-21     Washington    53      1       0
# 1     2020-01-22     Washington    53      1       0
# 2     2020-01-23     Washington    53      1       0
# 3     2020-01-24       Illinois    17      1       0
# 4     2020-01-24     Washington    53      1       0
# ...          ...            ...   ...    ...     ...
# 4574  2020-05-24       Virginia    51  36244    1171
# 4575  2020-05-24     Washington    53  20732    1069
# 4576  2020-05-24  West Virginia    54   1771      72
# 4577  2020-05-24      Wisconsin    55  15362     510
# 4578  2020-05-24        Wyoming    56    813      12
#
# [4579 rows x 5 columns]

# %%
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases
# Out:
#                        state  fips     cases   deaths
# 0                    Alabama    73    387786    14345
# 1                     Alaska   148     18316      367
# 2                    Arizona   480    426614    18857
# 3                   Arkansas   375    161569     3301
# 4                 California   726   2664110   102387
# 5                   Colorado   648    766512    37828
# 6                Connecticut   702   1314995   104185
# 7                   Delaware   750    234327     7813
# 8       District of Columbia   869    229466    10822
# 9                    Florida  1020   1726811    63147
# 10                   Georgia  1092   1282091    54209
# 11                      Guam  4686     48340      311
# 12                    Hawaii  1200     31433      681
# 13                     Idaho  1168    103987     2828
# 14                  Illinois  2074   2843621   122000
# 15                   Indiana  1440    920434    53042
# ...

# %%
COVIDCases.state
# Out:
# 0                      Alabama
# 1                       Alaska
# 2                      Arizona
# 3                     Arkansas
# 4                   California
# 5                     Colorado
# 6                  Connecticut
# 7                     Delaware
# 8         District of Columbia
# 9                      Florida
# 10                     Georgia
# 11                        Guam
# 12                      Hawaii
# 13                       Idaho
# 14                    Illinois
# 15                     Indiana
# 16                        Iowa
# 17                      Kansas
# 18                    Kentucky
# 19                   Louisiana
# 20                       Maine
# 21                    Maryland
# 22               Massachusetts
# 23                    Michigan
# 24                   Minnesota
# 25                 Mississippi
# 26                    Missouri
# 27                     Montana
# 28                    Nebraska
# 29                      Nevada
# ...

# %%
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVID4science = pd.merge(COVIDCases, fourscience, how = 'left', on = 'State')
COVID4science
# Out:
#                    State  fips     cases   deaths  4th 2009 Science  \
# 0                Alabama    73    387786    14345               143
# 1                 Alaska   148     18316      367               151
# 2                Arizona   480    426614    18857               138
# 3               Arkansas   375    161569     3301               146
# 4             California   726   2664110   102387               136
# 5               Colorado   648    766512    37828               155
# 6            Connecticut   702   1314995   104185               156
# 7               Delaware   750    234327     7813               153
# 8   District of Columbia   869    229466    10822               151
# 9                Florida  1020   1726811    63147               151
# 10               Georgia  1092   1282091    54209               144
# 11                Hawaii  1200     31433      681               140
# 12                 Idaho  1168    103987     2828               154
# ...

# %%
COVID4science.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             51 non-null     object
#  1   fips              51 non-null     int64
#  2   cases             51 non-null     int64
#  3   deaths            51 non-null     int64
#  4   4th 2009 Science  51 non-null     int32
#  5   4th 2015 Science  51 non-null     int32
# dtypes: int32(2), int64(3), object(1)
# memory usage: 2.4+ KB

# %%
COVID4science = COVID4science.drop(['fips'], axis = 1)
COVID4science
# Out:
#                    State     cases   deaths  4th 2009 Science  \
# 0                Alabama    387786    14345               143
# 1                 Alaska     18316      367               151
# 2                Arizona    426614    18857               138
# 3               Arkansas    161569     3301               146
# 4             California   2664110   102387               136
# 5               Colorado    766512    37828               155
# 6            Connecticut   1314995   104185               156
# 7               Delaware    234327     7813               153
# 8   District of Columbia    229466    10822               151
# 9                Florida   1726811    63147               151
# 10               Georgia   1282091    54209               144
# 11                Hawaii     31433      681               140
# 12                 Idaho    103987     2828               154
# 13              Illinois   2843621   122000               148
# ...

# %%
fourmath = pd.read_excel('fourth-grade-math-performance.xlsx')
fourmath.head()
# Out:
#                                            Table S-1          Unnamed: 1  \
# 0  Fourth Grade Mathematics Performance, by state...                 NaN
# 1                                                NaN  (Score out of 500)
# 2                                              State                2000
# 3                                      United States                 224
# 4                                            Alabama                 217
#
#   Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
# 2       2003       2005      2007.0      2009.0      2011.0      2013.0
# 3        234        237       239.0       239.0       240.0       241.0
# 4        223        225       229.0       228.0       231.0       233.0
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0         NaN         NaN          NaN
# ...

# %%
fourmath = fourmath.rename(columns = {'Table S-1' : 'State',
                                   'Unnamed: 1' : '4th 2000 Math',
                                   'Unnamed: 2' : '4th 2003 Math',
                                   'Unnamed: 3' : '4th 2005 Math',
                                   'Unnamed: 4' : '4th 2007 Math',
                                   'Unnamed: 5' : '4th 2009 Math',
                                   'Unnamed: 6' : '4th 2011 Math',
                                   'Unnamed: 7' : '4th 2013 Math',
                                   'Unnamed: 8' : '4th 2015 Math',
                                   'Unnamed: 9' : '4th 2017 Math',
                                   'Unnamed: 10': '4th 2019 Math' })

fourmath.drop(range(0,4), inplace = True)

fourmath.head()
# Out:
#         State 4th 2000 Math 4th 2003 Math 4th 2005 Math  4th 2007 Math  \
# 4     Alabama           217           223           225          229.0
# 5      Alaska           NaN           233           236          237.0
# 6     Arizona           219           229           230          232.0
# 7    Arkansas           216           229           236          238.0
# 8  California           213           227           230          230.0
#
#    4th 2009 Math  4th 2011 Math  4th 2013 Math  4th 2015 Math  4th 2017 Math  \
# 4          228.0          231.0          233.0          231.0          232.0
# 5          237.0          236.0          236.0          236.0          230.0
# 6          230.0          235.0          240.0          238.0          234.0
# 7          238.0          238.0          240.0          235.0          234.0
# 8          232.0          234.0          234.0          232.0          232.0
#
#    4th 2019 Math
# 4          230.0
# 5          232.0
# 6          238.0
# ...

# %%
fourmath = fourmath.reset_index(drop = True)

fourmath.head()
# Out:
#         State 4th 2000 Math 4th 2003 Math 4th 2005 Math  4th 2007 Math  \
# 0     Alabama           217           223           225          229.0
# 1      Alaska           NaN           233           236          237.0
# 2     Arizona           219           229           230          232.0
# 3    Arkansas           216           229           236          238.0
# 4  California           213           227           230          230.0
#
#    4th 2009 Math  4th 2011 Math  4th 2013 Math  4th 2015 Math  4th 2017 Math  \
# 0          228.0          231.0          233.0          231.0          232.0
# 1          237.0          236.0          236.0          236.0          230.0
# 2          230.0          235.0          240.0          238.0          234.0
# 3          238.0          238.0          240.0          235.0          234.0
# 4          232.0          234.0          234.0          232.0          232.0
#
#    4th 2019 Math
# 0          230.0
# 1          232.0
# 2          238.0
# ...

# %%
fourmath.State
# Out:
# 0                                               Alabama
# 1                                                Alaska
# 2                                               Arizona
# 3                                              Arkansas
# 4                                            California
# 5                                              Colorado
# 6                                           Connecticut
# 7                                              Delaware
# 8                                  District of Columbia
# 9                                               Florida
# 10                                              Georgia
# 11                                               Hawaii
# 12                                                Idaho
# 13                                             Illinois
# 14                                              Indiana
# 15                                                 Iowa
# 16                                               Kansas
# ...

# %%
fourmath.drop(range(51,60), inplace = True)
fourmath.State
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
fourmath = fourmath.fillna(fourmath.mean())
fourmath
# Out:
#                    State  4th 2000 Math  4th 2003 Math  4th 2005 Math  \
# 0                Alabama     217.000000            223            225
# 1                 Alaska     223.853659            233            236
# 2                Arizona     219.000000            229            230
# 3               Arkansas     216.000000            229            236
# 4             California     213.000000            227            230
# 5               Colorado     223.853659            235            239
# 6            Connecticut     234.000000            241            242
# 7               Delaware     223.853659            236            240
# 8   District of Columbia     192.000000            205            211
# 9                Florida     223.853659            234            239
# 10               Georgia     219.000000            230            234
# 11                Hawaii     216.000000            227            230
# ...

# %%
fourmath = fourmath.astype({'4th 2000 Math': 'int32',
                                  '4th 2003 Math': 'int32',
                                  '4th 2005 Math': 'int32',
                                  '4th 2007 Math': 'int32',
                                  '4th 2009 Math': 'int32',
                                  '4th 2011 Math': 'int32',
                                  '4th 2013 Math': 'int32',
                                  '4th 2015 Math': 'int32',
                                  '4th 2017 Math': 'int32',
                                  '4th 2019 Math': 'int32' })

fourmath
# Out:
#                    State  4th 2000 Math  4th 2003 Math  4th 2005 Math  \
# 0                Alabama            217            223            225
# 1                 Alaska            223            233            236
# 2                Arizona            219            229            230
# 3               Arkansas            216            229            236
# 4             California            213            227            230
# 5               Colorado            223            235            239
# 6            Connecticut            234            241            242
# 7               Delaware            223            236            240
# 8   District of Columbia            192            205            211
# 9                Florida            223            234            239
# 10               Georgia            219            230            234
# 11                Hawaii            216            227            230
# ...

# %%
fourmath = fourmath.drop(['4th 2000 Math','4th 2003 Math','4th 2005 Math','4th 2007 Math','4th 2011 Math','4th 2013 Math'], axis = 1)
fourmath
# Out:
#                    State  4th 2009 Math  4th 2015 Math  4th 2017 Math  \
# 0                Alabama            228            231            232
# 1                 Alaska            237            236            230
# 2                Arizona            230            238            234
# 3               Arkansas            238            235            234
# 4             California            232            232            232
# 5               Colorado            243            242            241
# 6            Connecticut            245            240            239
# 7               Delaware            239            239            236
# 8   District of Columbia            219            231            231
# 9                Florida            242            243            246
# 10               Georgia            236            236            236
# 11                Hawaii            236            238            238
# ...

# %%
COVID4math = pd.merge(COVIDCases, fourmath, how = 'left', on = 'State')
COVID4math
# Out:
#                    State  fips     cases   deaths  4th 2009 Math  \
# 0                Alabama    73    387786    14345            228
# 1                 Alaska   148     18316      367            237
# 2                Arizona   480    426614    18857            230
# 3               Arkansas   375    161569     3301            238
# 4             California   726   2664110   102387            232
# 5               Colorado   648    766512    37828            243
# 6            Connecticut   702   1314995   104185            245
# 7               Delaware   750    234327     7813            239
# 8   District of Columbia   869    229466    10822            219
# 9                Florida  1020   1726811    63147            242
# 10               Georgia  1092   1282091    54209            236
# 11                Hawaii  1200     31433      681            236
# 12                 Idaho  1168    103987     2828            241
# ...

# %%
COVID4math = COVID4math.drop(['fips'], axis = 1)
COVID4math
# Out:
#                    State     cases   deaths  4th 2009 Math  4th 2015 Math  \
# 0                Alabama    387786    14345            228            231
# 1                 Alaska     18316      367            237            236
# 2                Arizona    426614    18857            230            238
# 3               Arkansas    161569     3301            238            235
# 4             California   2664110   102387            232            232
# 5               Colorado    766512    37828            243            242
# 6            Connecticut   1314995   104185            245            240
# 7               Delaware    234327     7813            239            239
# 8   District of Columbia    229466    10822            219            231
# 9                Florida   1726811    63147            242            243
# 10               Georgia   1282091    54209            236            236
# 11                Hawaii     31433      681            236            238
# ...

# %%
COVID4sciencemath = pd.merge(COVID4math, fourscience, how = 'left', on = 'State')
COVID4sciencemath
# Out:
#                    State     cases   deaths  4th 2009 Math  4th 2015 Math  \
# 0                Alabama    387786    14345            228            231
# 1                 Alaska     18316      367            237            236
# 2                Arizona    426614    18857            230            238
# 3               Arkansas    161569     3301            238            235
# 4             California   2664110   102387            232            232
# 5               Colorado    766512    37828            243            242
# 6            Connecticut   1314995   104185            245            240
# 7               Delaware    234327     7813            239            239
# 8   District of Columbia    229466    10822            219            231
# 9                Florida   1726811    63147            242            243
# 10               Georgia   1282091    54209            236            236
# 11                Hawaii     31433      681            236            238
# ...

# %%
eightscience = pd.read_excel('eighth-grade-science-performance.xlsx')
eightscience.head()
# Out:
#                                            Table S-7          Unnamed: 1  \
# 0  Eighth Grade Science Performance, by state: 20...                 NaN
# 1                                                NaN  (Score out of 300)
# 2                                              State                2009
# 3                                      United States                 149
# 4                                            Alabama                 139
#
#    Unnamed: 2  Unnamed: 3
# 0         NaN         NaN
# 1         NaN         NaN
# 2      2011.0      2015.0
# 3       151.0       153.0
# 4       140.0       141.0

# %%
eightscience = eightscience.rename(columns = {'Table S-7' : 'State',
                                   'Unnamed: 1' : '8th 2009 science',
                                   'Unnamed: 2' : '8th 2011 science',
                                   'Unnamed: 3' : '8th 2015 science'})

eightscience.drop(range(0,4), inplace = True)

eightscience.head()
# Out:
#         State 8th 2009 science  8th 2011 science  8th 2015 science
# 4     Alabama              139             140.0             141.0
# 5      Alaska              NaN             153.0               NaN
# 6     Arizona              141             144.0             148.0
# 7    Arkansas              144             148.0             148.0
# 8  California              137             140.0             143.0

# %%
eightscience = eightscience.reset_index(drop = True)

eightscience.head()
# Out:
#         State 8th 2009 science  8th 2011 science  8th 2015 science
# 0     Alabama              139             140.0             141.0
# 1      Alaska              NaN             153.0               NaN
# 2     Arizona              141             144.0             148.0
# 3    Arkansas              144             148.0             148.0
# 4  California              137             140.0             143.0

# %%
eightscience.drop(range(51,60), inplace = True)
eightscience.State
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
eightscience = eightscience.fillna(eightscience.mean())
eightscience
# Out:
#                    State  8th 2009 science  8th 2011 science  8th 2015 science
# 0                Alabama        139.000000             140.0        141.000000
# 1                 Alaska        150.695652             153.0        154.586957
# 2                Arizona        141.000000             144.0        148.000000
# 3               Arkansas        144.000000             148.0        148.000000
# 4             California        137.000000             140.0        143.000000
# 5               Colorado        156.000000             161.0        154.586957
# 6            Connecticut        155.000000             155.0        155.000000
# 7               Delaware        148.000000             150.0        149.000000
# 8   District of Columbia        150.695652             112.0        154.586957
# 9                Florida        146.000000             148.0        153.000000
# 10               Georgia        147.000000             151.0        152.000000
# ...

# %%
eightscience = eightscience.astype({'8th 2009 science':'int32',
                                    '8th 2011 science':'int32',
                                    '8th 2015 science':'int32'})

eightscience
# Out:
#                    State  8th 2009 science  8th 2011 science  8th 2015 science
# 0                Alabama               139               140               141
# 1                 Alaska               150               153               154
# 2                Arizona               141               144               148
# 3               Arkansas               144               148               148
# 4             California               137               140               143
# 5               Colorado               156               161               154
# 6            Connecticut               155               155               155
# 7               Delaware               148               150               149
# 8   District of Columbia               150               112               154
# 9                Florida               146               148               153
# 10               Georgia               147               151               152
# ...

# %%
COVID8science = pd.merge(COVIDCases, eightscience, how = 'left', on = 'State')
COVID8science
# Out:
#                    State  fips     cases   deaths  8th 2009 science  \
# 0                Alabama    73    387786    14345               139
# 1                 Alaska   148     18316      367               150
# 2                Arizona   480    426614    18857               141
# 3               Arkansas   375    161569     3301               144
# 4             California   726   2664110   102387               137
# 5               Colorado   648    766512    37828               156
# 6            Connecticut   702   1314995   104185               155
# 7               Delaware   750    234327     7813               148
# 8   District of Columbia   869    229466    10822               150
# 9                Florida  1020   1726811    63147               146
# 10               Georgia  1092   1282091    54209               147
# 11                Hawaii  1200     31433      681               139
# 12                 Idaho  1168    103987     2828               158
# ...

# %%
COVID8science = COVID8science.drop(['fips'], axis = 1)
COVID8science
# Out:
#                    State     cases   deaths  8th 2009 science  \
# 0                Alabama    387786    14345               139
# 1                 Alaska     18316      367               150
# 2                Arizona    426614    18857               141
# 3               Arkansas    161569     3301               144
# 4             California   2664110   102387               137
# 5               Colorado    766512    37828               156
# 6            Connecticut   1314995   104185               155
# 7               Delaware    234327     7813               148
# 8   District of Columbia    229466    10822               150
# 9                Florida   1726811    63147               146
# 10               Georgia   1282091    54209               147
# 11                Hawaii     31433      681               139
# 12                 Idaho    103987     2828               158
# 13              Illinois   2843621   122000               148
# ...

# %%
eightmath = pd.read_excel('eighth-grade-math-performance.xlsx')
eightmath
# Out:
#                                             Table S-5          Unnamed: 1  \
# 0   Eighth Grade Mathematics Performance, by state...                 NaN
# 1                                                 NaN  (Score out of 500)
# 2                                               State                2000
# 3                                       United States                 272
# 4                                             Alabama                 264
# ..                                                ...                 ...
# 59  NOTES: The National Assessment of Educational ...                 NaN
# 60  SOURCE: National Center for Education Statisti...                 NaN
# 61  Recommended Citation: National Science Board. ...                 NaN
# 62                       Last updated: April 29, 2020                 NaN
# 63                 Science and Engineering Indicators                 NaN
#
#    Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# ...

# %%
eightmath = eightmath.rename(columns = {'Table S-5' : 'State',
                                   'Unnamed: 1' : '8th 2000 Math',
                                   'Unnamed: 2' : '8th 2003 Math',
                                   'Unnamed: 3' : '8th 2005 Math',
                                   'Unnamed: 4' : '8th 2007 Math',
                                   'Unnamed: 5' : '8th 2009 Math',
                                   'Unnamed: 6' : '8th 2011 Math',
                                   'Unnamed: 7' : '8th 2013 Math',
                                   'Unnamed: 8' : '8th 2015 Math',
                                   'Unnamed: 9' : '8th 2017 Math',
                                   'Unnamed: 10': '8th 2019 Math' })

eightmath.drop(range(0,4), inplace = True)

eightmath.head()
# Out:
#         State 8th 2000 Math 8th 2003 Math 8th 2005 Math  8th 2007 Math  \
# 4     Alabama           264           262           262          266.0
# 5      Alaska           NaN           279           279          283.0
# 6     Arizona           269           271           274          276.0
# 7    Arkansas           257           266           272          274.0
# 8  California           260           267           269          270.0
#
#    8th 2009 Math  8th 2011 Math  8th 2013 Math  8th 2015 Math  8th 2017 Math  \
# 4          269.0          269.0          269.0          267.0          268.0
# 5          283.0          283.0          282.0          280.0          277.0
# 6          277.0          279.0          280.0          283.0          282.0
# 7          276.0          279.0          278.0          275.0          274.0
# 8          270.0          273.0          276.0          275.0          277.0
#
#    8th 2019 Math
# 4          269.0
# 5          274.0
# 6          280.0
# ...

# %%
eightmath = eightmath.reset_index(drop = True)

eightmath.head()
# Out:
#         State 8th 2000 Math 8th 2003 Math 8th 2005 Math  8th 2007 Math  \
# 0     Alabama           264           262           262          266.0
# 1      Alaska           NaN           279           279          283.0
# 2     Arizona           269           271           274          276.0
# 3    Arkansas           257           266           272          274.0
# 4  California           260           267           269          270.0
#
#    8th 2009 Math  8th 2011 Math  8th 2013 Math  8th 2015 Math  8th 2017 Math  \
# 0          269.0          269.0          269.0          267.0          268.0
# 1          283.0          283.0          282.0          280.0          277.0
# 2          277.0          279.0          280.0          283.0          282.0
# 3          276.0          279.0          278.0          275.0          274.0
# 4          270.0          273.0          276.0          275.0          277.0
#
#    8th 2019 Math
# 0          269.0
# 1          274.0
# 2          280.0
# ...

# %%
eightmath.drop(range(51,60), inplace = True)
eightmath.State
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
eightmath = eightmath.fillna(eightmath.mean())
eightmath
# Out:
#                    State  8th 2000 Math  8th 2003 Math  8th 2005 Math  \
# 0                Alabama        264.000            262            262
# 1                 Alaska        271.225            279            279
# 2                Arizona        269.000            271            274
# 3               Arkansas        257.000            266            272
# 4             California        260.000            267            269
# 5               Colorado        271.225            283            281
# 6            Connecticut        281.000            284            281
# 7               Delaware        271.225            277            281
# 8   District of Columbia        235.000            243            245
# 9                Florida        271.225            271            274
# 10               Georgia        265.000            270            272
# 11                Hawaii        262.000            266            266
# ...

# %%
eightmath = eightmath.astype({'8th 2000 Math': 'int32',
                                  '8th 2003 Math': 'int32',
                                  '8th 2005 Math': 'int32',
                                  '8th 2007 Math': 'int32',
                                  '8th 2009 Math': 'int32',
                                  '8th 2011 Math': 'int32',
                                  '8th 2013 Math': 'int32',
                                  '8th 2015 Math': 'int32',
                                  '8th 2017 Math': 'int32',
                                  '8th 2019 Math': 'int32' })

eightmath
# Out:
#                    State  8th 2000 Math  8th 2003 Math  8th 2005 Math  \
# 0                Alabama            264            262            262
# 1                 Alaska            271            279            279
# 2                Arizona            269            271            274
# 3               Arkansas            257            266            272
# 4             California            260            267            269
# 5               Colorado            271            283            281
# 6            Connecticut            281            284            281
# 7               Delaware            271            277            281
# 8   District of Columbia            235            243            245
# 9                Florida            271            271            274
# 10               Georgia            265            270            272
# 11                Hawaii            262            266            266
# ...

# %%
COVID8math = pd.merge(COVIDCases, eightmath, how = 'left', on = 'State')
COVID8math
# Out:
#                    State  fips     cases   deaths  8th 2000 Math  \
# 0                Alabama    73    387786    14345            264
# 1                 Alaska   148     18316      367            271
# 2                Arizona   480    426614    18857            269
# 3               Arkansas   375    161569     3301            257
# 4             California   726   2664110   102387            260
# 5               Colorado   648    766512    37828            271
# 6            Connecticut   702   1314995   104185            281
# 7               Delaware   750    234327     7813            271
# 8   District of Columbia   869    229466    10822            235
# 9                Florida  1020   1726811    63147            271
# 10               Georgia  1092   1282091    54209            265
# 11                Hawaii  1200     31433      681            262
# 12                 Idaho  1168    103987     2828            277
# ...

# %%
COVID8math = COVID8math.drop(['fips','8th 2000 Math','8th 2003 Math','8th 2005 Math','8th 2007 Math','8th 2011 Math','8th 2013 Math'], axis = 1)
COVID8math
# Out:
#                    State     cases   deaths  8th 2009 Math  8th 2015 Math  \
# 0                Alabama    387786    14345            269            267
# 1                 Alaska     18316      367            283            280
# 2                Arizona    426614    18857            277            283
# 3               Arkansas    161569     3301            276            275
# 4             California   2664110   102387            270            275
# 5               Colorado    766512    37828            287            286
# 6            Connecticut   1314995   104185            289            284
# 7               Delaware    234327     7813            284            280
# 8   District of Columbia    229466    10822            254            263
# 9                Florida   1726811    63147            279            275
# 10               Georgia   1282091    54209            278            279
# 11                Hawaii     31433      681            274            279
# ...

# %%
COVID8sciencemath = pd.merge(COVID8math, eightscience, how = 'left', on = 'State')
COVID8sciencemath
# Out:
#                    State     cases   deaths  8th 2009 Math  8th 2015 Math  \
# 0                Alabama    387786    14345            269            267
# 1                 Alaska     18316      367            283            280
# 2                Arizona    426614    18857            277            283
# 3               Arkansas    161569     3301            276            275
# 4             California   2664110   102387            270            275
# 5               Colorado    766512    37828            287            286
# 6            Connecticut   1314995   104185            289            284
# 7               Delaware    234327     7813            284            280
# 8   District of Columbia    229466    10822            254            263
# 9                Florida   1726811    63147            279            275
# 10               Georgia   1282091    54209            278            279
# 11                Hawaii     31433      681            274            279
# ...

# %%
COVIDEducation = pd.merge(COVID8sciencemath, COVID4sciencemath, how = 'left', on = 'State')
COVIDEducation
# Out:
#                    State   cases_x  deaths_x  8th 2009 Math  8th 2015 Math  \
# 0                Alabama    387786     14345            269            267
# 1                 Alaska     18316       367            283            280
# 2                Arizona    426614     18857            277            283
# 3               Arkansas    161569      3301            276            275
# 4             California   2664110    102387            270            275
# 5               Colorado    766512     37828            287            286
# 6            Connecticut   1314995    104185            289            284
# 7               Delaware    234327      7813            284            280
# 8   District of Columbia    229466     10822            254            263
# 9                Florida   1726811     63147            279            275
# 10               Georgia   1282091     54209            278            279
# ...

# %%
COVIDEducation = COVIDEducation.drop(['cases_y','deaths_y'], axis = 1)
COVIDEducation
# Out:
#                    State   cases_x  deaths_x  8th 2009 Math  8th 2015 Math  \
# 0                Alabama    387786     14345            269            267
# 1                 Alaska     18316       367            283            280
# 2                Arizona    426614     18857            277            283
# 3               Arkansas    161569      3301            276            275
# 4             California   2664110    102387            270            275
# 5               Colorado    766512     37828            287            286
# 6            Connecticut   1314995    104185            289            284
# 7               Delaware    234327      7813            284            280
# 8   District of Columbia    229466     10822            254            263
# 9                Florida   1726811     63147            279            275
# 10               Georgia   1282091     54209            278            279
# ...
