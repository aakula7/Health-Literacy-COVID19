# %%
import pandas as pd
import numpy as np

# %%
PSchSalary = pd.read_excel('public-school-teacher-salaries.xlsx')
PSchSalary
# Out:
#                                             Table S-9 Unnamed: 1  Unnamed: 2  \
# 0   Public School Teacher Salaries, by state: 1990...        NaN         NaN
# 1                                                 NaN  (Dollars)         NaN
# 2                                               State       1990      1991.0
# 3                                       United States      31367     33061.0
# 4                                             Alabama      24828     26874.0
# ..                                                ...        ...         ...
# 59  NOTES: The national average for the United Sta...        NaN         NaN
# 60  SOURCE: National Education Association Ranking...        NaN         NaN
# 61  Recommended Citation: National Science Board. ...        NaN         NaN
# 62                   Last updated: September 24, 2019        NaN         NaN
# 63                 Science and Engineering Indicators        NaN         NaN
#
# ...

# %%
PSchSalary = PSchSalary.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 
                'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 
                'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
               'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
                        'Unnamed: 28'], axis = 1)

PSchSalary.head()
# Out:
#                                            Table S-9  Unnamed: 29
# 0  Public School Teacher Salaries, by state: 1990...          NaN
# 1                                                NaN          NaN
# 2                                              State       2018.0
# 3                                      United States      60477.0
# 4                                            Alabama      50568.0

# %%
PSchSalary = PSchSalary.rename(columns = {'Table S-9':'State',
                                   'Unnamed: 29': 'Public School Salary 2018(Dollars)'})
PSchSalary
# Out:
#                                                 State  \
# 0   Public School Teacher Salaries, by state: 1990...
# 1                                                 NaN
# 2                                               State
# 3                                       United States
# 4                                             Alabama
# ..                                                ...
# 59  NOTES: The national average for the United Sta...
# 60  SOURCE: National Education Association Ranking...
# 61  Recommended Citation: National Science Board. ...
# 62                   Last updated: September 24, 2019
# 63                 Science and Engineering Indicators
#
#     Public School Salary 2018(Dollars)
# 0                                  NaN
# 1                                  NaN
# 2                               2018.0
# 3                              60477.0
# 4                              50568.0
# ..                                 ...
# ...

# %%
PSchSalary.tail(10)
# Out:
#                                                 State  \
# 54                                            Wyoming
# 55                                                NaN
# 56                                        Puerto Rico
# 57                                                NaN
# 58                                NA = not available.
# 59  NOTES: The national average for the United Sta...
# 60  SOURCE: National Education Association Ranking...
# 61  Recommended Citation: National Science Board. ...
# 62                   Last updated: September 24, 2019
# 63                 Science and Engineering Indicators
#
#     Public School Salary 2018(Dollars)
# 54                             58352.0
# 55                                 NaN
# 56                                 NaN
# 57                                 NaN
# 58                                 NaN
# 59                                 NaN
# 60                                 NaN
# 61                                 NaN
# ...

# %%
PSchSalary.drop(range(0, 4), inplace = True)
PSchSalary.drop(range(55,64), inplace = True)
PSchSalary = PSchSalary.reset_index(drop = True)
PSchSalary
# Out:
#                    State  Public School Salary 2018(Dollars)
# 0                Alabama                             50568.0
# 1                 Alaska                             69682.0
# 2                Arizona                             48723.0
# 3               Arkansas                             50544.0
# 4             California                             80680.0
# 5               Colorado                             52701.0
# 6            Connecticut                             74517.0
# 7               Delaware                             61795.0
# 8   District of Columbia                             76486.0
# 9                Florida                             48168.0
# 10               Georgia                             56329.0
# 11                Hawaii                             57866.0
# 12                 Idaho                             49225.0
# 13              Illinois                             65721.0
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDPSchSalary = pd.merge(COVIDCases, PSchSalary, how = 'left', on = 'State')
COVIDPSchSalary
# Out:
#                    State  fips     cases   deaths  \
# 0                Alabama    73    387786    14345
# 1                 Alaska   148     18316      367
# 2                Arizona   480    426614    18857
# 3               Arkansas   375    161569     3301
# 4             California   726   2664110   102387
# 5               Colorado   648    766512    37828
# 6            Connecticut   702   1314995   104185
# 7               Delaware   750    234327     7813
# 8   District of Columbia   869    229466    10822
# 9                Florida  1020   1726811    63147
# 10               Georgia  1092   1282091    54209
# 11                Hawaii  1200     31433      681
# 12                 Idaho  1168    103987     2828
# 13              Illinois  2074   2843621   122000
# 14               Indiana  1440    920434    53042
# 15                  Iowa  1482    396980     9203
# 16                Kansas  1580    231885     6527
# 17              Kentucky  1680    246480    11851
# ...

# %%
COVIDPSchSalary = COVIDPSchSalary.drop(['fips'], axis = 1)
COVIDPSchSalary
# Out:
#                    State     cases   deaths  \
# 0                Alabama    387786    14345
# 1                 Alaska     18316      367
# 2                Arizona    426614    18857
# 3               Arkansas    161569     3301
# 4             California   2664110   102387
# 5               Colorado    766512    37828
# 6            Connecticut   1314995   104185
# 7               Delaware    234327     7813
# 8   District of Columbia    229466    10822
# 9                Florida   1726811    63147
# 10               Georgia   1282091    54209
# 11                Hawaii     31433      681
# 12                 Idaho    103987     2828
# 13              Illinois   2843621   122000
# 14               Indiana    920434    53042
# 15                  Iowa    396980     9203
# 16                Kansas    231885     6527
# 17              Kentucky    246480    11851
# 18             Louisiana   1443404    90609
# 19                 Maine     61284     2451
# ...
