# %%
import pandas as pd
import numpy as np

# %%
PSchExpGDP = pd.read_excel('public-school-expenditures-to-state-gdp.xlsx')
PSchExpGDP
# Out:
#                                            Table S-10  \
# 0   Elementary and Secondary Public School Expendi...
# 1                                                 NaN
# 2                                               State
# 3                                       United States
# 4                                             Alabama
# ..                                                ...
# 59  NOTES: The national total for public school ex...
# 60  SOURCE: National Center for Education Statisti...
# 61  Recommended Citation: National Science Board. ...
# 62                   Last updated: September 24, 2019
# 63                 Science and Engineering Indicators
#
#                                  Unnamed: 1   Unnamed: 2   Unnamed: 3  \
# 0                                       NaN          NaN          NaN
# 1   Public school expenditures ($thousands)          NaN          NaN
# 2                                      1993       1994.0       1995.0
# ...

# %%
PSchExpGDP = PSchExpGDP.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 
                'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 
                'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
               'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
                        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
                        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
                        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46',
                        'Unnamed: 47', 'Unnamed: 48','Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53',
                        'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59',
                        'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65',
                        'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71',
                        'Unnamed: 72', 'Unnamed: 73'], axis = 1)

PSchExpGDP.head()
# Out:
#                                           Table S-10  Unnamed: 24  \
# 0  Elementary and Secondary Public School Expendi...          NaN
# 1                                                NaN          NaN
# 2                                              State       2016.0
# 3                                      United States  599710063.0
# 4                                            Alabama    6885677.0
#
#    Unnamed: 49  Unnamed: 74
# 0          NaN          NaN
# 1          NaN          NaN
# 2       2016.0  2016.000000
# 3   18811150.0     3.188056
# 4     203398.0     3.385322

# %%
PSchExpGDP = PSchExpGDP.rename(columns = {'Table S-10':'State',
                                   'Unnamed: 24': 'Public School Expenditure 2016(Thousands)',
                                   'Unnamed: 49': 'State GDP(Millions)',
                                   'Unnamed: 74': 'School Expenditures per State GDP(Percent)'})
PSchExpGDP
# Out:
#                                                 State  \
# 0   Elementary and Secondary Public School Expendi...
# 1                                                 NaN
# 2                                               State
# 3                                       United States
# 4                                             Alabama
# ..                                                ...
# 59  NOTES: The national total for public school ex...
# 60  SOURCE: National Center for Education Statisti...
# 61  Recommended Citation: National Science Board. ...
# 62                   Last updated: September 24, 2019
# 63                 Science and Engineering Indicators
#
#     Public School Expenditure 2016(Thousands)  State GDP(Millions)  \
# 0                                         NaN                  NaN
# 1                                         NaN                  NaN
# 2                                      2016.0               2016.0
# ...

# %%
PSchExpGDP.tail(10)
# Out:
#                                                 State  \
# 54                                            Wyoming
# 55                                                NaN
# 56                                        Puerto Rico
# 57                                                NaN
# 58                       GDP = gross domestic product
# 59  NOTES: The national total for public school ex...
# 60  SOURCE: National Center for Education Statisti...
# 61  Recommended Citation: National Science Board. ...
# 62                   Last updated: September 24, 2019
# 63                 Science and Engineering Indicators
#
#     Public School Expenditure 2016(Thousands)  State GDP(Millions)  \
# 54                                  1556321.0              35905.0
# 55                                        NaN                  NaN
# 56                                  2970386.0             103961.0
# 57                                        NaN                  NaN
# ...

# %%
PSchExpGDP.drop(range(0, 4), inplace = True)
PSchExpGDP.drop(range(55,64), inplace = True)
PSchExpGDP = PSchExpGDP.reset_index(drop = True)
PSchExpGDP
# Out:
#                    State  Public School Expenditure 2016(Thousands)  \
# 0                Alabama                                  6885677.0
# 1                 Alaska                                  2319662.0
# 2                Arizona                                  8551673.0
# 3               Arkansas                                  4872214.0
# 4             California                                 72003129.0
# 5               Colorado                                  8648369.0
# 6            Connecticut                                 10551327.0
# 7               Delaware                                  1941408.0
# 8   District of Columbia                                  1775833.0
# 9                Florida                                 25621239.0
# 10               Georgia                                 17283295.0
# 11                Hawaii                                  2502117.0
# 12                 Idaho                                  2097992.0
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDPSchExp = pd.merge(COVIDCases, PSchExpGDP, how = 'left', on = 'State')
COVIDPSchExp
# Out:
#                    State  fips     cases   deaths  \
# 0                Alabama    73    387786    14345
# 1                 Alaska   148     18316      367
# 2                Arizona   480    426614    18857
# 3               Arkansas   375    161569     3301
# 4             California   726   2664110   102387
# 5               Colorado   648    766512    37828
# 6            Connecticut   702   1314995   104185
# 7               Delaware   750    234327     7813
# 8   District of Columbia   869    229466    10822
# 9                Florida  1020   1726811    63147
# 10               Georgia  1092   1282091    54209
# 11                Hawaii  1200     31433      681
# 12                 Idaho  1168    103987     2828
# 13              Illinois  2074   2843621   122000
# 14               Indiana  1440    920434    53042
# 15                  Iowa  1482    396980     9203
# 16                Kansas  1580    231885     6527
# 17              Kentucky  1680    246480    11851
# ...

# %%
COVIDPSchExp = COVIDPSchExp.drop(['fips'], axis = 1)
COVIDPSchExp
# Out:
#                    State     cases   deaths  \
# 0                Alabama    387786    14345
# 1                 Alaska     18316      367
# 2                Arizona    426614    18857
# 3               Arkansas    161569     3301
# 4             California   2664110   102387
# 5               Colorado    766512    37828
# 6            Connecticut   1314995   104185
# 7               Delaware    234327     7813
# 8   District of Columbia    229466    10822
# 9                Florida   1726811    63147
# 10               Georgia   1282091    54209
# 11                Hawaii     31433      681
# 12                 Idaho    103987     2828
# 13              Illinois   2843621   122000
# 14               Indiana    920434    53042
# 15                  Iowa    396980     9203
# 16                Kansas    231885     6527
# 17              Kentucky    246480    11851
# 18             Louisiana   1443404    90609
# 19                 Maine     61284     2451
# ...
