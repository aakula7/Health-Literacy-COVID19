# %%
import pandas as pd
import numpy as np

# %%
BachDF = pd.read_excel('bachelors-degree-holders-in-labor-force.xlsx')
BachDF
# Out:
#                                            Table S-31  \
# 0   Bachelor's Degree Holders in the Labor Force, ...
# 1                                                 NaN
# 2                                               State
# 3                                       United States
# 4                                             Alabama
# ..                                                ...
# 58  NOTES: The national labor force total for the ...
# 59  SOURCE: U.S. Census Bureau, special tabulation...
# 60  Recommended Citation: National Science Board. ...
# 61                       Last updated: April 29, 2020
# 62                 Science and Engineering Indicators
#
#                                           Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                                NaN         NaN         NaN
# 1   Labor force participants with bachelor's degrees         NaN         NaN
# 2                                               2005      2006.0      2007.0
# ...

# %%
BachDF.tail(10)
# Out:
#                                            Table S-31 Unnamed: 1  Unnamed: 2  \
# 53                                          Wisconsin     745930    772225.0
# 54                                            Wyoming      63580     62400.0
# 55                                                NaN        NaN         NaN
# 56                                        Puerto Rico     385790    405440.0
# 57                                                NaN        NaN         NaN
# 58  NOTES: The national labor force total for the ...        NaN         NaN
# 59  SOURCE: U.S. Census Bureau, special tabulation...        NaN         NaN
# 60  Recommended Citation: National Science Board. ...        NaN         NaN
# 61                       Last updated: April 29, 2020        NaN         NaN
# 62                 Science and Engineering Indicators        NaN         NaN
#
#     Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# ...

# %%
BachDF.drop([0,1,2,3], inplace = True)
BachDF.drop(range(55,63), inplace = True)

# %%
BachDF.head()
# Out:
#    Table S-31 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 4     Alabama     492565    502925.0    507605.0    533095.0    536210.0
# 5      Alaska      84585     89935.0     89525.0     94140.0     92035.0
# 6     Arizona     698240    748110.0    756520.0    783540.0    807020.0
# 7    Arkansas     265900    267735.0    277020.0    277340.0    282850.0
# 8  California    5181220   5303085.0   5447185.0   5566305.0   5662070.0
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 35  \
# 4    533990.0    549360.0    572805.0    571535.0  ...    24.006859
# 5    103295.0    100540.0    105020.0    103730.0  ...    24.986426
# 6    787640.0    805725.0    840385.0    849330.0  ...    25.795749
# 7    291095.0    306010.0    316445.0    306005.0  ...    20.627466
# 8   5718930.0   5830490.0   6020550.0   6088970.0  ...    30.537578
#
#    Unnamed: 36  Unnamed: 37  Unnamed: 38  Unnamed: 39  Unnamed: 40  \
# ...

# %%
BachDF.tail()
# Out:
#        Table S-31 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 50       Virginia    1298695   1346940.0   1388445.0   1400545.0   1442725.0
# 51     Washington     949695   1008820.0   1022795.0   1050915.0   1077385.0
# 52  West Virginia     163820    165280.0    170980.0    174875.0    176300.0
# 53      Wisconsin     745930    772225.0    790135.0    812365.0    804090.0
# 54        Wyoming      63580     62400.0     66250.0     67545.0     66535.0
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 35  \
# 50   1487740.0   1539620.0   1568095.0   1616385.0  ...    35.347089
# 51   1087285.0   1126340.0   1131995.0   1176675.0  ...    31.334725
# 52    181305.0    191630.0    191040.0    188280.0  ...    21.340854
# 53    829775.0    832600.0    857905.0    872680.0  ...    25.790425
# 54     72930.0     72735.0     74650.0     80780.0  ...    22.406506
#
#     Unnamed: 36  Unnamed: 37  Unnamed: 38  Unnamed: 39  Unnamed: 40  \
# ...

# %%
BachDF = BachDF.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
                      'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 
                     'Unnamed: 13', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
                     'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
                      'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
                      'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
                     'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43'], axis = 1)
BachDF.head()
# Out:
#    Table S-31  Unnamed: 14  Unnamed: 29  Unnamed: 44
# 4     Alabama     624760.0    2219105.0    28.153693
# 5      Alaska     108145.0     371180.0    29.135460
# 6     Arizona    1014830.0    3396895.0    29.875224
# 7    Arkansas     347335.0    1379145.0    25.184807
# 8  California    7115070.0   20038675.0    35.506689

# %%
BachDF = BachDF.reset_index(drop = True)
BachDF.head()
# Out:
#    Table S-31  Unnamed: 14  Unnamed: 29  Unnamed: 44
# 0     Alabama     624760.0    2219105.0    28.153693
# 1      Alaska     108145.0     371180.0    29.135460
# 2     Arizona    1014830.0    3396895.0    29.875224
# 3    Arkansas     347335.0    1379145.0    25.184807
# 4  California    7115070.0   20038675.0    35.506689

# %%
BachDF = BachDF.rename(columns = {'Table S-31':'State',
                                 'Unnamed: 14': 'Labor Force w/ Bachelor 2018',
                                 'Unnamed: 29': 'Labor Force Participants 2018',
                                 'Unnamed: 44': 'Percent of Labor Force w/ Bachelor 2018'})
BachDF.head()
# Out:
#         State  Labor Force w/ Bachelor 2018  Labor Force Participants 2018  \
# 0     Alabama                      624760.0                      2219105.0
# 1      Alaska                      108145.0                       371180.0
# 2     Arizona                     1014830.0                      3396895.0
# 3    Arkansas                      347335.0                      1379145.0
# 4  California                     7115070.0                     20038675.0
#
#    Percent of Labor Force w/ Bachelor 2018
# 0                                28.153693
# 1                                29.135460
# 2                                29.875224
# 3                                25.184807
# 4                                35.506689

# %%
BachDF.tail()
# Out:
#             State  Labor Force w/ Bachelor 2018  \
# 46       Virginia                     1797625.0
# 47     Washington                     1440765.0
# 48  West Virginia                      201375.0
# 49      Wisconsin                      962100.0
# 50        Wyoming                       78605.0
#
#     Labor Force Participants 2018  Percent of Labor Force w/ Bachelor 2018
# 46                      4364135.0                                41.190866
# 47                      3858830.0                                37.336835
# 48                       787455.0                                25.572890
# 49                      3091945.0                                31.116336
# 50                       299120.0                                26.278751

# %%
BachDF = BachDF.astype({'Labor Force w/ Bachelor 2018':'int32',
                        'Labor Force Participants 2018':'int32'})

BachDF.head()
# Out:
#         State  Labor Force w/ Bachelor 2018  Labor Force Participants 2018  \
# 0     Alabama                        624760                        2219105
# 1      Alaska                        108145                         371180
# 2     Arizona                       1014830                        3396895
# 3    Arkansas                        347335                        1379145
# 4  California                       7115070                       20038675
#
#    Percent of Labor Force w/ Bachelor 2018
# 0                                28.153693
# 1                                29.135460
# 2                                29.875224
# 3                                25.184807
# 4                                35.506689

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDBach = pd.merge(COVIDCases, BachDF, how = 'left', on = 'State')
COVIDBach
# Out:
#                    State  fips     cases   deaths  \
# 0                Alabama    73    387786    14345
# 1                 Alaska   148     18316      367
# 2                Arizona   480    426614    18857
# 3               Arkansas   375    161569     3301
# 4             California   726   2664110   102387
# 5               Colorado   648    766512    37828
# 6            Connecticut   702   1314995   104185
# 7               Delaware   750    234327     7813
# 8   District of Columbia   869    229466    10822
# 9                Florida  1020   1726811    63147
# 10               Georgia  1092   1282091    54209
# 11                Hawaii  1200     31433      681
# 12                 Idaho  1168    103987     2828
# 13              Illinois  2074   2843621   122000
# 14               Indiana  1440    920434    53042
# 15                  Iowa  1482    396980     9203
# 16                Kansas  1580    231885     6527
# 17              Kentucky  1680    246480    11851
# ...

# %%
COVIDBach = COVIDBach.drop(['fips'], axis = 1)
COVIDBach
# Out:
#                    State     cases   deaths  Labor Force w/ Bachelor 2018  \
# 0                Alabama    387786    14345                        624760
# 1                 Alaska     18316      367                        108145
# 2                Arizona    426614    18857                       1014830
# 3               Arkansas    161569     3301                        347335
# 4             California   2664110   102387                       7115070
# 5               Colorado    766512    37828                       1290890
# 6            Connecticut   1314995   104185                        796610
# 7               Delaware    234327     7813                        156250
# 8   District of Columbia    229466    10822                        270905
# 9                Florida   1726811    63147                       3194970
# 10               Georgia   1282091    54209                       1770780
# 11                Hawaii     31433      681                        238705
# ...
