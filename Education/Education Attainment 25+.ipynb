# %%
import pandas as pd
import numpy as np

# %%
Educ = pd.read_excel('Education.xls')
Educ.head()
# Out:
#   Educational attainment for adults age 25 and older for the U.S., States, and counties, 1970-2018  \
# 0  Sources: U.S. Census Bureau, 1970, 1980, 1990,...
# 1  For definitions of rural classifications, see ...
# 2  This table was prepared by USDA, Economic Rese...
# 3                                          FIPS Code
# 4                                              00000
#
#   Unnamed: 1     Unnamed: 2                       Unnamed: 3  \
# 0        NaN            NaN                              NaN
# 1        NaN            NaN                              NaN
# 2        NaN            NaN                              NaN
# 3      State      Area name  2003 Rural-urban Continuum Code
# 4         US  United States                              NaN
#
#                   Unnamed: 4                       Unnamed: 5  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# ...

# %%
Educ.drop(range(0,3), inplace = True)
Educ.drop(4, inplace = True)
Educ.head()
# Out:
#   Educational attainment for adults age 25 and older for the U.S., States, and counties, 1970-2018  \
# 3                                          FIPS Code
# 5                                              01000
# 6                                              01001
# 7                                              01003
# 8                                              01005
#
#   Unnamed: 1      Unnamed: 2                       Unnamed: 3  \
# 3      State       Area name  2003 Rural-urban Continuum Code
# 5         AL         Alabama                              NaN
# 6         AL  Autauga County                                2
# 7         AL  Baldwin County                                4
# 8         AL  Barbour County                                6
#
#                   Unnamed: 4                       Unnamed: 5  \
# 3  2003 Urban Influence Code  2013 Rural-urban Continuum Code
# 5                        NaN                              NaN
# ...

# %%
Educ = Educ.drop(['Educational attainment for adults age 25 and older for the U.S., States, and counties, 1970-2018',
                           'Unnamed: 1', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
                           'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13','Unnamed: 14', 'Unnamed: 15',
                            'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
                            'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
                            'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
                            'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 43',
                 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46'], axis = 1)

Educ.head()
# Out:
#        Unnamed: 2                       Unnamed: 3  \
# 3       Area name  2003 Rural-urban Continuum Code
# 5         Alabama                              NaN
# 6  Autauga County                                2
# 7  Baldwin County                                4
# 8  Barbour County                                6
#
#                                 Unnamed: 39  \
# 3  Less than a high school diploma, 2014-18
# 5                                    470043
# 6                                      4204
# 7                                     14310
# 8                                      4901
#
#                          Unnamed: 40  \
# 3  High school diploma only, 2014-18
# 5                            1020172
# 6                              12119
# 7                              40579
# 8                               6486
#
#                                    Unnamed: 41  \
# 3  Some college or associate's degree, 2014-18
# 5                                       987148
# ...

# %%
Educ = Educ[pd.isnull(Educ['Unnamed: 3'])]
Educ = Educ.reset_index(drop = True)
Educ
# Out:
#                    Unnamed: 2 Unnamed: 3 Unnamed: 39 Unnamed: 40 Unnamed: 41  \
# 0                     Alabama        NaN      470043     1020172      987148
# 1                      Alaska        NaN       34760      133851      169471
# 2            Aleutian Islands        NaN         NaN         NaN         NaN
# 3   Hoonah-Angoon Census Area        NaN         143         598         546
# 4          Kuskokwim Division        NaN         NaN         NaN         NaN
# ..                        ...        ...         ...         ...         ...
# 56                 Washington        NaN      444721     1109016     1684945
# 57              West Virginia        NaN      174230      523536      332568
# 58                  Wisconsin        NaN      317174     1216570     1236655
# 59                    Wyoming        NaN       27644      111899      145071
# 60                Puerto Rico        NaN      578229      659670      527171
#
#    Unnamed: 42
# 0       822595
# ...

# %%
Educ = Educ.drop(['Unnamed: 3'], axis = 1)
Educ.head()
# Out:
#                   Unnamed: 2 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42
# 0                    Alabama      470043     1020172      987148      822595
# 1                     Alaska       34760      133851      169471      139645
# 2           Aleutian Islands         NaN         NaN         NaN         NaN
# 3  Hoonah-Angoon Census Area         143         598         546         393
# 4         Kuskokwim Division         NaN         NaN         NaN         NaN

# %%
Educ = Educ.rename(columns = {'Unnamed: 2':'State',
                                 'Unnamed: 39': 'Less Than HS Diploma 14-18',
                                 'Unnamed: 40': 'HS Diploma 14-18',
                                 'Unnamed: 41': 'Some College or Associate Degree 14-18',
                             'Unnamed: 42': 'Bachelor Degree or Higher 14-18'})
Educ.head()
# Out:
#                        State Less Than HS Diploma 14-18 HS Diploma 14-18  \
# 0                    Alabama                     470043          1020172
# 1                     Alaska                      34760           133851
# 2           Aleutian Islands                        NaN              NaN
# 3  Hoonah-Angoon Census Area                        143              598
# 4         Kuskokwim Division                        NaN              NaN
#
#   Some College or Associate Degree 14-18 Bachelor Degree or Higher 14-18
# 0                                 987148                          822595
# 1                                 169471                          139645
# 2                                    NaN                             NaN
# 3                                    546                             393
# 4                                    NaN                             NaN

# %%
list(Educ.State)
# Out:
# ['Alabama',
#  'Alaska',
#  'Aleutian Islands',
#  'Hoonah-Angoon Census Area',
#  'Kuskokwim Division',
#  'Petersburg Census Area',
#  'Prince of Wales-Hyder Census Area',
#  'Skagway Municipality',
#  'Skagway-Yakutat-Angoon Census Area',
#  'Upper Yukon Division',
#  'Wrangell City and Borough',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Lousiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
# ...

# %%
Educ = Educ.replace('Lousiana', 'Louisiana')
list(Educ.State)
# Out:
# ['Alabama',
#  'Alaska',
#  'Aleutian Islands',
#  'Hoonah-Angoon Census Area',
#  'Kuskokwim Division',
#  'Petersburg Census Area',
#  'Prince of Wales-Hyder Census Area',
#  'Skagway Municipality',
#  'Skagway-Yakutat-Angoon Census Area',
#  'Upper Yukon Division',
#  'Wrangell City and Borough',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDEduc = pd.merge(COVIDCases, Educ, how = 'left', on = 'State')
COVIDEduc
# Out:
#                    State  fips     cases   deaths  Less Than HS Diploma 14-18  \
# 0                Alabama    73    387786    14345                    470043.0
# 1                 Alaska   148     18316      367                     34760.0
# 2                Arizona   480    426614    18857                    613002.0
# 3               Arkansas   375    161569     3301                    276029.0
# 4             California   726   2664110   102387                   4475565.0
# 5               Colorado   648    766512    37828                    322718.0
# 6            Connecticut   702   1314995   104185                    235826.0
# 7               Delaware   750    234327     7813                     67482.0
# 8   District of Columbia   869    229466    10822                     45805.0
# 9                Florida  1020   1726811    63147                   1769489.0
# 10               Georgia  1092   1282091    54209                    903914.0
# ...

# %%
COVIDEduc.isnull().sum()
# Out:
# State                                     0
# fips                                      0
# cases                                     0
# deaths                                    0
# Less Than HS Diploma 14-18                0
# HS Diploma 14-18                          0
# Some College or Associate Degree 14-18    0
# Bachelor Degree or Higher 14-18           0
# dtype: int64

# %%
COVIDEduc = COVIDEduc.drop(['fips'], axis = 1)
COVIDEduc
# Out:
#                    State     cases   deaths  Less Than HS Diploma 14-18  \
# 0                Alabama    387786    14345                    470043.0
# 1                 Alaska     18316      367                     34760.0
# 2                Arizona    426614    18857                    613002.0
# 3               Arkansas    161569     3301                    276029.0
# 4             California   2664110   102387                   4475565.0
# 5               Colorado    766512    37828                    322718.0
# 6            Connecticut   1314995   104185                    235826.0
# 7               Delaware    234327     7813                     67482.0
# 8   District of Columbia    229466    10822                     45805.0
# 9                Florida   1726811    63147                   1769489.0
# 10               Georgia   1282091    54209                    903914.0
# 11                Hawaii     31433      681                     80696.0
# ...
