# %%
# %matplotlib inline

import pandas as pd
import numpy as np
from functools import reduce
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy import stats
import statsmodels.api as sm
#import mplcursors
from pylab import rcParams
from matplotlib.backends.backend_agg import FigureCanvasAgg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

plt.style.use('seaborn-darkgrid')

# %%
psSalary = pd.read_csv('COVID_PSchSalary.csv',index_col = 0)
psSalary
# Out:
#                    State     cases   deaths  \
# 0                Alabama    387786    14345
# 1                 Alaska     18316      367
# 2                Arizona    426614    18857
# 3               Arkansas    161569     3301
# 4             California   2664110   102387
# 5               Colorado    766512    37828
# 6            Connecticut   1314995   104185
# 7               Delaware    234327     7813
# 8   District of Columbia    229466    10822
# 9                Florida   1726811    63147
# 10               Georgia   1282091    54209
# 11                Hawaii     31433      681
# 12                 Idaho    103987     2828
# 13              Illinois   2843621   122000
# 14               Indiana    920434    53042
# 15                  Iowa    396980     9203
# 16                Kansas    231885     6527
# 17              Kentucky    246480    11851
# 18             Louisiana   1443404    90609
# 19                 Maine     61284     2451
# 20              Maryland   1173802    56126
# 21         Massachusetts   2929874   167711
# 22              Michigan   2023047   171867
# 23             Minnesota    377850    18934
# 24           Mississippi    358459    15047
# 25              Missouri    395952    17924
# 26               Montana     23875      676
# 27              Nebraska    259429     3535
# 28                Nevada    259808    11975
# 29         New Hampshire    117245     4507
# 30            New Jersey   5645458   332869
# 31            New Mexico    177827     6867
# 32              New York  15041806  1081194
# 33        North Carolina    568719    19258
# 34          North Dakota     55932     1219
# 35                  Ohio    908834    47879
# 36              Oklahoma    187462    10394
# 37                Oregon    134979     5067
# 38          Pennsylvania   2320771   127278
# 39          Rhode Island    401931    14251
# 40        South Carolina    313173    11859
# 41          South Dakota    122292     1121
# 42             Tennessee    583792    10198
# 43                 Texas   1553075    41267
# 44                  Utah    245859     2472
# 45               Vermont     45230     2320
# 46              Virginia    866807    28754
# 47            Washington    807848    42371
# 48         West Virginia     56158     1950
# 49             Wisconsin    393823    15587
# 50               Wyoming     28407      281
#
#     Public School Salary 2018(Dollars)
# 0                              50568.0
# 1                              69682.0
# 2                              48723.0
# 3                              50544.0
# 4                              80680.0
# 5                              52701.0
# 6                              74517.0
# 7                              61795.0
# 8                              76486.0
# 9                              48168.0
# 10                             56329.0
# 11                             57866.0
# 12                             49225.0
# 13                             65721.0
# 14                             50614.0
# 15                             57018.0
# 16                             49754.0
# 17                             52952.0
# 18                             50359.0
# 19                             53815.0
# 20                             69627.0
# 21                             80357.0
# 22                             61911.0
# 23                             57782.0
# 24                             44926.0
# 25                             49304.0
# 26                             52776.0
# 27                             54213.0
# 28                             54280.0
# 29                             57833.0
# 30                             69917.0
# 31                             47152.0
# 32                             84227.0
# 33                             51231.0
# 34                             52850.0
# 35                             58000.0
# 36                             46300.0
# 37                             63061.0
# 38                             67535.0
# 39                             66758.0
# 40                             50182.0
# 41                             47631.0
# 42                             50900.0
# 43                             53334.0
# 44                             49655.0
# 45                             60556.0
# 46                             51994.0
# 47                             55693.0
# 48                             45642.0
# 49                             51469.0
# 50                             58352.0

# %%
psSalary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   cases                               51 non-null     int64
#  2   deaths                              51 non-null     int64
#  3   Public School Salary 2018(Dollars)  51 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.0+ KB

# %%
psSalary.isnull().sum()
# Out:
# State                                 0
# cases                                 0
# deaths                                0
# Public School Salary 2018(Dollars)    0
# dtype: int64

# %%
psSalary.describe()
# Out:
#               cases        deaths  Public School Salary 2018(Dollars)
# count  5.100000e+01  5.100000e+01                           51.000000
# mean   1.056306e+06  5.861198e+04                        57313.039216
# std    2.249183e+06  1.579360e+05                         9795.914601
# min    1.831600e+04  2.810000e+02                        44926.000000
# 25%    1.696980e+05  4.021000e+03                        50451.500000
# 50%    3.877860e+05  1.425100e+04                        53815.000000
# 75%    1.047118e+06  5.046050e+04                        61853.000000
# max    1.504181e+07  1.081194e+06                        84227.000000

# %%
corr = psSalary.corr()
corr
# Out:
#                                        cases    deaths  \
# cases                               1.000000  0.990033
# deaths                              0.990033  1.000000
# Public School Salary 2018(Dollars)  0.564535  0.543485
#
#                                     Public School Salary 2018(Dollars)
# cases                                                         0.564535
# deaths                                                        0.543485
# Public School Salary 2018(Dollars)                            1.000000

# %%
plt.figure(figsize = (20,10))
sns.heatmap(corr, cmap = 'BrBG', annot = True, linewidths = 0.5)
plt.title('Public School Salary Correlation Heatmap', fontweight = 'bold', fontsize = 30);

# %%
plt.style.use('seaborn-darkgrid')

psSalary['Public School Salary 2018(Dollars)'].plot(kind = 'hist', color = 'blue', edgecolor = 'black', figsize = (10,7))
plt.title('Public School Salary Histogram', fontsize = 16, fontweight = 'bold')
plt.xlabel('Public School Salary', fontsize = 10, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold');

# %%
fig = plt.figure(figsize = (15,8))

sns.regplot(x = 'Public School Salary 2018(Dollars)', y = 'cases', data = psSalary, color = 'b', scatter_kws = {'linewidths':1, 'edgecolor':'k', 's':100})

plt.title('Public School Salary vs. COVID-19 Case Count', fontsize = 16, fontweight = 'bold')
plt.xlabel('Public School Salary', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Linear Regression', 'Cases'])

plt.show();

# %%
model1 = sm.OLS(psSalary['cases'], psSalary['Public School Salary 2018(Dollars)']).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  cases   R-squared (uncentered):                   0.258
# Model:                            OLS   Adj. R-squared (uncentered):              0.243
# Method:                 Least Squares   F-statistic:                              17.36
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):                    0.000122
# Time:                        02:18:21   Log-Likelihood:                         -815.37
# No. Observations:                  51   AIC:                                      1633.
# Df Residuals:                      50   BIC:                                      1635.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Public School Salary 2018(Dollars)    21.5263      5.167      4.166      0.000      11.149      31.904
# ==============================================================================
# Omnibus:                       92.897   Durbin-Watson:                   2.111
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2005.500
# Skew:                           5.135   Prob(JB):                         0.00
# Kurtosis:                      31.953   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.style.use('seaborn-darkgrid')
fig = plt.figure(figsize = (20,10))

x = psSalary['State'] 
y = psSalary['cases']

plt.scatter(x, y, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, c = psSalary['Public School Salary 2018(Dollars)'], cmap = 'inferno')
plt.title('Public School Salary vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Public School Salary 2018(Dollars)'])

plt.xticks(rotation = 90)

plt.colorbar()
plt.show();

# %%
test_len = int(0.25 * len(psSalary))
train_len = len(psSalary) - test_len
print('Train Set Len: ' + str(train_len))
print('Test Set Len: ' + str(test_len))

train = psSalary[:train_len]
test = psSalary[train_len:]
print('Train Set Shape: ' + str(train.shape))
print('Test Set Shape: ' + str(test.shape))
# Out:
# Train Set Len: 39
# Test Set Len: 12
# Train Set Shape: (39, 4)
# Test Set Shape: (12, 4)

# %%
features_list = ['Public School Salary 2018(Dollars)']
    
target = 'cases'

X_train = train[features_list]
y_train = train[target]
X_test = test[features_list]
y_test = test[target]

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(np.array(X_train).reshape(-1, 1))
y_train_scaled = scaler.fit_transform(np.array(y_train).reshape(-1, 1))
X_test_scaled = scaler.transform(np.array(X_test).reshape(-1, 1))

SVRLinModel = SVR(kernel = 'linear')
SVRLinModel.fit(X_train_scaled, y_train_scaled)

train_predictions_scaled = SVRLinModel.predict(X_train_scaled)
train_predictions = scaler.inverse_transform(train_predictions_scaled)
test_predictions_scaled = SVRLinModel.predict(X_test_scaled)
test_predictions = scaler.inverse_transform(test_predictions_scaled)


MAE = mean_absolute_error(y_test, test_predictions)
MSE = mean_squared_error(y_test, test_predictions)
RMS = sqrt(mean_squared_error(y_test, test_predictions))
R2Score = r2_score(y_test, test_predictions)

print('MAE Value:', MAE)
print('MSE Value:', MSE)
print('RMS Value:', RMS)
print('R2 Score:', R2Score)
# Out:
# MAE Value: 340497.3320433724
# MSE Value: 184189055183.44775
# RMS Value: 429172.52379835286
# R2 Score: -0.001764756388361377
# c:\users\twins\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['cases'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['cases'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = train['State'], y = train_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('Public School Salary Per State (2018) vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Train Predictions'])

plt.xticks(rotation = 90)
plt.show();

# %%
rcParams['figure.figsize'] = 20, 10

plt.figure()

plt.scatter(x = train['State'], y = train['cases'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test['cases'], linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.scatter(x = test['State'], y = test_predictions, linewidths = 1, alpha = 0.7, edgecolor = 'k', s = 100, cmap = 'inferno')
plt.title('Public School Salary Per State (2018) vs. COVID-19 Case Count Per State', fontsize = 16, fontweight = 'bold')
plt.xlabel('State', fontsize = 10, fontweight = 'bold')
plt.ylabel('COVID-19 Case Count', fontsize = 10, fontweight = 'bold')

plt.legend(['Train Data', 'Test Data', 'Test Predictions'])

plt.xticks(rotation = 90)
plt.show();
