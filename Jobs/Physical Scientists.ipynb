# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
PhiSci = pd.read_excel('physical-scientists-to-all-occupations.xlsx')
PhiSci
# Out:
#                                            Table S-36           Unnamed: 1  \
# 0   Physical Scientists as a Percentage of All Occ...                  NaN
# 1                                                 NaN  Physical scientists
# 2                                               State                 2003
# 3                                       United States               271030
# 4                                             Alabama                 3470
# ..                                                ...                  ...
# 59  NOTES: Occupational Employment Statistics (OES...                  NaN
# 60  SOURCE: Bureau of Labor Statistics, special ta...                  NaN
# 61  Recommended Citation: National Science Board. ...                  NaN
# 62                   Last updated: September 24, 2019                  NaN
# 63                 Science and Engineering Indicators                  NaN
#
# ...

# %%
PhiSci2 = PhiSci.drop(['Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
                          'Unnamed: 34', 'Unnamed: 33', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

PhiSci2.head()
# Out:
#                                           Table S-36           Unnamed: 1  \
# 0  Physical Scientists as a Percentage of All Occ...                  NaN
# 1                                                NaN  Physical scientists
# 2                                              State                 2003
# 3                                      United States               271030
# 4                                            Alabama                 3470
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2      2004.0      2005.0      2006.0      2007.0      2008.0      2009.0
# 3    278750.0    280810.0    291380.0    297640.0    301500.0    302980.0
# 4      3270.0      3410.0      2880.0      3050.0      3110.0         NaN
#
# ...

# %%
PhiSci2.drop(range(0,4), inplace = True)
PhiSci2.drop(range(55,64), inplace = True)
PhiSci2 = PhiSci2.reset_index(drop = True)
PhiSci2
# Out:
#               Table S-36 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                Alabama       3470      3270.0      3410.0      2880.0
# 1                 Alaska       1370      1350.0      1340.0      1150.0
# 2                Arizona       3860      4170.0      4100.0      3670.0
# 3               Arkansas       1420      1710.0      1570.0      1390.0
# 4             California      32030     32440.0     32780.0         NaN
# 5               Colorado       7550      7840.0      8910.0      9520.0
# 6            Connecticut       3500      3700.0      3590.0      2920.0
# 7               Delaware       1980      1830.0      2040.0      1550.0
# 8   District of Columbia       3330      3420.0      3680.0      3910.0
# 9                Florida      11290     11920.0     12090.0     12590.0
# 10               Georgia       5020      5670.0      4880.0      4470.0
# 11                Hawaii       1310      1450.0      1420.0      1610.0
# ...

# %%
m = PhiSci2.mean(axis=1)
for i, col in enumerate(PhiSci2):
    PhiSci2.iloc[:, i] = PhiSci2.iloc[:, i].fillna(m)
PhiSci2 = PhiSci2.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15'], axis = 1)

PhiSci2 = PhiSci2.rename(columns = {'Table S-36':'State',
                                       'Unnamed: 16':'Physical Scientists 2018'})

PhiSci2.head(10)
# Out:
#                   State  Physical Scientists 2018
# 0               Alabama               2780.000000
# 1                Alaska               1670.000000
# 2               Arizona               4174.000000
# 3              Arkansas               1462.000000
# 4            California              39360.000000
# 5              Colorado              10467.272727
# 6           Connecticut               3320.000000
# 7              Delaware               2230.000000
# 8  District of Columbia               3570.000000
# 9               Florida              10840.000000

# %%
PhiSci3 = PhiSci.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

PhiSci3.head()
# Out:
#                                           Table S-36      Unnamed: 18  \
# 0  Physical Scientists as a Percentage of All Occ...              NaN
# 1                                                NaN  All occupations
# 2                                              State             2003
# 3                                      United States        127420170
# 4                                            Alabama          1817240
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       2004.0       2005.0       2006.0       2007.0       2008.0
# 3  129146700.0  130307840.0  132604980.0  134354250.0  135185230.0
# 4    1851040.0    1872600.0    1912220.0    1931970.0    1945300.0
#
#    Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
PhiSci3.drop(range(0,4), inplace = True)
PhiSci3.drop(range(55,64), inplace = True)
PhiSci3 = PhiSci3.reset_index(drop = True)
PhiSci3
# Out:
#               Table S-36 Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0                Alabama     1817240    1851040.0    1872600.0    1912220.0
# 1                 Alaska      290740     295810.0     300150.0     303890.0
# 2                Arizona     2275410    2370810.0    2437100.0    2574150.0
# 3               Arkansas     1118690    1133800.0    1142370.0    1166840.0
# 4             California    14460860   14598250.0   14723900.0   15065750.0
# 5               Colorado     2097650    2130430.0    2151520.0    2207120.0
# 6            Connecticut     1631610    1640840.0    1648070.0    1658980.0
# 7               Delaware      403650     413940.0     417550.0     424270.0
# 8   District of Columbia      595220     609770.0     611190.0     609400.0
# 9                Florida     7217400    7479050.0    7614840.0    7869210.0
# 10               Georgia     3770430    3848740.0    3904020.0    4001580.0
# ...

# %%
m = PhiSci3.mean(axis=1)
for i, col in enumerate(PhiSci3):
    PhiSci3.iloc[:, i] = PhiSci3.iloc[:, i].fillna(m)
PhiSci3 = PhiSci3.drop(['Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',], axis = 1)

PhiSci3 = PhiSci3.rename(columns = {'Table S-36':'State',
                                       'Unnamed: 33':'All Occupations 2018'})

PhiSci3.head(10)
# Out:
#                   State  All Occupations 2018
# 0               Alabama             1943760.0
# 1                Alaska              315250.0
# 2               Arizona             2789520.0
# 3              Arkansas             1210120.0
# 4            California            17007690.0
# 5              Colorado             2620640.0
# 6           Connecticut             1660200.0
# 7              Delaware              448510.0
# 8  District of Columbia              712370.0
# 9               Florida             8608660.0

# %%
PhiSci4 = PhiSci.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
                          'Unnamed: 34',], axis = 1)

PhiSci4.head()
# Out:
#                                           Table S-36  \
# 0  Physical Scientists as a Percentage of All Occ...
# 1                                                NaN
# 2                                              State
# 3                                      United States
# 4                                            Alabama
#
#                                         Unnamed: 35  Unnamed: 36  Unnamed: 37  \
# 0                                               NaN          NaN          NaN
# 1  Physical scientists in all occupations (Percent)          NaN          NaN
# 2                                              2003  2004.000000  2005.000000
# 3                                          0.212706     0.215840     0.215497
# 4                                          0.190949     0.176657     0.182100
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
PhiSci4.drop(range(0,4), inplace = True)
PhiSci4.drop(range(55,64), inplace = True)
PhiSci4 = PhiSci4.reset_index(drop = True)
PhiSci4
# Out:
#               Table S-36 Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 0                Alabama    0.190949     0.176657     0.182100     0.150610
# 1                 Alaska    0.471211     0.456374     0.446443     0.378426
# 2                Arizona     0.16964     0.175889     0.168233     0.142571
# 3               Arkansas    0.126934     0.150820     0.137434     0.119125
# 4             California    0.221494     0.222218     0.222631          NaN
# 5               Colorado    0.359927     0.368001     0.414126     0.431331
# 6            Connecticut    0.214512     0.225494     0.217831     0.176012
# 7               Delaware    0.490524     0.442093     0.488564     0.365333
# 8   District of Columbia    0.559457     0.560867     0.602104     0.641615
# 9                Florida    0.156428     0.159379     0.158769     0.159991
# 10               Georgia    0.133141     0.147321     0.124999     0.111706
# ...

# %%
m = PhiSci4.mean(axis=1)
for i, col in enumerate(PhiSci4):
    PhiSci4.iloc[:, i] = PhiSci4.iloc[:, i].fillna(m)
PhiSci4 = PhiSci4.drop(['Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49'], axis = 1)

PhiSci4 = PhiSci4.rename(columns = {'Table S-36':'State',
                                       'Unnamed: 50':'Phsysial Scientists 2018 (Percent)'})

PhiSci4.head(10)
# Out:
#                   State  Phsysial Scientists 2018 (Percent)
# 0               Alabama                            0.143022
# 1                Alaska                            0.529738
# 2               Arizona                            0.164212
# 3              Arkansas                            0.126750
# 4            California                            0.231425
# 5              Colorado                            0.452119
# 6           Connecticut                            0.199976
# 7              Delaware                            0.497202
# 8  District of Columbia                            0.501144
# 9               Florida                            0.125920

# %%
PhiSciDF = [PhiSci2, PhiSci3, PhiSci4]

PhiSciFinal = reduce(lambda left, right: pd.merge(left, right, on = 'State', how = 'outer'), PhiSciDF)

PhiSciFinal
# Out:
#                    State  Physical Scientists 2018  All Occupations 2018  \
# 0                Alabama               2780.000000             1943760.0
# 1                 Alaska               1670.000000              315250.0
# 2                Arizona               4174.000000             2789520.0
# 3               Arkansas               1462.000000             1210120.0
# 4             California              39360.000000            17007690.0
# 5               Colorado              10467.272727             2620640.0
# 6            Connecticut               3320.000000             1660200.0
# 7               Delaware               2230.000000              448510.0
# 8   District of Columbia               3570.000000              712370.0
# 9                Florida              10840.000000             8608660.0
# 10               Georgia               5110.000000             4394740.0
# 11                Hawaii               1630.000000              641790.0
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDPhiSci = pd.merge(COVIDCases, PhiSciFinal, how = 'left', on = 'State')
COVIDPhiSci
# Out:
#                    State  fips     cases   deaths  Physical Scientists 2018  \
# 0                Alabama    73    387786    14345               2780.000000
# 1                 Alaska   148     18316      367               1670.000000
# 2                Arizona   480    426614    18857               4174.000000
# 3               Arkansas   375    161569     3301               1462.000000
# 4             California   726   2664110   102387              39360.000000
# 5               Colorado   648    766512    37828              10467.272727
# 6            Connecticut   702   1314995   104185               3320.000000
# 7               Delaware   750    234327     7813               2230.000000
# 8   District of Columbia   869    229466    10822               3570.000000
# 9                Florida  1020   1726811    63147              10840.000000
# 10               Georgia  1092   1282091    54209               5110.000000
# ...

# %%
COVIDPhiSci = COVIDPhiSci.drop(['fips'], axis = 1)
COVIDPhiSci
# Out:
#                    State     cases   deaths  Physical Scientists 2018  \
# 0                Alabama    387786    14345               2780.000000
# 1                 Alaska     18316      367               1670.000000
# 2                Arizona    426614    18857               4174.000000
# 3               Arkansas    161569     3301               1462.000000
# 4             California   2664110   102387              39360.000000
# 5               Colorado    766512    37828              10467.272727
# 6            Connecticut   1314995   104185               3320.000000
# 7               Delaware    234327     7813               2230.000000
# 8   District of Columbia    229466    10822               3570.000000
# 9                Florida   1726811    63147              10840.000000
# 10               Georgia   1282091    54209               5110.000000
# 11                Hawaii     31433      681               1630.000000
# ...
