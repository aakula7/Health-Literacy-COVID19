# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
Engin = pd.read_excel('engineers-to-all-occupations.xlsx')
Engin
# Out:
#                                            Table S-38 Unnamed: 1  Unnamed: 2  \
# 0   Engineers as a Percentage of All Occupations, ...        NaN         NaN
# 1                                                 NaN  Engineers         NaN
# 2                                               State       2003      2004.0
# 3                                       United States    1465670   1508960.0
# 4                                             Alabama      21660     23050.0
# ..                                                ...        ...         ...
# 59  NOTES: Occupational Employment Statistics (OES...        NaN         NaN
# 60  SOURCE: Bureau of Labor Statistics, special ta...        NaN         NaN
# 61  Recommended Citation: National Science Board. ...        NaN         NaN
# 62                   Last updated: September 24, 2019        NaN         NaN
# 63                 Science and Engineering Indicators        NaN         NaN
#
# ...

# %%
Engin2 = Engin.drop(['Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
                          'Unnamed: 34', 'Unnamed: 33', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

Engin2.head()
# Out:
#                                           Table S-38 Unnamed: 1  Unnamed: 2  \
# 0  Engineers as a Percentage of All Occupations, ...        NaN         NaN
# 1                                                NaN  Engineers         NaN
# 2                                              State       2003      2004.0
# 3                                      United States    1465670   1508960.0
# 4                                            Alabama      21660     23050.0
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2      2005.0      2006.0      2007.0      2008.0      2009.0      2010.0
# 3   1514180.0   1543900.0   1588350.0   1626330.0   1587880.0   1554780.0
# 4     24580.0     26210.0     27860.0     26430.0     26990.0     27480.0
#
# ...

# %%
Engin2.drop(range(0,4), inplace = True)
Engin2.drop(range(55,64), inplace = True)
Engin2 = Engin2.reset_index(drop = True)
Engin2
# Out:
#               Table S-38 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                Alabama      21660     23050.0     24580.0     26210.0
# 1                 Alaska       3570      3410.0      3500.0      3330.0
# 2                Arizona      34500     36630.0     35420.0     35630.0
# 3               Arkansas       5610      6760.0      7130.0      7210.0
# 4             California     212620    227310.0    227820.0    231480.0
# 5               Colorado      35180     34390.0     34010.0     37040.0
# 6            Connecticut      26020     25960.0     25480.0     24070.0
# 7               Delaware       3440      3950.0      4120.0      4810.0
# 8   District of Columbia      10070      9760.0      9500.0      8920.0
# 9                Florida      58300     61830.0     64510.0     67810.0
# 10               Georgia      30060     30620.0     30320.0     30170.0
# 11                Hawaii       4670      4770.0      4740.0      5380.0
# ...

# %%
m = Engin2.mean(axis=1)
for i, col in enumerate(Engin2):
    Engin2.iloc[:, i] = Engin2.iloc[:, i].fillna(m)
Engin2 = Engin2.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15'], axis = 1)

Engin2 = Engin2.rename(columns = {'Table S-38':'State',
                                       'Unnamed: 16':'Engineers 2018'})

Engin2.head(10)
# Out:
#                   State  Engineers 2018
# 0               Alabama         32340.0
# 1                Alaska          5060.0
# 2               Arizona         35180.0
# 3              Arkansas          8190.0
# 4            California        243550.0
# 5              Colorado         45250.0
# 6           Connecticut         27610.0
# 7              Delaware          5090.0
# 8  District of Columbia          8570.0
# 9               Florida         66690.0

# %%
Engin3 = Engin.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

Engin3.head()
# Out:
#                                           Table S-38      Unnamed: 18  \
# 0  Engineers as a Percentage of All Occupations, ...              NaN
# 1                                                NaN  All occupations
# 2                                              State             2003
# 3                                      United States        127420170
# 4                                            Alabama          1817240
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       2004.0       2005.0       2006.0       2007.0       2008.0
# 3  129146700.0  130307840.0  132604980.0  134354250.0  135185230.0
# 4    1851040.0    1872600.0    1912220.0    1931970.0    1945300.0
#
#    Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
Engin3.drop(range(0,4), inplace = True)
Engin3.drop(range(55,64), inplace = True)
Engin3 = Engin3.reset_index(drop = True)
Engin3
# Out:
#               Table S-38 Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0                Alabama     1817240    1851040.0    1872600.0    1912220.0
# 1                 Alaska      290740     295810.0     300150.0     303890.0
# 2                Arizona     2275410    2370810.0    2437100.0    2574150.0
# 3               Arkansas     1118690    1133800.0    1142370.0    1166840.0
# 4             California    14460860   14598250.0   14723900.0   15065750.0
# 5               Colorado     2097650    2130430.0    2151520.0    2207120.0
# 6            Connecticut     1631610    1640840.0    1648070.0    1658980.0
# 7               Delaware      403650     413940.0     417550.0     424270.0
# 8   District of Columbia      595220     609770.0     611190.0     609400.0
# 9                Florida     7217400    7479050.0    7614840.0    7869210.0
# 10               Georgia     3770430    3848740.0    3904020.0    4001580.0
# ...

# %%
m = Engin3.mean(axis=1)
for i, col in enumerate(Engin3):
    Engin3.iloc[:, i] = Engin3.iloc[:, i].fillna(m)
Engin3 = Engin3.drop(['Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',], axis = 1)

Engin3 = Engin3.rename(columns = {'Table S-38':'State',
                                       'Unnamed: 33':'All Occupations 2018'})

Engin3.head(10)
# Out:
#                   State  All Occupations 2018
# 0               Alabama             1943760.0
# 1                Alaska              315250.0
# 2               Arizona             2789520.0
# 3              Arkansas             1210120.0
# 4            California            17007690.0
# 5              Colorado             2620640.0
# 6           Connecticut             1660200.0
# 7              Delaware              448510.0
# 8  District of Columbia              712370.0
# 9               Florida             8608660.0

# %%
Engin4 = Engin.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
                          'Unnamed: 34',], axis = 1)

Engin4.head()
# Out:
#                                           Table S-38  \
# 0  Engineers as a Percentage of All Occupations, ...
# 1                                                NaN
# 2                                              State
# 3                                      United States
# 4                                            Alabama
#
#                               Unnamed: 35  Unnamed: 36  Unnamed: 37  \
# 0                                     NaN          NaN          NaN
# 1  Engineers in all occupations (Percent)          NaN          NaN
# 2                                    2003  2004.000000  2005.000000
# 3                                 1.15027     1.168408     1.162002
# 4                                 1.19192     1.245246     1.312613
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# ...

# %%
Engin4.drop(range(0,4), inplace = True)
Engin4.drop(range(55,64), inplace = True)
Engin4 = Engin4.reset_index(drop = True)
Engin4
# Out:
#               Table S-38 Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 0                Alabama     1.19192     1.245246     1.312613     1.370658
# 1                 Alaska      1.2279     1.152767     1.166084     1.095791
# 2                Arizona     1.51621     1.545042     1.453367     1.384146
# 3               Arkansas    0.501479     0.596225     0.624141     0.617908
# 4             California     1.47031     1.557104     1.547280     1.536465
# 5               Colorado     1.67711     1.614228     1.580743     1.678205
# 6            Connecticut     1.59474     1.582116     1.546051     1.450892
# 7               Delaware    0.852223     0.954245     0.986708     1.133712
# 8   District of Columbia     1.69181     1.600604     1.554345     1.463735
# 9                Florida     0.80777     0.826709     0.847162     0.861713
# 10               Georgia    0.797257     0.795585     0.776635     0.753952
# ...

# %%
m = Engin4.mean(axis=1)
for i, col in enumerate(Engin4):
    Engin4.iloc[:, i] = Engin4.iloc[:, i].fillna(m)
Engin4 = Engin4.drop(['Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49'], axis = 1)

Engin4 = Engin4.rename(columns = {'Table S-38':'State',
                                       'Unnamed: 50':'Engineers 2018 (Percent)'})

Engin4.head(10)
# Out:
#                   State  Engineers 2018 (Percent)
# 0               Alabama                  1.663786
# 1                Alaska                  1.605075
# 2               Arizona                  1.261149
# 3              Arkansas                  0.676792
# 4            California                  1.431999
# 5              Colorado                  1.726677
# 6           Connecticut                  1.663053
# 7              Delaware                  1.134869
# 8  District of Columbia                  1.203027
# 9               Florida                  0.774685

# %%
EnginDFs = [Engin2, Engin3, Engin4]

EnginFinal = reduce(lambda left, right: pd.merge(left, right, on = 'State', how = 'outer'), EnginDFs)

EnginFinal
# Out:
#                    State  Engineers 2018  All Occupations 2018  \
# 0                Alabama    32340.000000             1943760.0
# 1                 Alaska     5060.000000              315250.0
# 2                Arizona    35180.000000             2789520.0
# 3               Arkansas     8190.000000             1210120.0
# 4             California   243550.000000            17007690.0
# 5               Colorado    45250.000000             2620640.0
# 6            Connecticut    27610.000000             1660200.0
# 7               Delaware     5090.000000              448510.0
# 8   District of Columbia     8570.000000              712370.0
# 9                Florida    66690.000000             8608660.0
# 10               Georgia    45900.000000             4394740.0
# 11                Hawaii     5910.000000              641790.0
# 12                 Idaho    10000.000000              706140.0
# 13              Illinois    60950.000000             5991270.0
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDEngin = pd.merge(COVIDCases, EnginFinal, how = 'left', on = 'State')
COVIDEngin
# Out:
#                    State  fips     cases   deaths  Engineers 2018  \
# 0                Alabama    73    387786    14345    32340.000000
# 1                 Alaska   148     18316      367     5060.000000
# 2                Arizona   480    426614    18857    35180.000000
# 3               Arkansas   375    161569     3301     8190.000000
# 4             California   726   2664110   102387   243550.000000
# 5               Colorado   648    766512    37828    45250.000000
# 6            Connecticut   702   1314995   104185    27610.000000
# 7               Delaware   750    234327     7813     5090.000000
# 8   District of Columbia   869    229466    10822     8570.000000
# 9                Florida  1020   1726811    63147    66690.000000
# 10               Georgia  1092   1282091    54209    45900.000000
# 11                Hawaii  1200     31433      681     5910.000000
# 12                 Idaho  1168    103987     2828    10000.000000
# ...

# %%
COVIDEngin = COVIDEngin.drop(['fips'], axis = 1)
COVIDEngin
# Out:
#                    State     cases   deaths  Engineers 2018  \
# 0                Alabama    387786    14345    32340.000000
# 1                 Alaska     18316      367     5060.000000
# 2                Arizona    426614    18857    35180.000000
# 3               Arkansas    161569     3301     8190.000000
# 4             California   2664110   102387   243550.000000
# 5               Colorado    766512    37828    45250.000000
# 6            Connecticut   1314995   104185    27610.000000
# 7               Delaware    234327     7813     5090.000000
# 8   District of Columbia    229466    10822     8570.000000
# 9                Florida   1726811    63147    66690.000000
# 10               Georgia   1282091    54209    45900.000000
# 11                Hawaii     31433      681     5910.000000
# 12                 Idaho    103987     2828    10000.000000
# 13              Illinois   2843621   122000    60950.000000
# 14               Indiana    920434    53042    37300.000000
# ...
