# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
SciEng = pd.read_excel('se-occupations-to-all-occupations.xlsx')
SciEng
# Out:
#                                            Table S-32  \
# 0   Individuals in Science and Engineering Occupat...
# 1                                                 NaN
# 2                                               State
# 3                                       United States
# 4                                             Alabama
# ..                                                ...
# 59  NOTES: Occupational Employment Statistics (OES...
# 60  SOURCE: Bureau of Labor Statistics, special ta...
# 61  Recommended Citation: National Science Board. ...
# 62                   Last updated: September 24, 2019
# 63                 Science and Engineering Indicators
#
#                         Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                              NaN         NaN         NaN         NaN
# 1   Individuals in S&E occupations         NaN         NaN         NaN
# 2                             2003      2004.0      2005.0      2006.0
# ...

# %%
SciEng2 = SciEng.drop(['Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
                          'Unnamed: 34', 'Unnamed: 33', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

SciEng2.head()
# Out:
#                                           Table S-32  \
# 0  Individuals in Science and Engineering Occupat...
# 1                                                NaN
# 2                                              State
# 3                                      United States
# 4                                            Alabama
#
#                        Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                             NaN         NaN         NaN         NaN
# 1  Individuals in S&E occupations         NaN         NaN         NaN
# 2                            2003      2004.0      2005.0      2006.0
# 3                         4961540   5174260.0   5233520.0   5407710.0
# 4                           56380     59880.0     62790.0     66100.0
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0         NaN         NaN         NaN         NaN         NaN          NaN
# ...

# %%
SciEng2.drop(range(0,4), inplace = True)
SciEng2.drop(range(55,64), inplace = True)
SciEng2 = SciEng2.reset_index(drop = True)
SciEng2
# Out:
#               Table S-32 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                Alabama      56380     59880.0     62790.0     66100.0
# 1                 Alaska      10600     10870.0     11230.0     10720.0
# 2                Arizona      92120     98400.0     96410.0     98110.0
# 3               Arkansas      21340     24170.0     24660.0     24860.0
# 4             California     676180    703250.0    716530.0         NaN
# 5               Colorado     124140    125510.0    126110.0    133730.0
# 6            Connecticut      81380     83840.0     83930.0     79380.0
# 7               Delaware      17370     18420.0     18010.0     21550.0
# 8   District of Columbia      54890     61460.0     63410.0     64120.0
# 9                Florida     221070    235170.0    241000.0    246190.0
# 10               Georgia     144170    139230.0    137580.0    136470.0
# 11                Hawaii      16090     17630.0     17460.0     18940.0
# ...

# %%
m = SciEng2.mean(axis=1)
for i, col in enumerate(SciEng2):
    SciEng2.iloc[:, i] = SciEng2.iloc[:, i].fillna(m)
SciEng2 = SciEng2.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15'], axis = 1)

SciEng2 = SciEng2.rename(columns = {'Table S-32':'State',
                                       'Unnamed: 16':'Science Engineer Workers 2018'})

SciEng2.head(10)
# Out:
#                   State  Science Engineer Workers 2018
# 0               Alabama                   69821.428571
# 1                Alaska                   14480.000000
# 2               Arizona                  114216.428571
# 3              Arkansas                   35500.000000
# 4            California                  989560.000000
# 5              Colorado                  187050.000000
# 6           Connecticut                   84100.000000
# 7              Delaware                   26120.000000
# 8  District of Columbia                   74030.000000
# 9               Florida                  304650.000000

# %%
SciEng3 = SciEng.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

SciEng3.head()
# Out:
#                                           Table S-32      Unnamed: 18  \
# 0  Individuals in Science and Engineering Occupat...              NaN
# 1                                                NaN  All occupations
# 2                                              State             2003
# 3                                      United States        127420170
# 4                                            Alabama          1817240
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       2004.0       2005.0       2006.0       2007.0       2008.0
# 3  129146700.0  130307840.0  132604980.0  134354250.0  135185230.0
# 4    1851040.0    1872600.0    1912220.0    1931970.0    1945300.0
#
#    Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
SciEng3.drop(range(0,4), inplace = True)
SciEng3.drop(range(55,64), inplace = True)
SciEng3 = SciEng3.reset_index(drop = True)
SciEng3
# Out:
#               Table S-32 Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0                Alabama     1817240    1851040.0    1872600.0    1912220.0
# 1                 Alaska      290740     295810.0     300150.0     303890.0
# 2                Arizona     2275410    2370810.0    2437100.0    2574150.0
# 3               Arkansas     1118690    1133800.0    1142370.0    1166840.0
# 4             California    14460860   14598250.0   14723900.0   15065750.0
# 5               Colorado     2097650    2130430.0    2151520.0    2207120.0
# 6            Connecticut     1631610    1640840.0    1648070.0    1658980.0
# 7               Delaware      403650     413940.0     417550.0     424270.0
# 8   District of Columbia      595220     609770.0     611190.0     609400.0
# 9                Florida     7217400    7479050.0    7614840.0    7869210.0
# 10               Georgia     3770430    3848740.0    3904020.0    4001580.0
# ...

# %%
m = SciEng3.mean(axis=1)
for i, col in enumerate(SciEng3):
    SciEng3.iloc[:, i] = SciEng3.iloc[:, i].fillna(m)
SciEng3 = SciEng3.drop(['Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',], axis = 1)

SciEng3 = SciEng3.rename(columns = {'Table S-32':'State',
                                       'Unnamed: 33':'All Occupations 2018'})

SciEng3.head(10)
# Out:
#                   State  All Occupations 2018
# 0               Alabama             1943760.0
# 1                Alaska              315250.0
# 2               Arizona             2789520.0
# 3              Arkansas             1210120.0
# 4            California            17007690.0
# 5              Colorado             2620640.0
# 6           Connecticut             1660200.0
# 7              Delaware              448510.0
# 8  District of Columbia              712370.0
# 9               Florida             8608660.0

# %%
SciEng4 = SciEng.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
                          'Unnamed: 34',], axis = 1)

SciEng4.head()
# Out:
#                                           Table S-32  \
# 0  Individuals in Science and Engineering Occupat...
# 1                                                NaN
# 2                                              State
# 3                                      United States
# 4                                            Alabama
#
#                                  Unnamed: 35  Unnamed: 36  Unnamed: 37  \
# 0                                        NaN          NaN          NaN
# 1  S&E occupations/all occupations (Percent)          NaN          NaN
# 2                                       2003  2004.000000  2005.000000
# 3                                    3.89384     4.006498     4.016274
# 4                                    3.10251     3.234938     3.353092
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# ...

# %%
SciEng4.drop(range(0,4), inplace = True)
SciEng4.drop(range(55,64), inplace = True)
SciEng4 = SciEng4.reset_index(drop = True)
SciEng4
# Out:
#               Table S-32 Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 0                Alabama     3.10251     3.234938     3.353092     3.456715
# 1                 Alaska     3.64587     3.674656     3.741463     3.527592
# 2                Arizona      4.0485     4.150480     3.955931     3.811355
# 3               Arkansas     1.90759     2.131769     2.158670     2.130541
# 4             California     4.67593     4.817358     4.866442          NaN
# 5               Colorado     5.91805     5.891299     5.861437     6.059027
# 6            Connecticut     4.98771     5.109578     5.092623     4.784868
# 7               Delaware     4.30323     4.449920     4.313256     5.079313
# 8   District of Columbia      9.2218    10.079210    10.374843    10.521825
# 9                Florida     3.06301     3.144383     3.164873     3.128522
# 10               Georgia      3.8237     3.617548     3.524060     3.410403
# ...

# %%
m = SciEng4.mean(axis=1)
for i, col in enumerate(SciEng4):
    SciEng4.iloc[:, i] = SciEng4.iloc[:, i].fillna(m)
SciEng4 = SciEng4.drop(['Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49'], axis = 1)

SciEng4 = SciEng4.rename(columns = {'Table S-32':'State',
                                       'Unnamed: 50':'Science Engineer Workers 2018 (Percent)'})

SciEng4.head(10)
# Out:
#                   State  Science Engineer Workers 2018 (Percent)
# 0               Alabama                                 3.727577
# 1                Alaska                                 4.593180
# 2               Arizona                                 4.532470
# 3              Arkansas                                 2.933593
# 4            California                                 5.818309
# 5              Colorado                                 7.137569
# 6           Connecticut                                 5.065655
# 7              Delaware                                 5.823727
# 8  District of Columbia                                10.392072
# 9               Florida                                 3.538878

# %%
SciEngDF = [SciEng2, SciEng3, SciEng4]

SciEngFinal = reduce(lambda left, right: pd.merge(left, right, on = 'State', how = 'outer'), SciEngDF)

SciEngFinal
# Out:
#                    State  Science Engineer Workers 2018  All Occupations 2018  \
# 0                Alabama                   69821.428571             1943760.0
# 1                 Alaska                   14480.000000              315250.0
# 2                Arizona                  114216.428571             2789520.0
# 3               Arkansas                   35500.000000             1210120.0
# 4             California                  989560.000000            17007690.0
# 5               Colorado                  187050.000000             2620640.0
# 6            Connecticut                   84100.000000             1660200.0
# 7               Delaware                   26120.000000              448510.0
# 8   District of Columbia                   74030.000000              712370.0
# 9                Florida                  304650.000000             8608660.0
# 10               Georgia                  210710.000000             4394740.0
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDSciEng = pd.merge(COVIDCases, SciEngFinal, how = 'left', on = 'State')
COVIDSciEng
# Out:
#                    State  fips     cases   deaths  \
# 0                Alabama    73    387786    14345
# 1                 Alaska   148     18316      367
# 2                Arizona   480    426614    18857
# 3               Arkansas   375    161569     3301
# 4             California   726   2664110   102387
# 5               Colorado   648    766512    37828
# 6            Connecticut   702   1314995   104185
# 7               Delaware   750    234327     7813
# 8   District of Columbia   869    229466    10822
# 9                Florida  1020   1726811    63147
# 10               Georgia  1092   1282091    54209
# 11                Hawaii  1200     31433      681
# 12                 Idaho  1168    103987     2828
# 13              Illinois  2074   2843621   122000
# 14               Indiana  1440    920434    53042
# 15                  Iowa  1482    396980     9203
# 16                Kansas  1580    231885     6527
# 17              Kentucky  1680    246480    11851
# ...

# %%
COVIDSciEng = COVIDSciEng.drop(['fips'], axis = 1)
COVIDSciEng
# Out:
#                    State     cases   deaths  Science Engineer Workers 2018  \
# 0                Alabama    387786    14345                   69821.428571
# 1                 Alaska     18316      367                   14480.000000
# 2                Arizona    426614    18857                  114216.428571
# 3               Arkansas    161569     3301                   35500.000000
# 4             California   2664110   102387                  989560.000000
# 5               Colorado    766512    37828                  187050.000000
# 6            Connecticut   1314995   104185                   84100.000000
# 7               Delaware    234327     7813                   26120.000000
# 8   District of Columbia    229466    10822                   74030.000000
# 9                Florida   1726811    63147                  304650.000000
# 10               Georgia   1282091    54209                  210710.000000
# ...

# %%
COVIDSciEng.to_csv('SciEng_Jobs.csv')
