# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
LifeSci = pd.read_excel('life-scientists-to-all-occupations.xlsx')
LifeSci
# Out:
#                                            Table S-34       Unnamed: 1  \
# 0   Life Scientists as a Percentage of All Occupat...              NaN
# 1                                                 NaN  Life scientists
# 2                                               State             2003
# 3                                       United States           272510
# 4                                             Alabama             2250
# ..                                                ...              ...
# 59  NOTES: Occupational Employment Statistics (OES...              NaN
# 60  SOURCE: Bureau of Labor Statistics, special ta...              NaN
# 61  Recommended Citation: National Science Board. ...              NaN
# 62                   Last updated: September 24, 2019              NaN
# 63                 Science and Engineering Indicators              NaN
#
#     Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# ...

# %%
LifeSci2 = LifeSci.drop(['Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
                          'Unnamed: 34', 'Unnamed: 33', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

LifeSci2.head()
# Out:
#                                           Table S-34       Unnamed: 1  \
# 0  Life Scientists as a Percentage of All Occupat...              NaN
# 1                                                NaN  Life scientists
# 2                                              State             2003
# 3                                      United States           272510
# 4                                            Alabama             2250
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2      2004.0      2005.0      2006.0      2007.0      2008.0      2009.0
# 3    286130.0    290950.0    291980.0    304720.0    319520.0    329000.0
# 4      2380.0      2350.0      2810.0      4190.0      4460.0      4690.0
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# ...

# %%
LifeSci2.drop(range(0,4), inplace = True)
LifeSci2.drop(range(55,64), inplace = True)
LifeSci2 = LifeSci2.reset_index(drop = True)
LifeSci2
# Out:
#               Table S-34 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                Alabama       2250      2380.0      2350.0      2810.0
# 1                 Alaska       1650      1750.0      1770.0      1860.0
# 2                Arizona       2900      2870.0      2700.0      2790.0
# 3               Arkansas       1530      1540.0      1530.0      1490.0
# 4             California      33370     37380.0     37640.0     40030.0
# 5               Colorado        NaN         NaN      5120.0      4610.0
# 6            Connecticut       4710      4910.0      5050.0      4830.0
# 7               Delaware       1270      1200.0      1140.0      1390.0
# 8   District of Columbia       2320      2560.0      2740.0      2460.0
# 9                Florida       8530      9700.0     10070.0      9510.0
# 10               Georgia       7270      5290.0      5420.0      5350.0
# 11                Hawaii       1140      1610.0      1620.0      1780.0
# ...

# %%
m = LifeSci2.mean(axis=1)
for i, col in enumerate(LifeSci2):
    LifeSci2.iloc[:, i] = LifeSci2.iloc[:, i].fillna(m)
LifeSci2 = LifeSci2.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15'], axis = 1)

LifeSci2 = LifeSci2.rename(columns = {'Table S-34':'State',
                                       'Unnamed: 16':'Life Scientists 2018'})

LifeSci2.head(10)
# Out:
#                   State  Life Scientists 2018
# 0               Alabama                3180.0
# 1                Alaska                1830.0
# 2               Arizona                4480.0
# 3              Arkansas                2210.0
# 4            California               63800.0
# 5              Colorado                7870.0
# 6           Connecticut                4210.0
# 7              Delaware                1260.0
# 8  District of Columbia                2190.0
# 9               Florida               11370.0

# %%
LifeSci3 = LifeSci.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'], axis = 1)

LifeSci3.head()
# Out:
#                                           Table S-34      Unnamed: 18  \
# 0  Life Scientists as a Percentage of All Occupat...              NaN
# 1                                                NaN  All occupations
# 2                                              State             2003
# 3                                      United States        127420170
# 4                                            Alabama          1817240
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       2004.0       2005.0       2006.0       2007.0       2008.0
# 3  129146700.0  130307840.0  132604980.0  134354250.0  135185230.0
# 4    1851040.0    1872600.0    1912220.0    1931970.0    1945300.0
#
#    Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
LifeSci3.drop(range(0,4), inplace = True)
LifeSci3.drop(range(55,64), inplace = True)
LifeSci3 = LifeSci3.reset_index(drop = True)
LifeSci3
# Out:
#               Table S-34 Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0                Alabama     1817240    1851040.0    1872600.0    1912220.0
# 1                 Alaska      290740     295810.0     300150.0     303890.0
# 2                Arizona     2275410    2370810.0    2437100.0    2574150.0
# 3               Arkansas     1118690    1133800.0    1142370.0    1166840.0
# 4             California    14460860   14598250.0   14723900.0   15065750.0
# 5               Colorado     2097650    2130430.0    2151520.0    2207120.0
# 6            Connecticut     1631610    1640840.0    1648070.0    1658980.0
# 7               Delaware      403650     413940.0     417550.0     424270.0
# 8   District of Columbia      595220     609770.0     611190.0     609400.0
# 9                Florida     7217400    7479050.0    7614840.0    7869210.0
# 10               Georgia     3770430    3848740.0    3904020.0    4001580.0
# ...

# %%
m = LifeSci3.mean(axis=1)
for i, col in enumerate(LifeSci3):
    LifeSci3.iloc[:, i] = LifeSci3.iloc[:, i].fillna(m)
LifeSci3 = LifeSci3.drop(['Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',], axis = 1)

LifeSci3 = LifeSci3.rename(columns = {'Table S-34':'State',
                                       'Unnamed: 33':'All Occupations 2018'})

LifeSci3.head(10)
# Out:
#                   State  All Occupations 2018
# 0               Alabama             1943760.0
# 1                Alaska              315250.0
# 2               Arizona             2789520.0
# 3              Arkansas             1210120.0
# 4            California            17007690.0
# 5              Colorado             2620640.0
# 6           Connecticut             1660200.0
# 7              Delaware              448510.0
# 8  District of Columbia              712370.0
# 9               Florida             8608660.0

# %%
LifeSci4 = LifeSci.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                          'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
                          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
                          'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
                          'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
                          'Unnamed: 34',], axis = 1)

LifeSci4.head()
# Out:
#                                           Table S-34  \
# 0  Life Scientists as a Percentage of All Occupat...
# 1                                                NaN
# 2                                              State
# 3                                      United States
# 4                                            Alabama
#
#                                     Unnamed: 35  Unnamed: 36  Unnamed: 37  \
# 0                                           NaN          NaN          NaN
# 1  Life scientists in all occupations (Percent)          NaN          NaN
# 2                                          2003  2004.000000  2005.000000
# 3                                      0.213867     0.221554     0.223279
# 4                                      0.123814     0.128576     0.125494
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
LifeSci4.drop(range(0,4), inplace = True)
LifeSci4.drop(range(55,64), inplace = True)
LifeSci4 = LifeSci4.reset_index(drop = True)
LifeSci4
# Out:
#               Table S-34 Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 0                Alabama    0.123814     0.128576     0.125494     0.146950
# 1                 Alaska    0.567517     0.591596     0.589705     0.612064
# 2                Arizona     0.12745     0.121056     0.110787     0.108385
# 3               Arkansas    0.136767     0.135826     0.133932     0.127695
# 4             California    0.230761     0.256058     0.255639     0.265702
# 5               Colorado         NaN          NaN     0.237971     0.208869
# 6            Connecticut    0.288672     0.299237     0.306419     0.291143
# 7               Delaware    0.314629     0.289897     0.273021     0.327622
# 8   District of Columbia    0.389772     0.419830     0.448306     0.403676
# 9                Florida    0.118187     0.129696     0.132242     0.120851
# 10               Georgia    0.192816     0.137448     0.138831     0.133697
# ...

# %%
m = LifeSci4.mean(axis=1)
for i, col in enumerate(LifeSci4):
    LifeSci4.iloc[:, i] = LifeSci4.iloc[:, i].fillna(m)
LifeSci4 = LifeSci4.drop(['Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
                          'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
                          'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49'], axis = 1)

LifeSci4 = LifeSci4.rename(columns = {'Table S-34':'State',
                                       'Unnamed: 50':'Life Scientists 2018 (Percent)'})

LifeSci4.head(10)
# Out:
#                   State  Life Scientists 2018 (Percent)
# 0               Alabama                        0.163600
# 1                Alaska                        0.580492
# 2               Arizona                        0.160601
# 3              Arkansas                        0.182627
# 4            California                        0.375124
# 5              Colorado                        0.300308
# 6           Connecticut                        0.253584
# 7              Delaware                        0.280930
# 8  District of Columbia                        0.307425
# 9               Florida                        0.132076

# %%
LifeSciDFs = [LifeSci2, LifeSci3, LifeSci4]

LifeSciFinal = reduce(lambda left, right: pd.merge(left, right, on = 'State', how = 'outer'), LifeSciDFs)

LifeSciFinal
# Out:
#                    State  Life Scientists 2018  All Occupations 2018  \
# 0                Alabama           3180.000000             1943760.0
# 1                 Alaska           1830.000000              315250.0
# 2                Arizona           4480.000000             2789520.0
# 3               Arkansas           2210.000000             1210120.0
# 4             California          63800.000000            17007690.0
# 5               Colorado           7870.000000             2620640.0
# 6            Connecticut           4210.000000             1660200.0
# 7               Delaware           1260.000000              448510.0
# 8   District of Columbia           2190.000000              712370.0
# 9                Florida          11370.000000             8608660.0
# 10               Georgia           5860.833333             4394740.0
# 11                Hawaii           1610.000000              641790.0
# 12                 Idaho           2790.000000              706140.0
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDLifeSci = pd.merge(COVIDCases, LifeSciFinal, how = 'left', on = 'State')
COVIDLifeSci
# Out:
#                    State  fips     cases   deaths  Life Scientists 2018  \
# 0                Alabama    73    387786    14345           3180.000000
# 1                 Alaska   148     18316      367           1830.000000
# 2                Arizona   480    426614    18857           4480.000000
# 3               Arkansas   375    161569     3301           2210.000000
# 4             California   726   2664110   102387          63800.000000
# 5               Colorado   648    766512    37828           7870.000000
# 6            Connecticut   702   1314995   104185           4210.000000
# 7               Delaware   750    234327     7813           1260.000000
# 8   District of Columbia   869    229466    10822           2190.000000
# 9                Florida  1020   1726811    63147          11370.000000
# 10               Georgia  1092   1282091    54209           5860.833333
# 11                Hawaii  1200     31433      681           1610.000000
# ...

# %%
COVIDLifeSci = COVIDLifeSci.drop(['fips'], axis = 1)
COVIDLifeSci
# Out:
#                    State     cases   deaths  Life Scientists 2018  \
# 0                Alabama    387786    14345           3180.000000
# 1                 Alaska     18316      367           1830.000000
# 2                Arizona    426614    18857           4480.000000
# 3               Arkansas    161569     3301           2210.000000
# 4             California   2664110   102387          63800.000000
# 5               Colorado    766512    37828           7870.000000
# 6            Connecticut   1314995   104185           4210.000000
# 7               Delaware    234327     7813           1260.000000
# 8   District of Columbia    229466    10822           2190.000000
# 9                Florida   1726811    63147          11370.000000
# 10               Georgia   1282091    54209           5860.833333
# 11                Hawaii     31433      681           1610.000000
# 12                 Idaho    103987     2828           2790.000000
# ...

# %%
COVIDLifeSci.to_csv('LifeSci_Jobs.csv')
