# %%
import pandas as pd
import numpy as np

# %%
povertycount = pd.read_csv('SAIPESNC_25MAY20_15_43_20_02.csv')
povertycount.head()
# Out:
#    Year  State  County ID  State / County Name  \
# 0  2018      0          0        United States
# 1  2018      1       1000              Alabama
# 2  2018      1       1001  Autauga County (AL)
# 3  2018      1       1003  Baldwin County (AL)
# 4  2018      1       1005  Barbour County (AL)
#
#   All Ages SAIPE Poverty Universe All Ages in Poverty Count  \
# 0                     319,184,033                41,852,315
# 1                       4,763,811                   801,758
# 2                          55,073                     7,587
# 3                         215,255                    21,069
# 4                          21,979                     6,788
#
#   All Ages in Poverty Count LB 90% All Ages in Poverty Count UB 90%  \
# 0                       41,619,366                       42,085,264
# 1                          785,668                          817,848
# 2                            6,334                            8,840
# ...

# %%
povertycount = povertycount[['State / County Name','All Ages SAIPE Poverty Universe','All Ages in Poverty Count']]

# %%
povertycount
# Out:
#          State / County Name All Ages SAIPE Poverty Universe  \
# 0              United States                     319,184,033
# 1                    Alabama                       4,763,811
# 2        Autauga County (AL)                          55,073
# 3        Baldwin County (AL)                         215,255
# 4        Barbour County (AL)                          21,979
# ...                      ...                             ...
# 3189  Sweetwater County (WY)                          42,205
# 3190       Teton County (WY)                          22,888
# 3191       Uinta County (WY)                          20,135
# 3192    Washakie County (WY)                           7,735
# 3193      Weston County (WY)                           6,595
#
#      All Ages in Poverty Count
# 0                   41,852,315
# 1                      801,758
# 2                        7,587
# 3                       21,069
# 4                        6,788
# ...                        ...
# ...

# %%
povertycount = povertycount.rename(columns = {'State / County Name':'State'})
povertycount
# Out:
#                        State All Ages SAIPE Poverty Universe  \
# 0              United States                     319,184,033
# 1                    Alabama                       4,763,811
# 2        Autauga County (AL)                          55,073
# 3        Baldwin County (AL)                         215,255
# 4        Barbour County (AL)                          21,979
# ...                      ...                             ...
# 3189  Sweetwater County (WY)                          42,205
# 3190       Teton County (WY)                          22,888
# 3191       Uinta County (WY)                          20,135
# 3192    Washakie County (WY)                           7,735
# 3193      Weston County (WY)                           6,595
#
#      All Ages in Poverty Count
# 0                   41,852,315
# 1                      801,758
# 2                        7,587
# 3                       21,069
# 4                        6,788
# ...                        ...
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases
# Out:
#             date          state  fips  cases  deaths
# 0     2020-01-21     Washington    53      1       0
# 1     2020-01-22     Washington    53      1       0
# 2     2020-01-23     Washington    53      1       0
# 3     2020-01-24       Illinois    17      1       0
# 4     2020-01-24     Washington    53      1       0
# ...          ...            ...   ...    ...     ...
# 4574  2020-05-24       Virginia    51  36244    1171
# 4575  2020-05-24     Washington    53  20732    1069
# 4576  2020-05-24  West Virginia    54   1771      72
# 4577  2020-05-24      Wisconsin    55  15362     510
# 4578  2020-05-24        Wyoming    56    813      12
#
# [4579 rows x 5 columns]

# %%
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases
# Out:
#                        state  fips     cases   deaths
# 0                    Alabama    73    387786    14345
# 1                     Alaska   148     18316      367
# 2                    Arizona   480    426614    18857
# 3                   Arkansas   375    161569     3301
# 4                 California   726   2664110   102387
# 5                   Colorado   648    766512    37828
# 6                Connecticut   702   1314995   104185
# 7                   Delaware   750    234327     7813
# 8       District of Columbia   869    229466    10822
# 9                    Florida  1020   1726811    63147
# 10                   Georgia  1092   1282091    54209
# 11                      Guam  4686     48340      311
# 12                    Hawaii  1200     31433      681
# 13                     Idaho  1168    103987     2828
# 14                  Illinois  2074   2843621   122000
# 15                   Indiana  1440    920434    53042
# ...

# %%
COVIDCases.state
# Out:
# 0                      Alabama
# 1                       Alaska
# 2                      Arizona
# 3                     Arkansas
# 4                   California
# 5                     Colorado
# 6                  Connecticut
# 7                     Delaware
# 8         District of Columbia
# 9                      Florida
# 10                     Georgia
# 11                        Guam
# 12                      Hawaii
# 13                       Idaho
# 14                    Illinois
# 15                     Indiana
# 16                        Iowa
# 17                      Kansas
# 18                    Kentucky
# 19                   Louisiana
# 20                       Maine
# 21                    Maryland
# 22               Massachusetts
# 23                    Michigan
# 24                   Minnesota
# 25                 Mississippi
# 26                    Missouri
# 27                     Montana
# 28                    Nebraska
# 29                      Nevada
# ...

# %%
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.State
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDpovertycount = pd.merge(COVIDCases, povertycount, how = 'left', on = 'State')
COVIDpovertycount
# Out:
#                    State  fips     cases   deaths  \
# 0                Alabama    73    387786    14345
# 1                 Alaska   148     18316      367
# 2                Arizona   480    426614    18857
# 3               Arkansas   375    161569     3301
# 4             California   726   2664110   102387
# 5               Colorado   648    766512    37828
# 6            Connecticut   702   1314995   104185
# 7               Delaware   750    234327     7813
# 8   District of Columbia   869    229466    10822
# 9                Florida  1020   1726811    63147
# 10               Georgia  1092   1282091    54209
# 11                Hawaii  1200     31433      681
# 12                 Idaho  1168    103987     2828
# 13              Illinois  2074   2843621   122000
# 14               Indiana  1440    920434    53042
# 15                  Iowa  1482    396980     9203
# 16                Kansas  1580    231885     6527
# 17              Kentucky  1680    246480    11851
# ...

# %%
COVIDpovertycount = COVIDpovertycount.drop(['fips'], axis = 1)
COVIDpovertycount
# Out:
#                    State     cases   deaths All Ages SAIPE Poverty Universe  \
# 0                Alabama    387786    14345                       4,763,811
# 1                 Alaska     18316      367                         720,866
# 2                Arizona    426614    18857                       7,013,461
# 3               Arkansas    161569     3301                       2,925,473
# 4             California   2664110   102387                      38,818,530
# 5               Colorado    766512    37828                       5,577,050
# 6            Connecticut   1314995   104185                       3,468,263
# 7               Delaware    234327     7813                         940,779
# 8   District of Columbia    229466    10822                         669,029
# 9                Florida   1726811    63147                      20,882,673
# 10               Georgia   1282091    54209                      10,238,647
# ...
