# %%
import pandas as pd
import numpy as np

# %%
agi = pd.read_excel('17in02stateshares.xlsx')
agi
# Out:
#    Table 2. Returns with Positive Adjusted Gross\nIncome (AGI): Number of Returns, Shares of AGI, \nand Sources of Income, by Selected Descending\nCumulative Percentiles of Returns Based on Income\nSize Using the Definition of AGI, by State, Tax Year 2017  \
# 0             [money amounts in thousands of dollars]
# 1                                               State
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 56                                          Wisconsin
# 57                                            Wyoming
# 58  [1] The number of returns with negative adjust...
# 59  NOTES: (a) The data in the table were compiled...
# 60  Source: IRS, Statistics of Income Division, Ma...
#
#                Unnamed: 1                         Unnamed: 2      Unnamed: 3  \
# ...

# %%
agi = agi.rename(columns = {'Table 2. Returns with Positive Adjusted Gross\nIncome (AGI): Number of Returns, Shares of AGI, \nand Sources of Income, by Selected Descending\nCumulative Percentiles of Returns Based on Income\nSize Using the Definition of AGI, by State, Tax Year 2017' :'State'})
agi
# Out:
#                                                 State             Unnamed: 1  \
# 0             [money amounts in thousands of dollars]                    NaN
# 1                                               State  Number of returns [1]
# 2                                                 NaN                  Total
# 3                                                 NaN                    NaN
# 4                                                 NaN                    NaN
# ..                                                ...                    ...
# 56                                          Wisconsin                2613791
# 57                                            Wyoming                 249553
# 58  [1] The number of returns with negative adjust...                    NaN
# 59  NOTES: (a) The data in the table were compiled...                    NaN
# 60  Source: IRS, Statistics of Income Division, Ma...                    NaN
#
# ...

# %%
agi = agi[['State', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14']]

# %%
agi
# Out:
#                                                 State             Unnamed: 8  \
# 0             [money amounts in thousands of dollars]                    NaN
# 1                                               State  Adjusted gross income
# 2                                                 NaN                  Total
# 3                                                 NaN                    NaN
# 4                                                 NaN                    NaN
# ..                                                ...                    ...
# 56                                          Wisconsin              185948284
# 57                                            Wyoming               21692660
# 58  [1] The number of returns with negative adjust...                    NaN
# 59  NOTES: (a) The data in the table were compiled...                    NaN
# 60  Source: IRS, Statistics of Income Division, Ma...                    NaN
#
# ...

# %%
agi.drop(range(0,7), inplace = True)
# Out:
# C:\Users\Nithin Reddy Malyala\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
agi
# Out:
#                                                 State  Unnamed: 8 Unnamed: 9  \
# 7                                             Alabama   119662909   18553159
# 8                                              Alaska    23969001    2848087
# 9                                             Arizona   197753744   33609317
# 10                                           Arkansas    74634888   16319991
# 11                                         California  1549284943  356240355
# 12                                           Colorado   212581123   37479649
# 13                                        Connecticut   175792834   47379889
# 14                                           Delaware    31403165    4412370
# 15                               District of Columbia    34743188    7442186
# 16                                            Florida   750608252  213461301
# 17                                            Georgia   301921590   57388490
# ...

# %%
agi = agi.reset_index(drop = True)

# %%
agi
# Out:
#                                                 State  Unnamed: 8 Unnamed: 9  \
# 0                                             Alabama   119662909   18553159
# 1                                              Alaska    23969001    2848087
# 2                                             Arizona   197753744   33609317
# 3                                            Arkansas    74634888   16319991
# 4                                          California  1549284943  356240355
# 5                                            Colorado   212581123   37479649
# 6                                         Connecticut   175792834   47379889
# 7                                            Delaware    31403165    4412370
# 8                                District of Columbia    34743188    7442186
# 9                                             Florida   750608252  213461301
# 10                                            Georgia   301921590   57388490
# ...

# %%
agi = agi.rename(columns = {'Unnamed: 8' : 'AGI Total',
                            'Unnamed: 9' : 'AGI Top 1 Percent',
                           'Unnamed: 10' :  'AGI Top 5 Percent',
                           'Unnamed: 11' : 'AGI Top 10 Percent',
                           'Unnamed: 12' : 'AGI Top 25 Percent',
                           'Unnamed: 13' : 'AGI Top 50 Percent',
                           'Unnamed: 14' : 'AGI Top 75 Percent'})

agi.head()
# Out:
#         State   AGI Total AGI Top 1 Percent AGI Top 5 Percent  \
# 0     Alabama   119662909          18553159          35924229
# 1      Alaska    23969001           2848087           6184956
# 2     Arizona   197753744          33609317          63073164
# 3    Arkansas    74634888          16319991          26475276
# 4  California  1549284943         356240355         600859502
#
#   AGI Top 10 Percent AGI Top 25 Percent AGI Top 50 Percent AGI Top 75 Percent
# 0           49537638           76667112          101687773          114405941
# 1            8915998           14554105           20064361           22927860
# 2           85351788          128616004          168531690          189378565
# 3           34256878           49689104           64088761           71584342
# 4          772738760         1086299917         1360947743         1497300869

# %%
agi
# Out:
#                                                 State   AGI Total  \
# 0                                             Alabama   119662909
# 1                                              Alaska    23969001
# 2                                             Arizona   197753744
# 3                                            Arkansas    74634888
# 4                                          California  1549284943
# 5                                            Colorado   212581123
# 6                                         Connecticut   175792834
# 7                                            Delaware    31403165
# 8                                District of Columbia    34743188
# 9                                             Florida   750608252
# 10                                            Georgia   301921590
# 11                                             Hawaii    46035510
# 12                                              Idaho    46384513
# ...

# %%
agi.drop(range(51,54), inplace= True)
agi
# Out:
#                    State   AGI Total AGI Top 1 Percent AGI Top 5 Percent  \
# 0                Alabama   119662909          18553159          35924229
# 1                 Alaska    23969001           2848087           6184956
# 2                Arizona   197753744          33609317          63073164
# 3               Arkansas    74634888          16319991          26475276
# 4             California  1549284943         356240355         600859502
# 5               Colorado   212581123          37479649          69617571
# 6            Connecticut   175792834          47379889          74456114
# 7               Delaware    31403165           4412370           8899481
# 8   District of Columbia    34743188           7442186          13245281
# 9                Florida   750608252         213461301         325886670
# 10               Georgia   301921590          57388490         104804525
# 11                Hawaii    46035510           6481803          12912656
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases
# Out:
#             date          state  fips  cases  deaths
# 0     2020-01-21     Washington    53      1       0
# 1     2020-01-22     Washington    53      1       0
# 2     2020-01-23     Washington    53      1       0
# 3     2020-01-24       Illinois    17      1       0
# 4     2020-01-24     Washington    53      1       0
# ...          ...            ...   ...    ...     ...
# 4574  2020-05-24       Virginia    51  36244    1171
# 4575  2020-05-24     Washington    53  20732    1069
# 4576  2020-05-24  West Virginia    54   1771      72
# 4577  2020-05-24      Wisconsin    55  15362     510
# 4578  2020-05-24        Wyoming    56    813      12
#
# [4579 rows x 5 columns]

# %%
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases
# Out:
#                        state  fips     cases   deaths
# 0                    Alabama    73    387786    14345
# 1                     Alaska   148     18316      367
# 2                    Arizona   480    426614    18857
# 3                   Arkansas   375    161569     3301
# 4                 California   726   2664110   102387
# 5                   Colorado   648    766512    37828
# 6                Connecticut   702   1314995   104185
# 7                   Delaware   750    234327     7813
# 8       District of Columbia   869    229466    10822
# 9                    Florida  1020   1726811    63147
# 10                   Georgia  1092   1282091    54209
# 11                      Guam  4686     48340      311
# 12                    Hawaii  1200     31433      681
# 13                     Idaho  1168    103987     2828
# 14                  Illinois  2074   2843621   122000
# 15                   Indiana  1440    920434    53042
# ...

# %%
COVIDCases.state
# Out:
# 0                      Alabama
# 1                       Alaska
# 2                      Arizona
# 3                     Arkansas
# 4                   California
# 5                     Colorado
# 6                  Connecticut
# 7                     Delaware
# 8         District of Columbia
# 9                      Florida
# 10                     Georgia
# 11                        Guam
# 12                      Hawaii
# 13                       Idaho
# 14                    Illinois
# 15                     Indiana
# 16                        Iowa
# 17                      Kansas
# 18                    Kentucky
# 19                   Louisiana
# 20                       Maine
# 21                    Maryland
# 22               Massachusetts
# 23                    Michigan
# 24                   Minnesota
# 25                 Mississippi
# 26                    Missouri
# 27                     Montana
# 28                    Nebraska
# 29                      Nevada
# ...

# %%
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})

# %%
COVIDagi = pd.merge(COVIDCases, agi, how = 'left', on = 'State')
COVIDagi
# Out:
#                    State  fips     cases   deaths   AGI Total  \
# 0                Alabama    73    387786    14345   119662909
# 1                 Alaska   148     18316      367    23969001
# 2                Arizona   480    426614    18857   197753744
# 3               Arkansas   375    161569     3301    74634888
# 4             California   726   2664110   102387  1549284943
# 5               Colorado   648    766512    37828   212581123
# 6            Connecticut   702   1314995   104185   175792834
# 7               Delaware   750    234327     7813    31403165
# 8   District of Columbia   869    229466    10822    34743188
# 9                Florida  1020   1726811    63147   750608252
# 10               Georgia  1092   1282091    54209   301921590
# 11                Hawaii  1200     31433      681    46035510
# 12                 Idaho  1168    103987     2828    46384513
# 13              Illinois  2074   2843621   122000   459437029
# ...

# %%
COVIDagi = COVIDagi.drop(['fips'], axis = 1)
COVIDagi
# Out:
#                    State     cases   deaths   AGI Total AGI Top 1 Percent  \
# 0                Alabama    387786    14345   119662909          18553159
# 1                 Alaska     18316      367    23969001           2848087
# 2                Arizona    426614    18857   197753744          33609317
# 3               Arkansas    161569     3301    74634888          16319991
# 4             California   2664110   102387  1549284943         356240355
# 5               Colorado    766512    37828   212581123          37479649
# 6            Connecticut   1314995   104185   175792834          47379889
# 7               Delaware    234327     7813    31403165           4412370
# 8   District of Columbia    229466    10822    34743188           7442186
# 9                Florida   1726811    63147   750608252         213461301
# 10               Georgia   1282091    54209   301921590          57388490
# 11                Hawaii     31433      681    46035510           6481803
# ...

# %%
COVIDagi.to_csv('COVIDAGI.csv')
