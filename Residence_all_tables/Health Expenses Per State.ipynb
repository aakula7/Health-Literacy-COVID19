# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
Tab1 = pd.read_excel('Residence_all_tables.xlsx', 'Table 1 Personal Health Care')
Tab2 = pd.read_excel('Residence_all_tables.xlsx', 'Table 2 Hospital')
Tab3 = pd.read_excel('Residence_all_tables.xlsx', 'Table 3 Physician and Clinics')
Tab4 = pd.read_excel('Residence_all_tables.xlsx', 'Table 4 Other Professionals')
Tab6 = pd.read_excel('Residence_all_tables.xlsx', 'Table 6 Home Health')
Tab8 = pd.read_excel('Residence_all_tables.xlsx', 'Table 8 Drugs and Non-durables')
Tab9 = pd.read_excel('Residence_all_tables.xlsx', 'Table 9 Durables')
Tab10 = pd.read_excel('Residence_all_tables.xlsx', 'Table 10 Other Health')

# %%
Tab1
# Out:
#    Table 1: Total All Payers State Estimates by State of Residence (1991 - 2014) - Personal Health Care (Millions of Dollars)  \
# 0                           Region/state of residence
# 1                                       United States
# 2                                         New England
# 3                                         Connecticut
# 4                                               Maine
# ..                                                ...
# 58                                             Nevada
# 59                                             Oregon
# 60                                         Washington
# 61  NOTE: Numbers may not add to totals shown beca...
# 62  SOURCE: Centers for Medicare and Medicaid Serv...
#
#     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0       1991.0      1992.0      1993.0      1994.0      1995.0      1996.0
# 1     675896.0    731455.0    778684.0    820172.0    869578.0    917540.0
# ...

# %%
Tab1 = Tab1.rename(columns = {'Table 1: Total All Payers State Estimates by State of Residence (1991 - 2014) - Personal Health Care (Millions of Dollars)':'State',
                             'Unnamed: 24':'Personal Health Care Expenses Per State (2014)'})
Tab1 = Tab1[['State', 'Personal Health Care Expenses Per State (2014)']]
Tab1
# Out:
#                                                 State  \
# 0                           Region/state of residence
# 1                                       United States
# 2                                         New England
# 3                                         Connecticut
# 4                                               Maine
# ..                                                ...
# 58                                             Nevada
# 59                                             Oregon
# 60                                         Washington
# 61  NOTE: Numbers may not add to totals shown beca...
# 62  SOURCE: Centers for Medicare and Medicaid Serv...
#
#     Personal Health Care Expenses Per State (2014)
# 0                                           2014.0
# 1                                        2562824.0
# 2                                         148571.0
# 3                                          35413.0
# 4                                          12684.0
# ...

# %%
Tab2 = Tab2.rename(columns = {'Table 2: Total All Payers State Estimates by State of Residence (1991 - 2014) - Hospital Services (Millions of Dollars)':'State',
                             'Unnamed: 24':'Hospital Services Expenses Per State (2014)'})
Tab2 = Tab2[['State', 'Hospital Services Expenses Per State (2014)']]

# %%
Tab2.head()
# Out:
#                        State  Hospital Services Expenses Per State (2014)
# 0  Region/state of residence                                       2014.0
# 1              United States                                     980966.0
# 2                New England                                      55504.0
# 3                Connecticut                                      11947.0
# 4                      Maine                                       5261.0

# %%
Tab3 = Tab3.rename(columns = {'Table 3: Total All Payers State Estimates by State of Residence (1991 - 2014) - Physician and Clinical Services (Millions of Dollars)':'State',
                             'Unnamed: 24':'Pysician and Clincial Services Expenses Per State (2014)'})
Tab3 = Tab3[['State','Pysician and Clincial Services Expenses Per State (2014)']]
Tab3.head()
# Out:
#                        State  \
# 0  Region/state of residence
# 1              United States
# 2                New England
# 3                Connecticut
# 4                      Maine
#
#    Pysician and Clincial Services Expenses Per State (2014)
# 0                                             2014.0
# 1                                           597137.0
# 2                                            31385.0
# 3                                             7852.0
# 4                                             2240.0

# %%
Tab4 = Tab4.rename(columns = {'Table 4: Total All Payers State Estimates by State of Residence (1991 - 2014) - Other Professional Services (Millions of Dollars)':'State',
                             'Unnamed: 24':'Other Professional Services Expenses Per State (2014)'})
Tab4 = Tab4[['State', 'Other Professional Services Expenses Per State (2014)']]
Tab4.head()
# Out:
#                        State  \
# 0  Region/state of residence
# 1              United States
# 2                New England
# 3                Connecticut
# 4                      Maine
#
#    Other Professional Services Expenses Per State (2014)
# 0                                             2014.0
# 1                                            82826.0
# 2                                             4506.0
# 3                                             1156.0
# 4                                              438.0

# %%
Tab6 = Tab6.rename(columns = {'Table 6: Total All Payers State Estimates by State of Residence (1991 - 2014) - Home Health Care (Millions of Dollars)':'State',
                             'Unnamed: 24':'Home Health Care Expenses Per State (2014)'})
Tab6 = Tab6[['State','Home Health Care Expenses Per State (2014)']]
Tab6.head()
# Out:
#                        State  Home Health Care Expenses Per State (2014)
# 0  Region/state of residence                                      2014.0
# 1              United States                                     83566.0
# 2                New England                                      6592.0
# 3                Connecticut                                      1062.0
# 4                      Maine                                       270.0

# %%
Tab8 = Tab8.rename(columns = {'Table 8: Total All Payers State Estimates by State of Residence (1991 - 2014) - Drugs and Other Non-durable Products  (Millions of Dollars)':'State',
                             'Unnamed: 24':'Drugs and Non-Durables Expenses Per State (2014)'})
Tab8 = Tab8[['State','Drugs and Non-Durables Expenses Per State (2014)']]
Tab8.head()
# Out:
#                        State  Drugs and Non-Durables Expenses Per State (2014)
# 0  Region/state of residence                                            2014.0
# 1              United States                                          354784.0
# 2                New England                                           19116.0
# 3                Connecticut                                            5300.0
# 4                      Maine                                            1542.0

# %%
Tab9 = Tab9.rename(columns = {'Table 9: Total All Payers State Estimates by State of Residence (1991 - 2014) - Durable Medical Equipment  (Millions of Dollars)':'State',
                             'Unnamed: 24':'Durables Expenses Per State (2014)'})
Tab9 = Tab9[['State','Durables Expenses Per State (2014)']]
Tab9.head()
# Out:
#                        State  Durables Expenses Per State (2014)
# 0  Region/state of residence                              2014.0
# 1              United States                             46622.0
# 2                New England                              2319.0
# 3                Connecticut                               506.0
# 4                      Maine                               183.0

# %%
Tab10 = Tab10.rename(columns = {'Table 10: Total All Payers State Estimates by State of Residence (1991 - 2014) - Other Health Residential and Personal Care (Millions of Dollars)':'State',
                             'Unnamed: 24':'Other Health Care Expenses Per State (2014)'})
Tab10 = Tab10[['State','Other Health Care Expenses Per State (2014)']]
Tab10.head()
# Out:
#                        State  Other Health Care Expenses Per State (2014)
# 0  Region/state of residence                                       2014.0
# 1              United States                                     151456.0
# 2                New England                                      11747.0
# 3                Connecticut                                       2839.0
# 4                      Maine                                       1463.0

# %%
PerStateDF = [Tab1, Tab2, Tab3, Tab4, Tab6, Tab8, Tab9, Tab10]
PerStateFinal = reduce(lambda left, right: pd.merge(left, right, on = 'State', how = 'outer'), PerStateDF)
PerStateFinal.head()
# Out:
#                        State  Personal Health Care Expenses Per State (2014)  \
# 0  Region/state of residence                                          2014.0
# 1              United States                                       2562824.0
# 2                New England                                        148571.0
# 3                Connecticut                                         35413.0
# 4                      Maine                                         12684.0
#
#    Hospital Services Expenses Per State (2014)  \
# 0                                       2014.0
# 1                                     980966.0
# 2                                      55504.0
# 3                                      11947.0
# 4                                       5261.0
#
#    Pysician and Clincial Services Expenses Per State (2014)  \
# 0                                             2014.0
# 1                                           597137.0
# ...

# %%
COVIDCases = pd.read_csv('us-states.csv')
COVIDCases = COVIDCases.groupby(['state']).sum()
COVIDCases = COVIDCases.reset_index()
COVIDCases.drop([11, 36, 41, 49], inplace = True)
COVIDCases = COVIDCases.reset_index(drop = True)
COVIDCases.state
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
COVIDCases = COVIDCases.rename(columns = {'state':'State'})
COVIDCases.head()
# Out:
#         State  fips    cases  deaths
# 0     Alabama    73   387786   14345
# 1      Alaska   148    18316     367
# 2     Arizona   480   426614   18857
# 3    Arkansas   375   161569    3301
# 4  California   726  2664110  102387

# %%
COVIDHealthPerState = pd.merge(COVIDCases, PerStateFinal, how = 'left', on = 'State')
COVIDHealthPerState
# Out:
#                    State  fips     cases   deaths  \
# 0                Alabama    73    387786    14345
# 1                 Alaska   148     18316      367
# 2                Arizona   480    426614    18857
# 3               Arkansas   375    161569     3301
# 4             California   726   2664110   102387
# 5               Colorado   648    766512    37828
# 6            Connecticut   702   1314995   104185
# 7               Delaware   750    234327     7813
# 8   District of Columbia   869    229466    10822
# 9                Florida  1020   1726811    63147
# 10               Georgia  1092   1282091    54209
# 11                Hawaii  1200     31433      681
# 12                 Idaho  1168    103987     2828
# 13              Illinois  2074   2843621   122000
# 14               Indiana  1440    920434    53042
# 15                  Iowa  1482    396980     9203
# 16                Kansas  1580    231885     6527
# 17              Kentucky  1680    246480    11851
# ...

# %%
COVIDHealthPerState = COVIDHealthPerState.drop(['fips'], axis = 1)
COVIDHealthPerState
# Out:
#                    State     cases   deaths  \
# 0                Alabama    387786    14345
# 1                 Alaska     18316      367
# 2                Arizona    426614    18857
# 3               Arkansas    161569     3301
# 4             California   2664110   102387
# 5               Colorado    766512    37828
# 6            Connecticut   1314995   104185
# 7               Delaware    234327     7813
# 8   District of Columbia    229466    10822
# 9                Florida   1726811    63147
# 10               Georgia   1282091    54209
# 11                Hawaii     31433      681
# 12                 Idaho    103987     2828
# 13              Illinois   2843621   122000
# 14               Indiana    920434    53042
# 15                  Iowa    396980     9203
# 16                Kansas    231885     6527
# 17              Kentucky    246480    11851
# 18             Louisiana   1443404    90609
# 19                 Maine     61284     2451
# ...
